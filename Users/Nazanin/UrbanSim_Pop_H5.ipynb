# %%
import h5py

# %%
#Assuming you do not know your hierarchy structure in advance, you can use a recursive algorithm to yield, via an iterator, full paths to all available datasets in the form group1/group2/.../dataset.
def traverse_datasets(hdf_file):

    def h5py_dataset_iterator(g, prefix=''):
        for key in g.keys():
            item = g[key]
            path = f'{prefix}/{key}'
            if isinstance(item, h5py.Dataset): # test for dataset
                yield (path, item)
            elif isinstance(item, h5py.Group): # test for group (go down)
                yield from h5py_dataset_iterator(item, path)

    for path, _ in h5py_dataset_iterator(hdf_file):
        yield path

# %%
with h5py.File('C:/Users/nazanin/Downloads/custom_mpo_06197001_model_data.h5', 'r') as f:
    for dset in traverse_datasets(f):
        print('Path:', dset)
        print('Shape:', f[dset].shape)
        print('Data type:', f[dset].dtype)
# Out:
# Path: /blocks/axis0
# Shape: (15,)
# Data type: |S25
# Path: /blocks/axis1
# Shape: (108469,)
# Data type: |S15
# Path: /blocks/block0_items
# Shape: (8,)
# Data type: |S14
# Path: /blocks/block0_values
# Shape: (1,)
# Data type: object
# Path: /blocks/block1_items
# Shape: (5,)
# Data type: |S25
# Path: /blocks/block1_values
# Shape: (108469, 5)
# Data type: float64
# Path: /blocks/block2_items
# Shape: (2,)
# Data type: |S18
# Path: /blocks/block2_values
# Shape: (108469, 2)
# Data type: int64
# Path: /counties/axis0
# Shape: (2,)
# Data type: |S9
# Path: /counties/axis1
# Shape: (9,)
# Data type: int64
# Path: /counties/block0_items
# Shape: (1,)
# Data type: |S9
# Path: /counties/block0_values
# Shape: (1,)
# Data type: object
# Path: /counties/block1_items
# Shape: (1,)
# Data type: |S8
# Path: /counties/block1_values
# Shape: (9, 1)
# Data type: float64
# Path: /ect/axis0
# Shape: (1,)
# Data type: |S20
# Path: /ect/axis1
# Shape: (41,)
# Data type: int64
# Path: /ect/block0_items
# Shape: (1,)
# Data type: |S20
# Path: /ect/block0_values
# Shape: (41, 1)
# Data type: float64
# Path: /edges/axis0
# Shape: (3,)
# Data type: |S6
# Path: /edges/axis1
# Shape: (232266,)
# Data type: int64
# Path: /edges/block0_items
# Shape: (2,)
# Data type: |S4
# Path: /edges/block0_values
# Shape: (232266, 2)
# Data type: int64
# Path: /edges/block1_items
# Shape: (1,)
# Data type: |S6
# Path: /edges/block1_values
# Shape: (232266, 1)
# Data type: float64
# Path: /hct/axis0
# Shape: (1,)
# Data type: |S26
# Path: /hct/axis1
# Shape: (41,)
# Data type: int64
# Path: /hct/block0_items
# Shape: (1,)
# Data type: |S26
# Path: /hct/block0_values
# Shape: (41, 1)
# Data type: float64
# Path: /household_targets_acs/axis0
# Shape: (8,)
# Data type: |S14
# Path: /household_targets_acs/axis1
# Shape: (1585,)
# Data type: |S11
# Path: /household_targets_acs/block0_items
# Shape: (8,)
# Data type: |S14
# Path: /household_targets_acs/block0_values
# Shape: (1585, 8)
# Data type: float64
# Path: /household_validation_acs/axis0
# Shape: (8,)
# Data type: |S14
# Path: /household_validation_acs/axis1
# Shape: (1585,)
# Data type: |S11
# Path: /household_validation_acs/block0_items
# Shape: (8,)
# Data type: |S14
# Path: /household_validation_acs/block0_values
# Shape: (1585, 8)
# Data type: float64
# Path: /households/axis0
# Shape: (27,)
# Data type: |S23
# Path: /households/axis1
# Shape: (2834263,)
# Data type: int64
# Path: /households/block0_items
# Shape: (11,)
# Data type: |S23
# Path: /households/block0_values
# Shape: (2834263, 11)
# Data type: int64
# Path: /households/block1_items
# Shape: (3,)
# Data type: |S7
# Path: /households/block1_values
# Shape: (2834263, 3)
# Data type: float64
# Path: /households/block2_items
# Shape: (13,)
# Data type: |S15
# Path: /households/block2_values
# Shape: (1,)
# Data type: object
# Path: /job_county_targets_BEA/axis0
# Shape: (6,)
# Data type: |S8
# Path: /job_county_targets_BEA/axis1
# Shape: (9,)
# Data type: |S5
# Path: /job_county_targets_BEA/block0_items
# Shape: (6,)
# Data type: |S8
# Path: /job_county_targets_BEA/block0_values
# Shape: (9, 6)
# Data type: int64
# Path: /job_county_validation_BEA/axis0
# Shape: (6,)
# Data type: |S8
# Path: /job_county_validation_BEA/axis1
# Shape: (9,)
# Data type: |S5
# Path: /job_county_validation_BEA/block0_items
# Shape: (6,)
# Data type: |S8
# Path: /job_county_validation_BEA/block0_values
# Shape: (9, 6)
# Data type: int64
# Path: /job_flows/axis0
# Shape: (3,)
# Data type: |S16
# Path: /job_flows/axis1
# Shape: (1991296,)
# Data type: int64
# Path: /job_flows/block0_items
# Shape: (2,)
# Data type: |S15
# Path: /job_flows/block0_values
# Shape: (1991296, 2)
# Data type: float64
# Path: /job_flows/block1_items
# Shape: (1,)
# Data type: |S16
# Path: /job_flows/block1_values
# Shape: (1,)
# Data type: object
# Path: /job_targets/axis0
# Shape: (6,)
# Data type: |S8
# Path: /job_targets/axis1
# Shape: (1585,)
# Data type: |S11
# Path: /job_targets/block0_items
# Shape: (6,)
# Data type: |S8
# Path: /job_targets/block0_values
# Shape: (1585, 6)
# Data type: float64
# Path: /job_validation/axis0
# Shape: (6,)
# Data type: |S8
# Path: /job_validation/axis1
# Shape: (1585,)
# Data type: |S11
# Path: /job_validation/block0_items
# Shape: (6,)
# Data type: |S8
# Path: /job_validation/block0_values
# Shape: (1585, 6)
# Data type: float64
# Path: /jobs/axis0
# Shape: (4,)
# Data type: |S13
# Path: /jobs/axis1
# Shape: (5388881,)
# Data type: int64
# Path: /jobs/block0_items
# Shape: (4,)
# Data type: |S13
# Path: /jobs/block0_values
# Shape: (1,)
# Data type: object
# Path: /nodes/axis0
# Shape: (3,)
# Data type: |S2
# Path: /nodes/axis1
# Shape: (92395,)
# Data type: int64
# Path: /nodes/block0_items
# Shape: (1,)
# Data type: |S2
# Path: /nodes/block0_values
# Shape: (92395, 1)
# Data type: int64
# Path: /nodes/block1_items
# Shape: (2,)
# Data type: |S1
# Path: /nodes/block1_values
# Shape: (92395, 2)
# Data type: float64
# Path: /persons/axis0
# Shape: (21,)
# Data type: |S14
# Path: /persons/axis1
# Shape: (7399627,)
# Data type: int64
# Path: /persons/block0_items
# Shape: (3,)
# Data type: |S7
# Path: /persons/block0_values
# Shape: (7399627, 3)
# Data type: float64
# Path: /persons/block1_items
# Shape: (12,)
# Data type: |S12
# Path: /persons/block1_values
# Shape: (7399627, 12)
# Data type: int64
# Path: /persons/block2_items
# Shape: (6,)
# Data type: |S14
# Path: /persons/block2_values
# Shape: (1,)
# Data type: object
# Path: /price_targets/axis0
# Shape: (2,)
# Data type: |S16
# Path: /price_targets/axis1
# Shape: (1585,)
# Data type: |S11
# Path: /price_targets/block0_items
# Shape: (2,)
# Data type: |S16
# Path: /price_targets/block0_values
# Shape: (1585, 2)
# Data type: float64
# Path: /price_validation/axis0
# Shape: (2,)
# Data type: |S16
# Path: /price_validation/axis1
# Shape: (1585,)
# Data type: |S11
# Path: /price_validation/block0_items
# Shape: (2,)
# Data type: |S16
# Path: /price_validation/block0_values
# Shape: (1585, 2)
# Data type: float64
# Path: /residential_units/axis0
# Shape: (9,)
# Data type: |S16
# Path: /residential_units/axis1
# Shape: (3104822,)
# Data type: int64
# Path: /residential_units/block0_items
# Shape: (4,)
# Data type: |S12
# Path: /residential_units/block0_values
# Shape: (3104822, 4)
# Data type: float64
# Path: /residential_units/block1_items
# Shape: (3,)
# Data type: |S14
# Path: /residential_units/block1_values
# Shape: (1,)
# Data type: object
# Path: /residential_units/block2_items
# Shape: (2,)
# Data type: |S16
# Path: /residential_units/block2_values
# Shape: (3104822, 2)
# Data type: int64
# Path: /taz_zone_geoms/axis0
# Shape: (7,)
# Data type: |S10
# Path: /taz_zone_geoms/axis1
# Shape: (1454,)
# Data type: |S4
# Path: /taz_zone_geoms/block0_items
# Shape: (2,)
# Data type: |S8
# Path: /taz_zone_geoms/block0_values
# Shape: (1454, 2)
# Data type: int64
# Path: /taz_zone_geoms/block1_items
# Shape: (2,)
# Data type: |S8
# Path: /taz_zone_geoms/block1_values
# Shape: (1,)
# Data type: object
# Path: /taz_zone_geoms/block2_items
# Shape: (3,)
# Data type: |S10
# Path: /taz_zone_geoms/block2_values
# Shape: (1454, 3)
# Data type: float64
# Path: /travel_data/axis0
# Shape: (2,)
# Data type: |S11
# Path: /travel_data/axis1_label0
# Shape: (2111369,)
# Data type: int16
# Path: /travel_data/axis1_label1
# Shape: (2111369,)
# Data type: int16
# Path: /travel_data/axis1_level0
# Shape: (1454,)
# Data type: |S4
# Path: /travel_data/axis1_level1
# Shape: (1454,)
# Data type: |S4
# Path: /travel_data/block0_items
# Shape: (2,)
# Data type: |S11
# Path: /travel_data/block0_values
# Shape: (2111369, 2)
# Data type: float64
# Path: /unit_county_targets_PEP/axis0
# Shape: (1,)
# Data type: |S11
# Path: /unit_county_targets_PEP/axis1
# Shape: (9,)
# Data type: |S5
# Path: /unit_county_targets_PEP/block0_items
# Shape: (1,)
# Data type: |S11
# Path: /unit_county_targets_PEP/block0_values
# Shape: (9, 1)
# Data type: float64
# Path: /unit_county_validation_PEP/axis0
# Shape: (1,)
# Data type: |S11
# Path: /unit_county_validation_PEP/axis1
# Shape: (9,)
# Data type: |S5
# Path: /unit_county_validation_PEP/block0_items
# Shape: (1,)
# Data type: |S11
# Path: /unit_county_validation_PEP/block0_values
# Shape: (9, 1)
# Data type: float64
# Path: /unit_targets/axis0
# Shape: (21,)
# Data type: |S17
# Path: /unit_targets/axis1
# Shape: (1585,)
# Data type: |S11
# Path: /unit_targets/block0_items
# Shape: (21,)
# Data type: |S17
# Path: /unit_targets/block0_values
# Shape: (1585, 21)
# Data type: float64
# Path: /unit_validation/axis0
# Shape: (1,)
# Data type: |S11
# Path: /unit_validation/axis1
# Shape: (1585,)
# Data type: |S11
# Path: /unit_validation/block0_items
# Shape: (1,)
# Data type: |S11
# Path: /unit_validation/block0_values
# Shape: (1585, 1)
# Data type: float64
# Path: /validation_ect/axis0
# Shape: (3,)
# Data type: |S20
# Path: /validation_ect/axis1
# Shape: (432,)
# Data type: int64
# Path: /validation_ect/block0_items
# Shape: (2,)
# Data type: |S10
# Path: /validation_ect/block0_values
# Shape: (1,)
# Data type: object
# Path: /validation_ect/block1_items
# Shape: (1,)
# Data type: |S20
# Path: /validation_ect/block1_values
# Shape: (432, 1)
# Data type: float64
# Path: /validation_hct/axis0
# Shape: (3,)
# Data type: |S26
# Path: /validation_hct/axis1
# Shape: (648,)
# Data type: int64
# Path: /validation_hct/block0_items
# Shape: (1,)
# Data type: |S26
# Path: /validation_hct/block0_values
# Shape: (648, 1)
# Data type: float64
# Path: /validation_hct/block1_items
# Shape: (1,)
# Data type: |S7
# Path: /validation_hct/block1_values
# Shape: (648, 1)
# Data type: int64
# Path: /validation_hct/block2_items
# Shape: (1,)
# Data type: |S9
# Path: /validation_hct/block2_values
# Shape: (1,)
# Data type: object
# Path: /values/axis0
# Shape: (5,)
# Data type: |S14
# Path: /values/axis1
# Shape: (4753,)
# Data type: int64
# Path: /values/block0_items
# Shape: (4,)
# Data type: |S12
# Path: /values/block0_values
# Shape: (4753, 4)
# Data type: float64
# Path: /values/block1_items
# Shape: (1,)
# Data type: |S14
# Path: /values/block1_values
# Shape: (1,)
# Data type: object

# %%
f = h5py.File('C:/Users/nazanin/Downloads/custom_mpo_06197001_model_data.h5', 'r')
list(f.keys())
# Out:
# ['blocks',
#  'counties',
#  'ect',
#  'edges',
#  'hct',
#  'household_targets_acs',
#  'household_validation_acs',
#  'households',
#  'job_county_targets_BEA',
#  'job_county_validation_BEA',
#  'job_flows',
#  'job_targets',
#  'job_validation',
#  'jobs',
#  'nodes',
#  'persons',
#  'price_targets',
#  'price_validation',
#  'residential_units',
#  'taz_zone_geoms',
#  'travel_data',
#  'unit_county_targets_PEP',
#  'unit_county_validation_PEP',
#  'unit_targets',
#  'unit_validation',
#  'validation_ect',
#  'validation_hct',
#  'values']

# %%
list(f['persons'].keys())
# Out:
# ['axis0',
#  'axis1',
#  'block0_items',
#  'block0_values',
#  'block1_items',
#  'block1_values',
#  'block2_items',
#  'block2_values']

# %%
list(f.values())
# Out:
# [<HDF5 group "/blocks" (8 members)>,
#  <HDF5 group "/counties" (6 members)>,
#  <HDF5 group "/ect" (4 members)>,
#  <HDF5 group "/edges" (6 members)>,
#  <HDF5 group "/hct" (4 members)>,
#  <HDF5 group "/household_targets_acs" (4 members)>,
#  <HDF5 group "/household_validation_acs" (4 members)>,
#  <HDF5 group "/households" (8 members)>,
#  <HDF5 group "/job_county_targets_BEA" (4 members)>,
#  <HDF5 group "/job_county_validation_BEA" (4 members)>,
#  <HDF5 group "/job_flows" (6 members)>,
#  <HDF5 group "/job_targets" (4 members)>,
#  <HDF5 group "/job_validation" (4 members)>,
#  <HDF5 group "/jobs" (4 members)>,
#  <HDF5 group "/nodes" (6 members)>,
#  <HDF5 group "/persons" (8 members)>,
#  <HDF5 group "/price_targets" (4 members)>,
#  <HDF5 group "/price_validation" (4 members)>,
#  <HDF5 group "/residential_units" (8 members)>,
#  <HDF5 group "/taz_zone_geoms" (8 members)>,
#  <HDF5 group "/travel_data" (7 members)>,
#  <HDF5 group "/unit_county_targets_PEP" (4 members)>,
#  <HDF5 group "/unit_county_validation_PEP" (4 members)>,
#  <HDF5 group "/unit_targets" (4 members)>,
#  <HDF5 group "/unit_validation" (4 members)>,
#  <HDF5 group "/validation_ect" (6 members)>,
#  <HDF5 group "/validation_hct" (8 members)>,
#  <HDF5 group "/values" (6 members)>]

# %%
list(f['households'].keys())
# Out:
# ['axis0',
#  'axis1',
#  'block0_items',
#  'block0_values',
#  'block1_items',
#  'block1_values',
#  'block2_items',
#  'block2_values']

# %%
dset = f['/persons/axis0']

# %%
dset1 = f['/persons/block0_items']

# %%
dset2 = f['/persons/block0_values']

# %%
dset3 = f['/persons/block1_items']

# %%
dset4 = f['/persons/block1_values']

# %%
dset5 = f['/persons/block2_items']

# %%
dset6 = f['/persons/block2_values']

# %%
list(dset[:])
# Out:
# [b'earning',
#  b'worker',
#  b'student',
#  b'hispanic.1',
#  b'person_sex',
#  b'member_id',
#  b'sex',
#  b'household_id',
#  b'hours',
#  b'MAR',
#  b'person_age',
#  b'edu',
#  b'school_zone_id',
#  b'race_id',
#  b'race',
#  b'work_at_home',
#  b'age',
#  b'work_zone_id',
#  b'p_hispanic',
#  b'relate',
#  b'hispanic']

# %%
list(dset1[:])
# Out:
# [b'earning', b'hours', b'edu']

# %%
list(dset3[:])
# Out:
# [b'worker',
#  b'student',
#  b'hispanic.1',
#  b'member_id',
#  b'sex',
#  b'household_id',
#  b'MAR',
#  b'race_id',
#  b'work_at_home',
#  b'age',
#  b'relate',
#  b'hispanic']

# %%
list(dset5[:])
# Out:
# [b'person_sex',
#  b'person_age',
#  b'school_zone_id',
#  b'race',
#  b'work_zone_id',
#  b'p_hispanic']

# %%
dset['in_wheelchair']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\2/ipykernel_4100/1369025942.py in <module>
# ----> 1 dset['in_wheelchair']
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~\.conda\envs\BEAM\lib\site-packages\h5py\_hl\dataset.py in __getitem__(self, args, new_dtype)
#     758                 names = names[0]  # Read with simpler dtype of this field
#     759             args = tuple(x for x in args if not isinstance(x, str))
# --> 760             return self.fields(names, _prior_dtype=new_dtype)[args]
#     761
#     762         if new_dtype is None:
#
# ~\.conda\envs\BEAM\lib\site-packages\h5py\_hl\dataset.py in fields(self, names, _prior_dtype)
#     416         if _prior_dtype is None:
#     417             _prior_dtype = self.dtype
# --> 418         return FieldsWrapper(self, _prior_dtype, names)
#     419
#     420     if MPI:
#
# ~\.conda\envs\BEAM\lib\site-packages\h5py\_hl\dataset.py in __init__(self, dset, prior_dtype, names)
#     252             self.extract_field = names
#     253             names = [names]
# --> 254         self.read_dtype = readtime_dtype(prior_dtype, names)
#     255
#     256     def __getitem__(self, args):
#
# ~\.conda\envs\BEAM\lib\site-packages\h5py\_hl\dataset.py in readtime_dtype(basetype, names)
#     271     """Make a NumPy compound dtype with a subset of available fields"""
#     272     if basetype.names is None:  # Names provided, but not compound
# --> 273         raise ValueError("Field names only allowed for compound types")
#     274
#     275     for name in names:  # Check all names are legal
#
# ValueError: Field names only allowed for compound types
