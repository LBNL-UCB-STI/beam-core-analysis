# %%
import os
import os.path as op
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="darkgrid", color_codes=True)
sns.set(font_scale=1.35, style="ticks") #set styling preferences
import statsmodels.api as sm
from scipy import stats
import math
from math import pi
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from scipy.spatial.distance import cdist
from scipy.cluster.vq import kmeans2,vq, whiten
import sidetable
import geopandas as gpd
import h5py
import boto.s3
import glob
import boto3
from zipfile import ZipFile
import shutil

# %%
# Show all columns and rows
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
# %%time
s3 = boto3.client("s3")
key = "pilates-outputs/sfbay-rhprice2.0-rhfleet1.0-20220905/beam/year-2018-iteration-5/ITERS/it.0/0.events.csv.gz"  #the path should be updated
obj = s3.get_object(Bucket="beam-outputs", Key=key)
dtypes = {
    "time": "float32",
    "type": "category",
    "legMode": "category",
    "actType": "category", 
    "primaryFuelLevel": "float64",
    "legMode": "category",
    "chargingPointType":"category",
    "pricingModel":"category",
    "parkingType":"category",
    "mode":"category",
    "personalVehicleAvailable": "category",
    "person": "object",
    "driver": "object",
    "riders": "object",
    'primaryFuelType': "category",
    'secondaryFuelType': 'category',
    'currentTourMode': 'category',
    'currentActivity': 'category',
    'nextActivity': 'category'    
}
eventsSF = pd.read_csv(obj['Body'], compression = 'gzip', dtype = dtypes)
# Out:
# <timed exec>:25: DtypeWarning: Columns (17,22,23,37,41,42,46,48) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: total: 3min 24s
# Wall time: 3min 24s

# %%
key = "pilates-outputs/sfbay-rhprice2.0-rhfleet1.0-20220905/activitysim/year-2018-iteration-5/final_trips.csv.gz"  #the path should be updated
obj = s3.get_object(Bucket="beam-outputs", Key=key)
trips = pd.read_csv(obj['Body'], compression = 'gzip')

# %%
# %%time
baseline2018 = "https://beam-core-act.s3.amazonaws.com/deepDive/CleanData/SanFrancisco/Ridehail_Price/"
sfbase = pd.read_csv(baseline2018 + 'sf_2018_rh_price_2.csv')
# Out:
# <timed exec>:2: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: total: 1min 32s
# Wall time: 4min 17s

# %%
# %%time
comb_stacked_path = "https://beam-core-act.s3.amazonaws.com/deepDive/CleanData/SanFrancisco/Stacked/"
comb_stacked = pd.read_csv(comb_stacked_path + 'sf_2018_stacked_rh_price_fleetsz_2p25.csv')
# Out:
# CPU times: total: 4min 14s
# Wall time: 14min 40s

# %%
a = comb_stacked[comb_stacked['lever_position_fleetsize']==2.25]

# %%
comb_stacked[comb_stacked['mode_choice_planned_BEAM'] != comb_stacked['mode_choice_actual_BEAM']].head()
# Out:
#       IDMerged  tripIndex  scenario            lever  \
# 256        180    59241.0  ridehail  price_fleetsize
# 378        277    91173.0  ridehail  price_fleetsize
# 1068       592   194490.0  ridehail  price_fleetsize
# 1114       593   194758.0  ridehail  price_fleetsize
# 1142       595   195237.0  ridehail  price_fleetsize
#
#       lever_position_fleetsize  Realized_INEXUS  logsum_relative_to_baseline  \
# 256                       2.25        -0.703254                     0.831708
# 378                       2.25        -0.979787                     0.074262
# 1068                      2.25        -0.534311                    -0.014924
# 1114                      2.25      -999.755829                          NaN
# 1142                      2.25      -999.376956                     0.275551
#
#       door_to_door_time_relative_to_baseline    income        actPurpose  \
# 256                                    296.0   50700.0  Home_to_othdiscr
# 378                                    252.0  276000.0      work_to_Home
# 1068                                   144.0  166100.0  escort_to_escort
# 1114                                     NaN  166100.0  othmaint_to_Home
# 1142                                  3563.0  166100.0    escort_to_Home
#
#       lever_position_price mode_choice_actual_BEAM mandatoryCat  \
# 256                   0.05                     car          NaN
# 378                   0.05        ride_hail_pooled  from_M_to_H
# 1068                  1.50                    walk  from_N_to_N
# 1114                  0.05            walk_transit          NaN
# 1142                  0.05            walk_transit          NaN
#
#       logsum_trip_Potential_INEXUS  actEndTime actEndType  actStartTime  \
# 256                       0.244296     44168.0       Home       44688.0
# 378                      -0.003564     43808.0       work       45990.0
# 1068                     -0.104136     35352.0     escort       35938.0
# 1114                     -0.726249     63793.0   othmaint       68804.0
# 1142                      0.186858     27355.0     escort       32327.0
#
#      actStartType  cost_BEAM  distance_bike  distance_mode_choice  \
# 256      othdiscr   1.409505            0.0           7605.930000
# 378          Home  13.237752            0.0          40443.616000
# 1068       escort   0.000000            0.0           3146.438732
# 1114         Home   3.600000            0.0          59516.303676
# 1142         Home   5.350000            0.0          62022.603419
#
#       distance_privateCar  distance_ridehail  distance_transit  \
# 256              3733.654              0.000          0.000000
# 378                 0.000          31493.133          0.000000
# 1068                0.000              0.000          0.000000
# 1114                0.000              0.000      32309.831145
# 1142                0.000              0.000      34600.230045
#
#       distance_travelling  distance_walking  duration_in_privateCar  \
# 256           3872.276000           138.622                   181.0
# 378          31493.133000             0.000                     0.0
# 1068           762.957000           762.957                     0.0
# 1114         33425.250145          1115.419                     0.0
# 1142         35160.631045           560.401                     0.0
#
#       duration_in_ridehail  duration_in_transit  duration_on_bike  \
# 256                    0.0                  0.0               0.0
# 378                 1563.0                  0.0               0.0
# 1068                   0.0                  0.0               0.0
# 1114                   0.0               2757.0               0.0
# 1142                   0.0               2995.0               0.0
#
#       duration_travelling  duration_walking  emissionBiodiesel  \
# 256                 288.0             107.0                0.0
# 378                1563.0               0.0                0.0
# 1068                586.0             586.0                0.0
# 1114               3614.0             857.0                0.0
# 1142               3425.0             430.0                0.0
#
#       emissionDiesel  emissionElectricity  emissionFood  emissionGasoline  \
# 256         0.000000                  0.0           0.0          0.000389
# 378         0.000000                  0.0           0.0          0.004728
# 1068        0.000000                  0.0           0.0          0.000000
# 1114        0.004908                  0.0           0.0          0.000000
# 1142        0.006300                  0.0           0.0          0.000000
#
#       emission_marginal  fuelBiodiesel    fuelDiesel  fuelElectricity  \
# 256            0.000000            0.0  0.000000e+00              0.0
# 378            0.000409            0.0  0.000000e+00              0.0
# 1068           0.000000            0.0  0.000000e+00              0.0
# 1114           0.000000            0.0  5.799052e+07              0.0
# 1142           0.000000            0.0  7.443425e+07              0.0
#
#        fuelFood  fuelGasoline  fuel_marginal  fuel_not_Food  \
# 256    7346.966  5.257461e+06   5.264808e+06   5.257461e+06
# 378       0.000  6.396205e+07   6.396205e+07   6.396205e+07
# 1068  40436.721  0.000000e+00   4.043672e+04   0.000000e+00
# 1114  59117.207  0.000000e+00   5.911721e+04   5.799052e+07
# 1142  29701.253  0.000000e+00   2.970125e+04   7.443425e+07
#
#      mode_choice_planned_BEAM  \
# 256          ride_hail_pooled
# 378                 ride_hail
# 1068             walk_transit
# 1114         ride_hail_pooled
# 1142         ride_hail_pooled
#
#                                           numPassengers          parkingType  \
# 256                             1.0, 1.0, 0.0, 0.0, 1.0  Residential, Public
# 378              1.0, 1.0, 1.0, 2.0, 3.0, 2.0, 1.0, 1.0                  NaN
# 1068                                 1.0, 1.0, 1.0, 1.0                  NaN
# 1114  1.0, 1.0, 10.0, 8.0, 8.0, 7.0, 8.0, 11.0, 20.0...                  NaN
# 1142  1.0, 1.0, 5.0, 4.0, 6.0, 6.0, 8.0, 8.0, 9.0, 1...                  NaN
#
#                                                  reason  replanning_status  \
# 256                ResourceUnavailable RIDE_HAIL_POOLED                  1
# 378                       ResourceUnavailable RIDE_HAIL                  1
# 1068  ResourceCapacityExhausted WALK_TRANSIT, Resour...                  3
# 1114               ResourceUnavailable RIDE_HAIL_POOLED                  1
# 1142               ResourceUnavailable RIDE_HAIL_POOLED                  1
#
#       ride_hail_pooled  transit_bus  transit_cable_car  transit_rail  \
# 256                  1            0                  0             0
# 378                  3            0                  0             0
# 1068                 0            0                  0             0
# 1114                 1           11                  0             0
# 1142                 1           12                  0             0
#
#       transit_subway  transit_tram  \
# 256                0             0
# 378                0             0
# 1068               0             0
# 1114              10             0
# 1142              10             0
#
#                                              vehicleIds  year  \
# 256                                    body-180, 698322  2018
# 378           body-277, rideHailVehicle-2226417@default  2018
# 1068                                           body-592  2018
# 1114                     AC:5594232, BA:57R11, body-593  2018
# 1142  AC:5594135, body-595, BA:12DC11, AC:5577812, B...  2018
#
#       duration_door_to_door  waitTime mode_choice_actual_5  \
# 256                   520.0     232.0                  car
# 378                  2182.0     619.0            ride_hail
# 1068                  586.0       0.0                 walk
# 1114                 5011.0    1397.0              transit
# 1142                 4972.0    1547.0              transit
#
#      mode_choice_actual_6  trip_id  person_id  household_id  tour_id  \
# 256                   car    59241        180        779945     7405
# 378             ride_hail    91173        277        745372    11396
# 1068                 walk   194490        592        159724    24311
# 1114              transit   194758        593        159724    24344
# 1142              transit   195237        595        159724    24404
#
#      primary_purpose_x  trip_count   purpose trip_mode_AS_trips tour_type  \
# 256           othdiscr           1  othdiscr         TNC_SINGLE  othdiscr
# 378               work           1      Home         TNC_SINGLE      work
# 1068              work           3    escort           WALK_LOC      work
# 1114              univ           2      Home         TNC_SHARED    school
# 1142            escort           1      Home         TNC_SINGLE    escort
#
#       tour_category  start   end  duration tour_mode_AS_tours   earning  \
# 256   non_mandatory   12.0  17.0       5.0     DRIVEALONEFREE    4700.0
# 378       mandatory    9.0  12.0       3.0         TNC_SINGLE  125000.0
# 1068      mandatory    8.0  17.0       9.0           WALK_HVY   80000.0
# 1114      mandatory   14.0  17.0       3.0         TNC_SINGLE       0.0
# 1142  non_mandatory    7.0   7.0       0.0         TNC_SHARED   82000.0
#
#      person_sex  sex   edu   race  work_at_home  age  value_of_time  \
# 256        male    1  16.0  white             0   35       1.129980
# 378      female    2  22.0  white             0   54      10.780311
# 1068     female    2  21.0  white             0   54       6.999438
# 1114     female    2  16.0  other             0   18       6.999438
# 1142       male    1  22.0  other             0   60       6.999438
#
#       free_parking_at_work  num_mand  lcm_county_id    tenure_mover  \
# 256                  False         0           6013  own not recent
# 378                  False         2           6013  own not recent
# 1068                 False         1           6001  own not recent
# 1114                 False         1           6001  own not recent
# 1142                 False         1           6001  own not recent
#
#            hh_size  tenure      hh_cars  hh_income  hhsize  \
# 256          three       1  two or more  gt30-lt60       3
# 378          three       1  two or more      gt150       3
# 1068  four or more       1  two or more      gt150       4
# 1114  four or more       1  two or more      gt150       4
# 1142  four or more       1  two or more      gt150       4
#
#       income_in_thousands  median_value_of_time  hh_value_of_time  \
# 256                  50.7                  8.81          1.129980
# 378                 276.0                 12.86         10.780311
# 1068                166.1                 12.86          6.999438
# 1114                166.1                 12.86          6.999438
# 1142                166.1                 12.86          6.999438
#
#       home_is_urban  home_is_rural  auto_ownership  DRIVEALONEFREE  \
# 256           False          False               3       -0.703254
# 378           False          False               2     -999.746072
# 1068          False          False               4     -999.493889
# 1114          False          False               4    -1000.166593
# 1142          False          False               4    -1000.339117
#
#       DRIVEALONEPAY  SHARED2FREE  SHARED2PAY  SHARED3FREE  SHARED3PAY  \
# 256       -0.731506  -999.703254 -999.719398  -999.703254 -999.714555
# 378     -999.746672    -6.848226   -6.848569    -7.737887   -7.738127
# 1068    -999.493960    -3.951773   -3.951814    -4.337987   -4.338015
# 1114   -1000.217576    -5.487328   -5.516461    -6.065542   -6.085935
# 1142   -1000.346260    -6.987417   -6.991499    -8.339117   -8.341974
#
#            WALK         BIKE     WALK_LOC     WALK_LRF     WALK_EXP  \
# 256  -12.074241 -1000.624266 -1000.702354 -1998.370594 -1998.370594
# 378  -49.075553 -1015.153757  -999.989700    -2.840063  -999.630640
# 1068  -0.534311  -999.726691    -1.308513  -999.839814 -1000.135752
# 1114 -87.302831 -1028.637299  -999.755829  -999.755829 -1000.026829
# 1142 -97.720468 -1033.335147  -999.376956  -999.376956  -999.376956
#
#          WALK_HVY     WALK_COM    DRIVE_LOC    DRIVE_LRF    DRIVE_EXP  \
# 256  -1998.370594 -1998.370594 -1000.113785 -2002.609909 -1998.417466
# 378   -999.630640  -999.630640 -1998.337600 -1998.337600 -1998.337600
# 1068  -999.206552  -999.159152 -1998.267312 -1998.267312 -1998.267312
# 1114  -999.958858  -999.755829 -1998.394857 -1998.394857 -1998.394857
# 1142  -999.919817  -999.376956 -1998.423828 -1998.423828 -1998.423828
#
#         DRIVE_HVY    DRIVE_COM       TAXI  TNC_SINGLE  TNC_SHARED  \
# 256  -2002.265860 -1998.417466 -11.046186   -0.487343   -0.807432
# 378  -1998.337600 -1998.337600  -6.965391   -0.095197   -0.979787
# 1068 -1998.267312 -1998.267312  -4.383231   -5.906031   -5.268210
# 1114 -1998.394857 -1998.394857 -11.264015   -0.903740   -1.100933
# 1142 -1998.423828 -1998.423828 -14.777778    0.151407   -0.676097
#
#      income_quartiles  MedianQuartiles  alpha  socialCarbonCost  \
# 256              2ndQ          70000.0    0.1          0.000000
# 378              4thQ         219000.0    0.1          0.020856
# 1068             4thQ         219000.0    0.1          0.000000
# 1114             4thQ         219000.0    0.1          0.000000
# 1142             4thQ         219000.0    0.1          0.000000
#
#       Social_INEXUS  Potential_INEXUS_in_dollar  Realized_INEXUS_in_dollar
# 256       -7.032543                    2.442955                  -7.032543
# 378       -9.818727                   -0.035642                  -9.797871
# 1068      -5.343110                   -1.041363                  -5.343110
# 1114   -9997.558293                   -7.262487               -9997.558293
# 1142   -9993.769561                    1.868580               -9993.769561

# %%
#sfbase[(sfbase['mode_choice_actual_BEAM'] == 'walk')&(sfbase['Realized_INEXUS_in_dollar'] <-20000)].head()

# %%
wTime = comb_stacked[['IDMerged', 'tripIndex','end','start','duration', 'household_id','actPurpose',
               'waitTime', 'duration_travelling', 'duration_door_to_door','mode_choice_actual_BEAM', 'lever_position_fleetsize']]

# %%
wTime[wTime['IDMerged']== 1583162]
# Out:
#          IDMerged    tripIndex   end  start  duration  household_id  \
# 2666778   1583162  519277361.0  17.0   16.0       1.0       1903246
# 2666779   1583162  519277361.0  17.0   16.0       1.0       1903246
# 2666780   1583162  519277361.0  17.0   16.0       1.0       1903246
# 2666781   1583162  519277361.0  17.0   16.0       1.0       1903246
# 2666782   1583162  519277361.0  17.0   16.0       1.0       1903246
# 2666783   1583162  519277365.0  17.0   16.0       1.0       1903246
# 2666784   1583162  519277365.0  17.0   16.0       1.0       1903246
# 2666785   1583162  519277365.0  17.0   16.0       1.0       1903246
# 2666786   1583162  519277365.0  17.0   16.0       1.0       1903246
# 2666787   1583162  519277365.0  17.0   16.0       1.0       1903246
#
#                actPurpose  waitTime  duration_travelling  \
# 2666778  Home_to_othmaint     460.0                166.0
# 2666779  Home_to_othmaint     245.0                228.0
# 2666780  Home_to_othmaint      64.0                218.0
# 2666781  Home_to_othmaint     261.0                306.0
# 2666782  Home_to_othmaint     971.0                219.0
# 2666783  othmaint_to_Home     442.0                122.0
# 2666784  othmaint_to_Home     570.0                 51.0
# 2666785  othmaint_to_Home     334.0                151.0
# 2666786  othmaint_to_Home     826.0                237.0
# 2666787  othmaint_to_Home     273.0                313.0
#
#          duration_door_to_door mode_choice_actual_BEAM  \
# 2666778                  626.0        ride_hail_pooled
# 2666779                  473.0        ride_hail_pooled
# 2666780                  282.0        ride_hail_pooled
# 2666781                  567.0        ride_hail_pooled
# 2666782                 1190.0        ride_hail_pooled
# 2666783                  564.0        ride_hail_pooled
# 2666784                  621.0        ride_hail_pooled
# 2666785                  485.0        ride_hail_pooled
# 2666786                 1063.0        ride_hail_pooled
# 2666787                  586.0        ride_hail_pooled
#
#          lever_position_fleetsize
# 2666778                      1.00
# 2666779                      2.25
# 2666780                      2.25
# 2666781                      2.25
# 2666782                      2.25
# 2666783                      1.00
# 2666784                      2.25
# 2666785                      2.25
# 2666786                      2.25
# 2666787                      2.25

# %%
rh_wTime = wTime[(wTime['mode_choice_actual_BEAM'] == 'ride_hail')|(wTime['mode_choice_actual_BEAM'] == 'ride_hail_pooled')&
                wTime['lever_position_fleetsize']==2.25]

# %%
rh_wTime
# Out:
# Empty DataFrame
# Columns: [IDMerged, tripIndex, end, start, duration, household_id, actPurpose, waitTime, duration_travelling, duration_door_to_door, mode_choice_actual_BEAM, lever_position_fleetsize]
# Index: []

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
plt.hist(rh_wTime['waitTime'], bins=60)
ax.set_xlabel('Wait Time of Ridehail and Ridehail Pooled Trips')
fig.tight_layout()
