# %%
import pandas as pd
import numpy as np
from dask import dataframe as dd

# %%
#Checking the plans file
loc_2018 =  "https://beam-outputs.s3.amazonaws.com/pilates-outputs/sfbay-2018-base-20220306/beam/year-2018-iteration-5/ITERS/it.0/"

# %%
plansSF = pd.read_csv(loc_2018 + '0.plans.csv.gz', compression = 'gzip')

# %%
plansSF[plansSF['personId']]
# Out:
#        tripId  personId  planIndex   planScore  planSelected planElementType  \
# 0         NaN     57953          0  123.128559          True        activity
# 1  19008833.0     57953          0  123.128559          True             leg
# 2         NaN     57953          0  123.128559          True        activity
# 3  19008837.0     57953          0  123.128559          True             leg
# 4         NaN     57953          0  123.128559          True        activity
#
#    planElementIndex activityType  activityLocationX  activityLocationY  \
# 0                 0         Home      523673.936124       4.256004e+06
# 1                 1          NaN                NaN                NaN
# 2                 2       school      522459.947905       4.256796e+06
# 3                 3          NaN                NaN                NaN
# 4                 4         Home      523673.936124       4.256004e+06
#
#    activityEndTime   legMode  legDepartureTime  legTravelTime  legRouteType  \
# 0          30434.4       NaN               NaN            NaN           NaN
# 1              NaN  car_hov3              -inf           -inf           NaN
# 2          59371.2       NaN               NaN            NaN           NaN
# 3              NaN  car_hov3              -inf           -inf           NaN
# 4             -inf       NaN               NaN            NaN           NaN
#
#    legRouteStartLink  legRouteEndLink  legRouteTravelTime  legRouteDistance  \
# 0                NaN              NaN                 NaN               NaN
# 1                NaN              NaN                 NaN               NaN
# 2                NaN              NaN                 NaN               NaN
# 3                NaN              NaN                 NaN               NaN
# 4                NaN              NaN                 NaN               NaN
#
#    legRouteLinks
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# #### Comparing old and new activity sim files

# %%
#Checking the activity sim plans file
locOld = "https://beam-outputs.s3.amazonaws.com/pilates-outputs/sfbay-2010-central-20210114/activitysim/"
#plansSFactivityOld = pd.read_csv(locOld + 'final_plans.csv')
locNew = "https://beam-outputs.s3.amazonaws.com/pilates-outputs/sfbay-2010-base-20200206/activitysim/" 
#plansSFactivityNew = pd.read_csv(locNew + 'final_plans.csv')
#plansSFactivity[(plansSFactivity["person_id"]==4373312)]

# %%
#Checking the activity sim person file
personsSFactivityOld = pd.read_csv(locOld + 'final_persons.csv')
personsSFactivityNew = pd.read_csv(locNew + 'final_persons.csv')

# %%
personsSFactivityOld.sort_values(['person_id']).head()
# Out:
#         person_id  age  earning   edu  hispanic  hours  PNUM  race_id  relate  \
# 229122          4   68      0.0  22.0         0    0.0     1        2       0
# 229123          8   74      0.0  18.0         0    0.0     2        1       1
# 270046        113   33  60000.0  24.0         0   30.0     2        1       1
# 270047        114    4      0.0   2.0         0    0.0     3        1       2
# 270048        115    0      0.0   0.0         0    0.0     4        1       2
#
#         sex  student  work_at_home  worker  household_id    person_age  \
# 229122    2        0             0       0           865      above 60
# 229123    1        0             0       0           865      above 60
# 270046    2        0             0       1          1114      20 to 35
# 270047    1        1             0       0          1114  19 and under
# 270048    1        0             0       0          1114  19 and under
#
#        person_sex   race  hispanic.1 p_hispanic  MAR   TAZ  ptype  pemploy  \
# 229122     female  black           0         no    1  1005      5        3
# 229123       male  white           0         no    1  1005      5        3
# 270046     female  white           0         no    1  1005      1        1
# 270047       male  white           0         no    5  1005      8        4
# 270048       male  white           0         no    5  1005      8        4
#
#         pstudent      home_x     home_y  age_16_to_19  age_16_p  adult   male  \
# 229122         3 -122.227937  37.854097         False      True   True  False
# 229123         3 -122.227937  37.854097         False      True   True   True
# 270046         3 -122.228693  37.859558         False      True   True  False
# 270047         1 -122.228693  37.859558         False     False  False   True
# 270048         1 -122.228693  37.859558         False     False  False   True
#
#         female  has_non_worker  has_retiree  has_preschool_kid  \
# 229122    True           False         True              False
# 229123   False           False         True              False
# 270046    True           False        False               True
# 270047   False           False        False               True
# 270048   False           False        False               True
#
#         has_driving_kid  has_school_kid  has_full_time  has_part_time  \
# 229122            False           False          False          False
# 229123            False           False          False          False
# 270046            False           False           True          False
# 270047            False           False           True          False
# 270048            False           False           True          False
#
#         has_university  student_is_employed  nonstudent_to_school  is_student  \
# 229122           False                False                 False       False
# 229123           False                False                 False       False
# 270046           False                False                 False       False
# 270047           False                False                 False        True
# 270048           False                False                 False        True
#
#         is_gradeschool  is_highschool  is_university  school_segment  \
# 229122           False          False          False               0
# 229123           False          False          False               0
# 270046           False          False          False               0
# 270047            True          False          False               1
# 270048            True          False          False               1
#
#         is_worker  home_taz  value_of_time  school_taz  distance_to_school  \
# 229122      False      1005       2.818730          -1                 NaN
# 229123      False      1005       2.818730          -1                 NaN
# 270046       True      1005      33.268101          -1                 NaN
# 270047      False      1005      22.189823        1154            1.651912
# 270048      False      1005      22.189823        1154            1.651912
#
#         roundtrip_auto_time_to_school  workplace_taz  \
# 229122                       0.000000             -1
# 229123                       0.000000             -1
# 270046                       0.000000            969
# 270047                      41.621815             -1
# 270048                      41.621815             -1
#
#         workplace_location_logsum  distance_to_work  workplace_in_cbd  \
# 229122                        NaN               NaN             False
# 229123                        NaN               NaN             False
# 270046                  13.511774          7.761097              True
# 270047                        NaN               NaN             False
# 270048                        NaN               NaN             False
#
#         work_taz_area_type  roundtrip_auto_time_to_work  work_auto_savings  \
# 229122                 NaN                     0.000000             0.0000
# 229123                 NaN                     0.000000             0.0000
# 270046                 0.0                    26.564331           327.6267
# 270047                 NaN                     0.000000             0.0000
# 270048                 NaN                     0.000000             0.0000
#
#         work_auto_savings_ratio  free_parking_at_work cdap_activity  \
# 229122                      0.0                 False             N
# 229123                      0.0                 False             N
# 270046                      1.0                 False             M
# 270047                      0.0                 False             M
# 270048                      0.0                 False             M
#
#         travel_active  under16_not_at_school  has_preschool_kid_at_home  \
# 229122           True                  False                      False
# 229123           True                  False                      False
# 270046           True                  False                      False
# 270047           True                  False                      False
# 270048           True                  False                      False
#
#         has_school_kid_at_home mandatory_tour_frequency  \
# 229122                   False                      NaN
# 229123                   False                      NaN
# 270046                   False                    work1
# 270047                   False                  school1
# 270048                   False                  school1
#
#         work_and_school_and_worker  work_and_school_and_student  num_mand  \
# 229122                       False                        False         0
# 229123                       False                        False         0
# 270046                       False                        False         1
# 270047                       False                        False         1
# 270048                       False                        False         1
#
#         num_work_tours  num_joint_tours  non_mandatory_tour_frequency  \
# 229122               0                0                             1
# 229123               0                0                            16
# 270046               1                0                             0
# 270047               0                0                             0
# 270048               0                0                             0
#
#         num_non_mand  num_escort_tours  num_eatout_tours  num_shop_tours  \
# 229122             1                 0                 0               0
# 229123             1                 0                 0               1
# 270046             0                 0                 0               0
# 270047             0                 0                 0               0
# 270048             0                 0                 0               0
#
#         num_maint_tours  num_discr_tours  num_social_tours  \
# 229122                0                1                 0
# 229123                0                0                 0
# 270046                0                0                 0
# 270047                0                0                 0
# 270048                0                0                 0
#
#         num_non_escort_tours
# 229122                     1
# 229123                     1
# 270046                     0
# 270047                     0
# 270048                     0

# %%
personsSFactivityNew.sort_values(['person_id']).head()
# Out:
#         person_id  Unnamed: 0  work_at_home  MAR   edu  PNUM  age  worker  \
# 0               0           0             0    5  22.0     1   61       1
# 151146          1         129             0    1  16.0     2   60       0
# 151147          2         130             0    1  16.0     1   60       0
# 75813           3         147             0    1  20.0     1   51       1
# 75814           4         148             0    5  16.0     3   25       0
#
#         hours  race_id   earning person_sex  sex person_age p_hispanic  \
# 0        40.0        6  116000.0     female    2   above 60         no
# 151146    0.0        1       0.0       male    1   35 to 60         no
# 151147    0.0        1       0.0     female    2   35 to 60         no
# 75813    60.0        1   91000.0     female    2   35 to 60         no
# 75814    15.0        1     500.0     female    2   20 to 35         no
#
#         household_id  student  school_zone_id  hispanic  hispanic.1   race  \
# 0                  0        0              -1         0           0  asian
# 151146       1681635        0              -1         0           0  white
# 151147       1681635        0              -1         0           0  white
# 75813         840133        0              -1         0           0  white
# 75814         840133        0              -1         0           0  white
#
#         relate  work_zone_id   TAZ  ptype  pemploy  pstudent      home_x  \
# 0            0          1440  1005      1        1         3 -122.237696
# 151146       1            -1   542      4        3         3 -121.916851
# 151147       0            -1   542      4        3         3 -121.916851
# 75813        0          1186  1178      1        1         3 -121.724207
# 75814        2            -1  1178      4        3         3 -121.724207
#
#            home_y  age_16_to_19  age_16_p  adult   male  female  \
# 0       37.861152         False      True   True  False    True
# 151146  37.340697         False      True   True   True   False
# 151147  37.340697         False      True   True  False    True
# 75813   37.922609         False      True   True  False    True
# 75814   37.922609         False      True   True  False    True
#
#         has_non_worker  has_retiree  has_preschool_kid  has_driving_kid  \
# 0                False        False              False            False
# 151146            True        False              False            False
# 151147            True        False              False            False
# 75813             True        False              False            False
# 75814            False        False              False            False
#
#         has_school_kid  has_full_time  has_part_time  has_university  \
# 0                False          False          False           False
# 151146           False          False          False           False
# 151147           False          False          False           False
# 75813            False           True          False            True
# 75814            False           True          False            True
#
#         student_is_employed  nonstudent_to_school  is_student  is_gradeschool  \
# 0                     False                 False       False           False
# 151146                False                 False       False           False
# 151147                False                 False       False           False
# 75813                 False                 False       False           False
# 75814                 False                 False       False           False
#
#         is_highschool  is_university  school_segment  is_worker  home_taz  \
# 0               False          False               0       True      1005
# 151146          False          False               0      False       542
# 151147          False          False               0      False       542
# 75813           False          False               0       True      1178
# 75814           False          False               0      False      1178
#
#         value_of_time  school_taz  distance_to_school  \
# 0            6.650505          -1                 NaN
# 151146       1.000000          -1                 NaN
# 151147       1.000000          -1                 NaN
# 75813        9.762132          -1                 NaN
# 75814        9.762132          -1                 NaN
#
#         roundtrip_auto_time_to_school  workplace_taz  \
# 0                                 0.0           1440
# 151146                            0.0             -1
# 151147                            0.0             -1
# 75813                             0.0            549
# 75814                             0.0             -1
#
#         workplace_location_logsum  distance_to_work  workplace_in_cbd  \
# 0                       13.856360         22.011642             False
# 151146                        NaN               NaN             False
# 151147                        NaN               NaN             False
# 75813                   11.653988         52.777060             False
# 75814                         NaN               NaN             False
#
#         work_taz_area_type  roundtrip_auto_time_to_work  work_auto_savings  \
# 0                      4.0                    33.384956           847.0807
# 151146                 NaN                     0.000000             0.0000
# 151147                 NaN                     0.000000             0.0000
# 75813                  2.0                   135.707260          1975.3752
# 75814                  NaN                     0.000000             0.0000
#
#         work_auto_savings_ratio  free_parking_at_work cdap_activity  \
# 0                           1.0                 False             M
# 151146                      0.0                 False             N
# 151147                      0.0                 False             N
# 75813                       1.0                 False             M
# 75814                       0.0                 False             N
#
#         travel_active  under16_not_at_school  has_preschool_kid_at_home  \
# 0                True                  False                      False
# 151146           True                  False                      False
# 151147           True                  False                      False
# 75813            True                  False                      False
# 75814            True                  False                      False
#
#         has_school_kid_at_home mandatory_tour_frequency  \
# 0                        False                    work1
# 151146                   False                      NaN
# 151147                   False                      NaN
# 75813                    False                    work2
# 75814                    False                      NaN
#
#         work_and_school_and_worker  work_and_school_and_student  num_mand  \
# 0                            False                        False         1
# 151146                       False                        False         0
# 151147                       False                        False         0
# 75813                        False                        False         2
# 75814                        False                        False         0
#
#         num_work_tours  num_joint_tours  non_mandatory_tour_frequency  \
# 0                    1                0                             8
# 151146               0                0                            16
# 151147               0                0                             1
# 75813                2                0                             0
# 75814                0                0                             1
#
#         num_non_mand  num_escort_tours  num_eatout_tours  num_shop_tours  \
# 0                  1                 0                 0               0
# 151146             1                 0                 0               1
# 151147             1                 0                 0               0
# 75813              0                 0                 0               0
# 75814              1                 0                 0               0
#
#         num_maint_tours  num_discr_tours  num_social_tours  \
# 0                     1                0                 0
# 151146                0                0                 0
# 151147                0                1                 0
# 75813                 0                0                 0
# 75814                 0                1                 0
#
#         num_non_escort_tours
# 0                          1
# 151146                     1
# 151147                     1
# 75813                      0
# 75814                      1

# %%
personsSFactivityNew[personsSFactivityNew['person_id'] == 113]
# Out:
#          person_id  Unnamed: 0  work_at_home  MAR   edu  PNUM  age  worker  \
# 3320697        113       10694             0    5  21.0     5   21       1
#
#          hours  race_id  earning person_sex  sex person_age p_hispanic  \
# 3320697   30.0        6    500.0       male    1   20 to 35         no
#
#          household_id  student  school_zone_id  hispanic  hispanic.1   race  \
# 3320697       2376235        0              -1         0           0  asian
#
#          relate  work_zone_id   TAZ  ptype  pemploy  pstudent      home_x  \
# 3320697       2          1146  1220      1        1         3 -122.222567
#
#             home_y  age_16_to_19  age_16_p  adult  male  female  \
# 3320697  38.073618         False      True   True  True   False
#
#          has_non_worker  has_retiree  has_preschool_kid  has_driving_kid  \
# 3320697           False        False              False            False
#
#          has_school_kid  has_full_time  has_part_time  has_university  \
# 3320697           False           True          False            True
#
#          student_is_employed  nonstudent_to_school  is_student  \
# 3320697                False                 False       False
#
#          is_gradeschool  is_highschool  is_university  school_segment  \
# 3320697           False          False          False               0
#
#          is_worker  home_taz  value_of_time  school_taz  distance_to_school  \
# 3320697       True      1220       1.755522          -1                 NaN
#
#          roundtrip_auto_time_to_school  workplace_taz  \
# 3320697                            0.0           1027
#
#          workplace_location_logsum  distance_to_work  workplace_in_cbd  \
# 3320697                  11.587363         17.310123             False
#
#          work_taz_area_type  roundtrip_auto_time_to_work  work_auto_savings  \
# 3320697                 2.0                       71.335          648.40594
#
#          work_auto_savings_ratio  free_parking_at_work cdap_activity  \
# 3320697                      1.0                 False             M
#
#          travel_active  under16_not_at_school  has_preschool_kid_at_home  \
# 3320697           True                  False                      False
#
#          has_school_kid_at_home mandatory_tour_frequency  \
# 3320697                   False                    work1
#
#          work_and_school_and_worker  work_and_school_and_student  num_mand  \
# 3320697                       False                        False         1
#
#          num_work_tours  num_joint_tours  non_mandatory_tour_frequency  \
# 3320697               1                0                             0
#
#          num_non_mand  num_escort_tours  num_eatout_tours  num_shop_tours  \
# 3320697             0                 0                 0               0
#
#          num_maint_tours  num_discr_tours  num_social_tours  \
# 3320697                0                0                 0
#
#          num_non_escort_tours
# 3320697                     0

# %%
#plansSFactivityOld.sort_values(['person_id']).head()

# %%
#difference_persons = np.where(plansSFactivityOld['person_id'] != plansSFactivityNew['person_id'])
#ne = (plansSFactivityOld != plansSFactivityNew).any(1)
plansSFactivityOld['person_id'].isin(plansSFactivityNew['person_id']).value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\2/ipykernel_6744/2459328773.py in <module>
#       1 #difference_persons = np.where(plansSFactivityOld['person_id'] != plansSFactivityNew['person_id'])
#       2 #ne = (plansSFactivityOld != plansSFactivityNew).any(1)
# ----> 3 plansSFactivityOld['person_id'].isin(plansSFactivityNew['person_id']).value_counts()
#
# NameError: name 'plansSFactivityOld' is not defined

# %%
plansSFactivityNew[(plansSFactivityNew["person_id"]==8)]
# Out:
#     trip_id  person_id  number_of_participants   trip_mode  PlanElementIndex  \
# 68      NaN        8.0                     NaN         NaN                 1
# 69   3073.0        8.0                     2.0  SHARED2PAY                 2
# 70      NaN        8.0                     NaN         NaN                 3
# 71   3077.0        8.0                     2.0  SHARED3PAY                 4
# 72      NaN        8.0                     NaN         NaN                 5
#
#    ActivityElement ActivityType           x          y  departure_time
# 68        activity         Home -122.181090  37.477232          12.389
# 69             leg          NaN         NaN        NaN             NaN
# 70        activity     othdiscr -121.901749  37.267610          15.003
# 71             leg          NaN         NaN        NaN             NaN
# 72        activity         Home -122.181090  37.477232             NaN

# %%
plansSFactivityOld[(plansSFactivityOld["person_id"]==8)]
# Out:
#     trip_id  person_id  number_of_participants       trip_mode  \
# 7       NaN        8.0                     NaN             NaN
# 11      NaN        8.0                     NaN             NaN
# 8    2889.0        8.0                     1.0  DRIVEALONEFREE
# 10   2893.0        8.0                     1.0  DRIVEALONEFREE
# 9       NaN        8.0                     NaN             NaN
#
#     PlanElementIndex ActivityElement ActivityType           x          y  \
# 7                  1        activity         Home -122.227937  37.854097
# 11                 5        activity         Home -122.227937  37.854097
# 8                  2             leg          NaN         NaN        NaN
# 10                 4             leg          NaN         NaN        NaN
# 9                  3        activity     shopping -122.254654  37.865014
#
#     departure_time
# 7           16.038
# 11             NaN
# 8              NaN
# 10             NaN
# 9           16.989

# %% [markdown]
# ### Reading the files

# %%
loc = "https://beam-outputs.s3.amazonaws.com/pilates-outputs/sfbay-2010-base-20200206/beam/sfbay-pilates-base__2022-02-06_07-26-58_kwy/ITERS/it.0/" 
#"https://beam-outputs.s3.amazonaws.com/pilates-outputs/sfbay-2010-central-20210114/beam/sfbay-pilates-base__2022-01-14_17-54-11_cda/ITERS/it.0/"

# %%
#BEAM plans file
#plansSF = pd.read_csv(loc + '0.plans.csv.gz', compression='gzip')

# %%
#eventsSF = pd.read_csv(loc + '0.events.csv.gz', compression = 'gzip')
#usecols=["vehicle", 'time', "type", 'person', 'driver', "riders", 'actType', 'legMode', 'primaryFuelType', 'secondaryFuelType', 'vehicleType', 'netCost', 'currentTourMode', 'reason'])

# %%
# %%time

dtypes = {
    "person": "object",
    "time": "float32",
    "type": "category",
    "currentTourMode": "category",
    "vehicleType": "object",
    "driver": "object",
    "vehicle": "object",
    "legMode": "category",
    "actType": "category", 
    "reason": "category",
    "primaryFuelLevel": "float64",
    "legMode": "category",
    "riders": "object",
    "primaryFuel": "category",
    "chargingPointType":"category",
    "pricingModel":"category",
    "parkingType":"category",
    "mode":"category",
    "personalVehicleAvailable": "category"
}

# Use list comprehension to remove the unwanted column in **usecol**
eventsSF = pd.read_csv(loc + '0.events.csv.gz', compression = 'gzip', dtype = dtypes)
# Out:
# C:\Users\nazanin\.conda\envs\geo_env\lib\site-packages\IPython\core\magics\execution.py:1324: DtypeWarning: Columns (9,32,44,46,47,49,52,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code, glob, local_ns)
# Wall time: 3min 6s

# %%
#List unique values in a Pandas dataframe
#pd.Series({c: eventsSF['type'].unique() for c in eventsSF['type']})

# %%
#Reading the events file in chunks
#df_chunk = pd.read_csv(loc + '0.events.csv.gz', compression = 'gzip', chunksize=1000000)
#chunk_list = []  # append each chunk df here 

# Each chunk is in df format
#for chunk in df_chunk:  
    # perform data filtering 
    #chunk_filter = chunk.sort_values(['time'])
    
    # Once the data filtering is done, append the chunk to list
    #chunk_list.append(chunk_filter)
    
# concat the list into dataframe 
#df_concat = pd.concat(chunk_list)

# %%
#Show all columns and rows
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
eventsSF.dtypes
# Out:
# person                        object
# link                         float64
# facility                     float64
# actType                     category
# time                         float32
# type                        category
# legMode                     category
# secondaryFuelLevel           float64
# price                        float64
# parkingTaz                    object
# chargingPointType           category
# pricingModel                category
# parkingType                 category
# locationY                    float64
# locationX                    float64
# primaryFuelLevel             float64
# vehicle                       object
# cost                         float64
# driver                        object
# departTime                   float64
# startX                       float64
# startY                       float64
# endX                         float64
# endY                         float64
# arrivalTime                  float64
# departureTime                float64
# currentTourMode             category
# mode                        category
# incentive                    float64
# tollCost                     float64
# netCost                      float64
# expectedMaximumUtility       float64
# availableAlternatives         object
# location                     float64
# personalVehicleAvailable    category
# length                       float64
# tourIndex                    float64
# reason                      category
# riders                        object
# toStopIndex                  float64
# fromStopIndex                float64
# seatingCapacity              float64
# tollPaid                     float64
# capacity                     float64
# linkTravelTime                object
# secondaryFuel                float64
# secondaryFuelType             object
# primaryFuelType               object
# vehicleType                   object
# links                         object
# numPassengers                float64
# primaryFuel                 category
# shiftStatus                   object
# parkingZoneId                 object
# fuel                         float64
# duration                     float64
# score                        float64
# dtype: object

# %%
#eventsSF.memory_usage(deep=True)  # memory usage in bytes

# %%
#Change type of a column
#eventsSF2["type"] = eventsSF2["type"].astype("category")

# %%
#Drop unused columns
#to_drop = ['facility', 
           #'shiftStatus', 
           #'startY', 
           #'endX', 
           #'endY', 'incentive',
           #'price',
           #'expectedMaximumUtility',
           #'links',
           #'link',
           #'pricingModel',
           #'parkingZoneId',
           #'startX']

#eventsSF.drop(to_drop, inplace=True, axis=1)

# %%
#counting the number of negarive values in a column
eventsSF.primaryFuelLevel[eventsSF.primaryFuelLevel<0].count()
# Out:
# 1084

# %%
#counting the number of values in a column
#eventsSF.actType[eventsSF.actType == "work"].count()

# %%
#Rename mode column
eventsSF.rename(columns={"mode":"modeType"}, inplace=True)

# %%
#Replace "Work" with "work" in actType column
eventsSF["actType"].replace({"Work": "work"}, inplace=True)

# %% [markdown]
# #### Matching person with driver and rider

# %%
#eventsSF_chunk = eventsSF[1000:1000000]

# %%
eventsSF['UniqueID'] = eventsSF['person']

# %%
eventsSF['personID'] = np.where(eventsSF['person'].isin(eventsSF['driver'])
                     , eventsSF['person'], np.nan)

# %%
eventsSF['driverID'] = np.where(eventsSF['driver'].isin(eventsSF['person'])
                     , eventsSF['driver'], np.nan)

# %%
eventsSF['IDMerged'] = eventsSF['personID'].combine_first(eventsSF['driverID'])

# %%
eventsSF['IDMerged'] = eventsSF['UniqueID'].combine_first(eventsSF['IDMerged'])

# %%
eventsSF = eventsSF.drop(['personID','driverID','UniqueID'], axis=1)

# %%
# %%time
dfRiders = eventsSF['riders'].str.split(':',expand=True)
# Out:
# Wall time: 6min 30s

# %%
riderStartIndex = len(eventsSF.columns)

# %%
eventsSF = pd.concat([eventsSF, dfRiders.reindex(eventsSF.index)], axis=1)

# %%
# %%time
NaN = np.nan
eventsSF['ID'] = NaN 
    
for col in eventsSF.columns[riderStartIndex:-2]:
    eventsSF['riderID'] = np.where(eventsSF[col].isin(eventsSF["IDMerged"]), eventsSF[col], np.nan)
    eventsSF['ID'] = eventsSF['ID'].combine_first(eventsSF['riderID'])
# Out:
# Wall time: 6min 7s

# %%
eventsSF['IDMerged'] = eventsSF['IDMerged'].combine_first(eventsSF['ID'])

# %%
eventsSF = eventsSF.drop(columns=eventsSF.columns[riderStartIndex:])

# %%
#eventsSF_chunk = eventsSF[200000:1000000]
#eventsSF_chunk.sort_values(['person']).head(1000)
eventsSF.head()
# Out:
#                                             person  link  facility actType  \
# 0                        TransitDriverAgent-3D:309   NaN       NaN     NaN
# 1                        TransitDriverAgent-3D:309   NaN       NaN     NaN
# 2  TransitDriverAgent-CC:31002002_merged_421003228   NaN       NaN     NaN
# 3  TransitDriverAgent-CC:31002002_merged_421003228   NaN       NaN     NaN
# 4                    TransitDriverAgent-SF:7590302   NaN       NaN     NaN
#
#    time                 type              legMode  secondaryFuelLevel  price  \
# 0   0.0            departure  be_a_transit_driver                 NaN    NaN
# 1   0.0  PersonEntersVehicle                  NaN                 NaN    NaN
# 2   0.0            departure  be_a_transit_driver                 NaN    NaN
# 3   0.0  PersonEntersVehicle                  NaN                 NaN    NaN
# 4   0.0            departure  be_a_transit_driver                 NaN    NaN
#
#   parkingTaz chargingPointType pricingModel parkingType  locationY  locationX  \
# 0        NaN               NaN          NaN         NaN        NaN        NaN
# 1        NaN               NaN          NaN         NaN        NaN        NaN
# 2        NaN               NaN          NaN         NaN        NaN        NaN
# 3        NaN               NaN          NaN         NaN        NaN        NaN
# 4        NaN               NaN          NaN         NaN        NaN        NaN
#
#    primaryFuelLevel                       vehicle  cost driver  departTime  \
# 0               NaN                           NaN   NaN    NaN         NaN
# 1               NaN                        3D:309   NaN    NaN         NaN
# 2               NaN                           NaN   NaN    NaN         NaN
# 3               NaN  CC:31002002_merged_421003228   NaN    NaN         NaN
# 4               NaN                           NaN   NaN    NaN         NaN
#
#    startX  startY  endX  endY  arrivalTime  departureTime currentTourMode  \
# 0     NaN     NaN   NaN   NaN          NaN            NaN             NaN
# 1     NaN     NaN   NaN   NaN          NaN            NaN             NaN
# 2     NaN     NaN   NaN   NaN          NaN            NaN             NaN
# 3     NaN     NaN   NaN   NaN          NaN            NaN             NaN
# 4     NaN     NaN   NaN   NaN          NaN            NaN             NaN
#
#   modeType  incentive  tollCost  netCost  expectedMaximumUtility  \
# 0      NaN        NaN       NaN      NaN                     NaN
# 1      NaN        NaN       NaN      NaN                     NaN
# 2      NaN        NaN       NaN      NaN                     NaN
# 3      NaN        NaN       NaN      NaN                     NaN
# 4      NaN        NaN       NaN      NaN                     NaN
#
#   availableAlternatives  location personalVehicleAvailable  length  tourIndex  \
# 0                   NaN       NaN                      NaN     NaN        NaN
# 1                   NaN       NaN                      NaN     NaN        NaN
# 2                   NaN       NaN                      NaN     NaN        NaN
# 3                   NaN       NaN                      NaN     NaN        NaN
# 4                   NaN       NaN                      NaN     NaN        NaN
#
#   reason riders  toStopIndex  fromStopIndex  seatingCapacity  tollPaid  \
# 0    NaN    NaN          NaN            NaN              NaN       NaN
# 1    NaN    NaN          NaN            NaN              NaN       NaN
# 2    NaN    NaN          NaN            NaN              NaN       NaN
# 3    NaN    NaN          NaN            NaN              NaN       NaN
# 4    NaN    NaN          NaN            NaN              NaN       NaN
#
#    capacity linkTravelTime  secondaryFuel secondaryFuelType primaryFuelType  \
# 0       NaN            NaN            NaN               NaN             NaN
# 1       NaN            NaN            NaN               NaN             NaN
# 2       NaN            NaN            NaN               NaN             NaN
# 3       NaN            NaN            NaN               NaN             NaN
# 4       NaN            NaN            NaN               NaN             NaN
#
#   vehicleType links  numPassengers primaryFuel shiftStatus parkingZoneId  \
# 0         NaN   NaN            NaN         NaN         NaN           NaN
# 1         NaN   NaN            NaN         NaN         NaN           NaN
# 2         NaN   NaN            NaN         NaN         NaN           NaN
# 3         NaN   NaN            NaN         NaN         NaN           NaN
# 4         NaN   NaN            NaN         NaN         NaN           NaN
#
#    fuel  duration  score                                         IDMerged
# 0   NaN       NaN    NaN                        TransitDriverAgent-3D:309
# 1   NaN       NaN    NaN                        TransitDriverAgent-3D:309
# 2   NaN       NaN    NaN  TransitDriverAgent-CC:31002002_merged_421003228
# 3   NaN       NaN    NaN  TransitDriverAgent-CC:31002002_merged_421003228
# 4   NaN       NaN    NaN                    TransitDriverAgent-SF:7590302

# %%
IDnan = eventsSF[eventsSF['IDMerged'].isna()]
IDnan.head()
# Out:
#        person  link  facility actType     time                  type legMode  \
# 195489    NaN   NaN       NaN     NaN  18329.0   ChargingPlugInEvent     NaN
# 195529    NaN   NaN       NaN     NaN  18398.0  ChargingPlugOutEvent     NaN
# 195734    NaN   NaN       NaN     NaN  18407.0   ChargingPlugInEvent     NaN
# 202082    NaN   NaN       NaN     NaN  18561.0   ChargingPlugInEvent     NaN
# 202480    NaN   NaN       NaN     NaN  18595.0  ChargingPlugOutEvent     NaN
#
#         secondaryFuelLevel  price parkingTaz chargingPointType pricingModel  \
# 195489        3.655980e+09    0.0        776   dcfast(50.0|DC)      FlatFee
# 195529        3.655980e+09    0.0        776   dcfast(50.0|DC)      FlatFee
# 195734        3.655980e+09    0.0        971   dcfast(50.0|DC)      FlatFee
# 202082        0.000000e+00    0.0         45   dcfast(50.0|DC)      FlatFee
# 202480        0.000000e+00    0.0         45   dcfast(50.0|DC)      FlatFee
#
#        parkingType  locationY   locationX  primaryFuelLevel vehicle  cost  \
# 195489   Workplace  37.551187 -121.993221      4.271406e+07   40067   NaN
# 195529   Workplace  37.551187 -121.993221      4.616406e+07   40067   NaN
# 195734      Public  37.807875 -122.264529      1.764508e+07  292297   NaN
# 202082      Public  37.798129 -122.427376      9.206262e+07  154789   NaN
# 202480      Public  37.798129 -122.427376      9.376262e+07  154789   NaN
#
#        driver  departTime  startX  startY  endX  endY  arrivalTime  \
# 195489    NaN         NaN     NaN     NaN   NaN   NaN          NaN
# 195529    NaN         NaN     NaN     NaN   NaN   NaN          NaN
# 195734    NaN         NaN     NaN     NaN   NaN   NaN          NaN
# 202082    NaN         NaN     NaN     NaN   NaN   NaN          NaN
# 202480    NaN         NaN     NaN     NaN   NaN   NaN          NaN
#
#         departureTime currentTourMode modeType  incentive  tollCost  netCost  \
# 195489            NaN             NaN      NaN        NaN       NaN      NaN
# 195529            NaN             NaN      NaN        NaN       NaN      NaN
# 195734            NaN             NaN      NaN        NaN       NaN      NaN
# 202082            NaN             NaN      NaN        NaN       NaN      NaN
# 202480            NaN             NaN      NaN        NaN       NaN      NaN
#
#         expectedMaximumUtility availableAlternatives  location  \
# 195489                     NaN                   NaN       NaN
# 195529                     NaN                   NaN       NaN
# 195734                     NaN                   NaN       NaN
# 202082                     NaN                   NaN       NaN
# 202480                     NaN                   NaN       NaN
#
#        personalVehicleAvailable  length  tourIndex reason riders  toStopIndex  \
# 195489                      NaN     NaN        NaN    NaN    NaN          NaN
# 195529                      NaN     NaN        NaN    NaN    NaN          NaN
# 195734                      NaN     NaN        NaN    NaN    NaN          NaN
# 202082                      NaN     NaN        NaN    NaN    NaN          NaN
# 202480                      NaN     NaN        NaN    NaN    NaN          NaN
#
#         fromStopIndex  seatingCapacity  tollPaid  capacity linkTravelTime  \
# 195489            NaN              NaN       NaN       NaN            NaN
# 195529            NaN              NaN       NaN       NaN            NaN
# 195734            NaN              NaN       NaN       NaN            NaN
# 202082            NaN              NaN       NaN       NaN            NaN
# 202480            NaN              NaN       NaN       NaN            NaN
#
#         secondaryFuel secondaryFuelType primaryFuelType vehicleType links  \
# 195489            NaN               NaN             NaN         NaN   NaN
# 195529            NaN               NaN             NaN         NaN   NaN
# 195734            NaN               NaN             NaN         NaN   NaN
# 202082            NaN               NaN             NaN         NaN   NaN
# 202480            NaN               NaN             NaN         NaN   NaN
#
#         numPassengers primaryFuel shiftStatus parkingZoneId  fuel  duration  \
# 195489            NaN         NaN         NaN           NaN   NaN       NaN
# 195529            NaN         NaN         NaN           NaN   NaN       NaN
# 195734            NaN         NaN         NaN           NaN   NaN       NaN
# 202082            NaN         NaN         NaN           NaN   NaN       NaN
# 202480            NaN         NaN         NaN           NaN   NaN       NaN
#
#         score IDMerged
# 195489    NaN      NaN
# 195529    NaN      NaN
# 195734    NaN      NaN
# 202082    NaN      NaN
# 202480    NaN      NaN

# %%
#To select just the numeric MergedID
#eventsSF.loc[eventsSF.IDMerged.str.isnumeric()]
eventsSFnum = eventsSF[pd.to_numeric(eventsSF.IDMerged, errors='coerce').notnull()].sort_values(['IDMerged','time']).reset_index(drop=True)

# %%
eventsSFnum['duration_doorToDoor'] = eventsSFnum.groupby(["IDMerged"]).

# %%
eventsSFnum['duration_travelTime'] =

# %% [markdown]
# #### Checking the file

# %%
Tel = eventsSF[eventsSF['type'] == "TeleportationEvent"].sort_values(['person'])
Tel1 = eventsSF[eventsSF['type'] == "PathTraversal"]
#Tel = eventsSF[(eventsSF['type'] == "TeleportationEvent")&(eventsSF['IDMerged']== '2326180')]
Tel3 = eventsSF[eventsSF['person']== '3644771']
TelCar = eventsSF[eventsSF['person']== '72035']
#eventsSF[(eventsSF.vehicle == '115040')|(eventsSF.IDMerged == 2101144)|(eventsSF.IDMerged == 2101142)]

# %%
SFcharge.to_csv('C:/Shared-Work/Data/CleanData/SFcharge.csv', index = False)

# %%
#person_value = set(eventsSF_chunk['person'].unique())
#person_value = eventsSF_chunk['person'].unique().tolist()
#eventsSF_chunk['personID'] = eventsSF_chunk['driver'].map(lambda x : True if x in person_value else False)

# %%
eventsSF_chunk.personID[eventsSF_chunk.personID != 'NaN'].count()
# Out:
# 470633

# %%
#eventsSF_chunk['personID'] = np.where(eventsSF_chunk['person'].isin(eventsSF_chunk['driver']), eventsSF_chunk['person'], np.nan)

# %%
#it matches the values in one row
#eventsSF_chunk['personID'] = eventsSF_chunk.apply(lambda x: str(x['person']) == str(x['driver']), axis=1)

# %%
#Check if person has an equal value in the driver column
#eventsSF_chunk['personID'] = eventsSF_chunk.person.isin(eventsSF_chunk.driver)

# %%
#eventsSF_chunk['personID'] = eventsSF_chunk.apply(lambda x: x.str(person) in x.str(driver), axis=1)

# %%
#personID = []
#for i, row in eventsSF_chunk.iterrows():
    #for j, row in eventsSF_chunk.iterrows():
        #if eventsSF_chunk.person[i] == eventsSF_chunk.driver[j]:
            #personID.append('True')

# %%
for column in eventsSF[['person', 'driver', 'riders']]:
    for i in column 
    


personID = []
for i, row in eventsSF.iterrows():
    for j, row in eventsSF.iterrows():
        if eventsSF.person[i] == eventsSF.driver[j]:
            personID.append('True') 
            
eventsSF["personID"] = personID           
    
    
    groupedPerson = eventsSF.groupby(["person"]),
    eventsSF[(eventsSF["person"]==groupedPerson)|(eventsSF["driver"]== groupedPerson)|]
    
    
    if row['person'] == 'none':
        eventsSF
    

    if row['classification'] == 'none':
        df.at[i,'classification'] = 'any'
# Out:
#   File "C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/4283926593.py", line 2
#     for i in column
#                     ^
# SyntaxError: invalid syntax

# %%
groupedPerson = eventsSF.groupby(["person"])

# %%
#def ridersToList(val):
    #if str(val) == 'nan':
        #return []
    #else:
        #return str(val).split(':')

# %%
#eventsSF['riders'] = eventsSF.riders.apply(ridersToList)

# %%
SFpersonRidehail = eventsSF[(eventsSF["person"]=='1633871')|(eventsSF["driver"]=="1633871")]

# %%
SFpersonRidehail.to_csv('C:/Shared-Work/Data/CleanData/SFpersonRidehail.csv', index = False)

# %%
b = eventsSF[eventsSF["type"]=="Replanning"]

# %%
SFpersonRidehail = eventsSF[(eventsSF["person"]==6540390)|(eventsSF["driver"]=="6540390")]

# %%
#SFpersonRidehail.to_csv('C:/Shared-Work/Data/CleanData/SFpersonRidehail.csv')

# %%
SFRidehail = eventsSF[eventsSF['vehicle'] == "rideHailVehicle-6506744@default"]

# %%
#SFRidehail.to_csv('C:/Shared-Work/Data/CleanData/SFRidehail.csv')

# %%
SFperson361511 = eventsSF[(eventsSF["person"]==361511)|(eventsSF["driver"]=="361511")|(eventsSF["vehicle"]=="442590")]

# %%
SFperson361511.to_csv('C:/Shared-Work/Data/CleanData/SFperson361511.csv')

# %%
SFRidehailTransit361511 = eventsSF[(eventsSF['vehicle'] == "rideHailVehicle-952441@default")|(eventsSF['vehicle'] == "AC:5578533")|(eventsSF['vehicle'] == "AC:5578545")]

# %%
plansSF[(plansSF["personId"]==4373312)]

# %%
SFRidehailTransit361511.to_csv('C:/Shared-Work/Data/CleanData/SFRidehailTransit361511.csv')

# %%
SFHomeWork4373312 = eventsSF[(eventsSF["person"]==4373312)|(eventsSF["driver"]=="4373312")]

# %%
SFHomeWork4373312.to_csv('C:/Shared-Work/Data/CleanData/SFHomeWork361511.csv')

# %%
eventsSF.time = eventsSF.time/3600

# %%
eventsSF[(eventsSF["person"]==4373312)|(eventsSF["driver"]=="4373312")]

# %%
#Zach's code to extract activities, trips and path traversals from the plans and events 
import geopandas as gpd
import numpy as np
import pandas as pd


def fixPathTraversals(PTs):
    PTs['duration'] = PTs['arrivalTime'] - PTs['departureTime']
    PTs['mode_extended'] = PTs['mode']
    PTs['isRH'] = PTs['vehicle'].str.contains('rideHail')
    PTs['isCAV'] = PTs['vehicleType'].str.contains('L5')
    PTs.loc[PTs['isRH'], 'mode_extended'] += '_RideHail'
    PTs.loc[PTs['isCAV'], 'mode_extended'] += '_CAV'
    PTs['occupancy'] = PTs['numPassengers']
    PTs.loc[PTs['mode_extended'] == 'car', 'occupancy'] += 1
    PTs.loc[PTs['mode_extended'] == 'walk', 'occupancy'] = 1
    PTs.loc[PTs['mode_extended'] == 'bike', 'occupancy'] = 1
    PTs['vehicleMiles'] = PTs['length'] / 1609.34
    PTs['passengerMiles'] = (PTs['length'] * PTs['occupancy']) / 1609.34
    PTs['totalEnergyInJoules'] = PTs['primaryFuel'] + PTs['secondaryFuel']
    PTs['gallonsGasoline'] = 0
    PTs.loc[PTs['primaryFuelType'] == 'gasoline',
            'gallonsGasoline'] += PTs.loc[PTs['primaryFuelType'] == 'gasoline', 'primaryFuel'] * 8.3141841e-9
    PTs.loc[PTs['secondaryFuelType'] == 'gasoline',
            'gallonsGasoline'] += PTs.loc[PTs['secondaryFuelType'] == 'gasoline', 'secondaryFuel'] * 8.3141841e-9
    PTs.drop(columns=['numPassengers', 'length'], inplace=True)
    return PTs


def addGeometryIdToDataFrame(df, gdf, xcol, ycol, idColumn="geometry", df_geom='epsg:4326'):
    gdf_data = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df[xcol], df[ycol]))
    gdf_data.crs = {'init': df_geom}
    joined = gpd.sjoin(gdf_data.to_crs('epsg:26910'), gdf.to_crs('epsg:26910'))
    gdf_data = gdf_data.merge(joined['blkgrpid'], left_index=True, right_index=True, how="left")
    gdf_data.rename(columns={'blkgrpid': idColumn}, inplace=True)
    df = pd.DataFrame(gdf_data.drop(columns='geometry'))
    df.drop(columns=[xcol, ycol], inplace=True)
    return df.loc[~df.index.duplicated(keep='first'), :]


def ridersToList(val):
    if str(val) == 'nan':
        return []
    else:
        return str(val).split(':')


def processEvents(directory):
    fullPath = directory + 'events.csv.gz'
    PTs = []
    PEVs = []
    PLVs = []
    print('Reading ', fullPath)
    for chunk in pd.read_csv(fullPath, chunksize=500000):
        if sum((chunk['type'] == 'PathTraversal')) > 0:
            chunk['vehicle'] = chunk['vehicle'].astype(str)
            PT = chunk.loc[(chunk['type'] == 'PathTraversal') & (chunk['length'] > 0)].dropna(how='all', axis=1)
            PT['departureTime'] = PT['departureTime'].astype(int)
            PT['arrivalTime'] = PT['arrivalTime'].astype(int)
            if 'riders' in PT.columns:
                PT['riders'] = PT.riders.apply(ridersToList)
            else:
                PT['riders'] = [[]] * len(PT)
            PTs.append(PT[['driver', 'vehicle', 'mode', 'length', 'startX', 'startY', 'endX', 'endY', 'vehicleType',
                           'arrivalTime', 'departureTime', 'primaryFuel', 'primaryFuelType', 'secondaryFuel',
                           'secondaryFuelType', 'numPassengers', 'riders']])
            PEV = chunk.loc[(chunk.type == "PersonEntersVehicle") &
                            ~(chunk['person'].apply(str).str.contains('Agent').fillna(False)) &
                            ~(chunk['vehicle'].str.contains('body').fillna(False)), :].dropna(how='all', axis=1)
            if ~PEV.empty:
                PEV['person'] = PEV['person'].astype(int)
                PEV['time'] = PEV['time'].astype(int)
                PEVs.append(PEV)

            PLV = chunk.loc[(chunk.type == "PersonLeavesVehicle") &
                            ~(chunk['person'].apply(str).str.contains('Agent').fillna(False)) &
                            ~(chunk['vehicle'].str.contains('body').fillna(False)), :].dropna(how='all', axis=1)
            if ~PLV.empty:
                PLV['person'] = PLV['person'].astype(int)
                PLV['time'] = PLV['time'].astype(int)
                PLVs.append(PLV)
    PTs = fixPathTraversals(pd.concat(PTs))
    return PTs, pd.concat(PEVs), pd.concat(PLVs)


def createLabeledNetwork(networkPath, gdf):
    network = pd.read_csv(networkPath)[['linkId', 'fromLocationX', 'fromLocationY']]
    network = gpd.GeoDataFrame(network, geometry=gpd.points_from_xy(network.fromLocationX, network.fromLocationY))
    network.crs = {'init': 'epsg:26910'}
    joined = gpd.sjoin(network, gdf[['geometry', 'blkgrpid']].to_crs('epsg:26910'))
    network = pd.DataFrame(joined.drop(columns=['geometry', 'index_right'])).rename(columns={'blkgrpid': 'blockGroup'})
    return network


def labelTrips(trips, labeledNetwork):
    labeledTrips = trips.merge(labeledNetwork, left_on='legRouteStartLink', right_on='linkId', how='left')
    labeledTrips.drop(columns=['linkId', 'fromLocationX', 'fromLocationY'], inplace=True)
    labeledTrips.rename(columns={'blockGroup': 'startBlockGroup'}, inplace=True)
    labeledTrips = labeledTrips.merge(labeledNetwork, left_on='legRouteEndLink', right_on='linkId', how='left')
    labeledTrips.drop(columns=['linkId', 'fromLocationX', 'fromLocationY'], inplace=True)
    labeledTrips.rename(columns={'blockGroup': 'endBlockGroup'}, inplace=True)
    return labeledTrips

def addTimesToPlans(plans):
    legInds = np.where(plans['ActivityElement'].str.lower() == "leg")[0]
    plans['legDepartureTime'] = np.nan
    plans['legDepartureTime'].iloc[legInds] = plans['departure_time'].iloc[legInds - 1].copy()
    return plans

def processPlans(directory):
    fullPath = directory + 'final_plans.csv'
    trips = []
    activities = []
    personToTripDeparture = {}
    print(fullPath)
    for chunk in pd.read_csv(fullPath, chunksize=100000):
        chunk = addTimesToPlans(chunk)
        legs = chunk.loc[(chunk['ActivityElement'].str.lower().str.contains('leg'))].dropna(how='all', axis=1)
        legsSub = legs[['person_id', 'legDepartureTime',  'PlanElementIndex']]
        for rowID, val in legsSub.iterrows():
            personToTripDeparture.setdefault(val.person_id, []).append(
                {"planID": val.PlanElementIndex, "departureTime": val.legDepartureTime * 3600.0})
        trips.append(legsSub)
        acts = chunk.loc[(chunk['ActivityElement'].str.lower().str.contains('activity'))].dropna(how='all', axis=1)

        actsSub = acts[['person_id', 'ActivityType', 'x', 'y', 'departure_time']]
        activities.append(actsSub)
    return pd.concat(trips), pd.concat(activities), personToTripDeparture


def personToPathTraversal(PTs, PEVs, PLVs, personToTripDeparture):
    vehicleToPT = PTs.groupby('vehicle').apply(lambda x: list(x.index)).apply(
        lambda x: {y: [] for y in x}).to_dict()

    PEVlookup = PEVs[['person', 'vehicle', 'time']].value_counts().to_dict()
    PLVlookup = PLVs.groupby(['person', 'vehicle']).apply(lambda x: list(x.time)).to_dict()
    # personToPT = PEVs['person'].value_counts().apply(lambda x: []).to_dict()

    for key, counts in PEVlookup.items():
        person = key[0]
        vehicle = key[1]
        departureTime = key[2]
        if vehicle in vehicleToPT:
            legs = vehicleToPT[vehicle]
            if (person, vehicle) in PLVlookup:
                if person in personToTripDeparture:
                    planTrips = personToTripDeparture[person]
                    tripsLeavingBeforeDeparture = [-1] + [t['planID'] for t in planTrips if
                                                          t['departureTime'] <= (departureTime + 1800)]
                else:
                    tripsLeavingBeforeDeparture = [-1]
                endTimes = PLVlookup[(person, vehicle)]
                plvsAfterDeparture = [t for t in endTimes if t > departureTime]

                if len(plvsAfterDeparture) > 0:
                    firstPLVafterDeparture = plvsAfterDeparture[0]
                    lastTripBeforeDeparture = tripsLeavingBeforeDeparture[-1]
                    if lastTripBeforeDeparture == -1:
                        print('hmm')
                    for leg in legs.keys():
                        ptDepartureTime = PTs.at[leg, 'departureTime']
                        if (ptDepartureTime >= departureTime) & (ptDepartureTime < firstPLVafterDeparture):
                            legs[leg].append((person, lastTripBeforeDeparture))
                            # personToPT[person].append(leg)
                # else:
                #     for leg in legs.keys():
                #         ptDepartureTime = PTs.at[leg, 'departureTime']
                #         if ptDepartureTime >= departureTime:
                #             legs[leg].append(person)
                            # # personToPT[person].append(leg)
            else:
                for leg in legs.keys():
                    ptDepartureTime = PTs.at[leg, 'departureTime']
                    if person in personToTripDeparture:
                        planTrips = personToTripDeparture[person]
                        tripsLeavingBeforeDeparture = [-1] + [t['planID'] for t in planTrips if
                                                              t['departureTime'] <= (departureTime + 1800)]
                    else:
                        tripsLeavingBeforeDeparture = [-1]
                    lastTripBeforeDeparture = tripsLeavingBeforeDeparture[-1]
                    if lastTripBeforeDeparture == -1:
                        print('hmm')
                    if ptDepartureTime >= departureTime:
                        legs[leg].append((person, lastTripBeforeDeparture))
                        # personToPT[person].append(leg)
        # else:
        #     print("no legs for ", vehicle)

    vehiclePathPassengerList = [(veh, pathTraversalID, passenger, planIndex) for veh, vehicleLegs in
                                vehicleToPT.items() for pathTraversalID, passengers in vehicleLegs.items() for
                                (passenger, planIndex) in passengers if len(passengers) > 0]
    vehiclePathPassenger = pd.MultiIndex.from_tuples(vehiclePathPassengerList,
                                                     name=['vehicleID', 'pathTraversalID', 'personID',
                                                           'planIndex']).to_frame()

    return vehiclePathPassenger


def collectAllData(inDirectory, outDirectory, popDirectory, prefix):
    filePath = inDirectory + '/' + prefix + '.'
    inputFilePath = inDirectory + '/' + popDirectory + '/'

    trips, activities, personToTripDeparture = processPlans(inputFilePath)

    PTs, PEVs, PLVs = processEvents(filePath)
    # personToPathTraversal(PTs, PEVs, PLVs, personToTripDeparture)
    vehiclePathPassenger = personToPathTraversal(PTs, PEVs, PLVs, personToTripDeparture)
    # BGs = gpd.read_file('scenario/sfbay-blockg  roups-2010.zip')

    if False:
        BGs = gpd.read_file('scenario/block_groups_austin/block_groups_austin.shp')

        network = createLabeledNetwork('data/austin.network.csv.gz', BGs)
        trips = labelTrips(trips, network)
        activities = addGeometryIdToDataFrame(activities, BGs, 'activityLocationX', 'activityLocationY',
                                              'activityBlockGroup', df_geom='epsg:26910')

        PTs = addGeometryIdToDataFrame(PTs, BGs, 'startX', 'startY', 'startBlockGroup')
        PTs = addGeometryIdToDataFrame(PTs, BGs, 'endX', 'endY', 'endBlockGroup')
        PTs.index.set_names('PathTraversalID', inplace=True)

    trips.to_csv(outDirectory + '/' + prefix + '.trips.csv', index=True)
    vehiclePathPassenger.to_csv(outDirectory + '/' + prefix + '.passengerToPathTraversal.csv', index=False)
    PTs.to_csv(outDirectory + '/' + prefix + '.pathTraversals.csv', index=True)
    activities.to_csv(outDirectory + '/' + prefix + '.activities.csv', index=True)


if __name__ == '__main__':
    # directory = 'https://beam-outputs.s3.amazonaws.com/pilates-outputs/15thSep2019/c_ht/beam/sfbay-smart-c-ht' \
    #             '-pilates__2019-09-13_18-00-40/ITERS/it.15/15.'
    inDirectory = 'https://beam-outputs.s3.amazonaws.com/pilates-outputs/sfbay-2010-central-20210114'
    popDirectory = 'activitysim'
    prefixes = ['beam/sfbay-pilates-base__2022-01-14_17-54-11_cda/ITERS/it.0/0']
    outDirectory = 'C:/Shared-Work/Data/out_test'
    for prefix in prefixes:
        collectAllData(inDirectory, outDirectory, popDirectory, prefix)

    print('done')
# Out:
# https://beam-outputs.s3.amazonaws.com/pilates-outputs/sfbay-2010-central-20210114/activitysim/final_plans.csv
# C:\Users\nazanin\.conda\envs\geo_env\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Reading  https://beam-outputs.s3.amazonaws.com/pilates-outputs/sfbay-2010-central-20210114/beam/sfbay-pilates-base__2022-01-14_17-54-11_cda/ITERS/it.0/0.events.csv.gz
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (0,8,9,11,13,16,17,20,31,33,34,36,37,38,39,50,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (22,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (20,22,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (11,13,20,22,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (0,20,22,36,51,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (0,11,13,20,22,36,51,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (11,20,22,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (11,13,17,20,22,31,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (11,13,20,22,36,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (20,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (11,13,20,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (20,36,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (11,20,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (11,13,36,52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# C:\Users\nazanin\AppData\Local\Temp\2/ipykernel_6744/2479515664.py:236: DtypeWarning: Columns (52,56) have mixed types.Specify dtype option on import or set low_memory=False.
#   collectAllData(inDirectory, outDirectory, popDirectory, prefix)
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# ...
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# hmm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\2/ipykernel_6744/2479515664.py in <module>
#     234     outDirectory = 'C:/Shared-Work/Data/out_test'
#     235     for prefix in prefixes:
# --> 236         collectAllData(inDirectory, outDirectory, popDirectory, prefix)
#     237
#     238     print('done')
#
# ~\AppData\Local\Temp\2/ipykernel_6744/2479515664.py in collectAllData(inDirectory, outDirectory, popDirectory, prefix)
#     205     PTs, PEVs, PLVs = processEvents(filePath)
#     206     # personToPathTraversal(PTs, PEVs, PLVs, personToTripDeparture)
# --> 207     vehiclePathPassenger = personToPathTraversal(PTs, PEVs, PLVs, personToTripDeparture)
#     208     # BGs = gpd.read_file('scenario/sfbay-blockg  roups-2010.zip')
#     209
#
# ~\AppData\Local\Temp\2/ipykernel_6744/2479515664.py in personToPathTraversal(PTs, PEVs, PLVs, personToTripDeparture)
#     159                         print('hmm')
#     160                     for leg in legs.keys():
# --> 161                         ptDepartureTime = PTs.at[leg, 'departureTime']
#     162                         if (ptDepartureTime >= departureTime) & (ptDepartureTime < firstPLVafterDeparture):
#     163                             legs[leg].append((person, lastTripBeforeDeparture))
#
# ~\.conda\envs\geo_env\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2273             return self.obj.loc[key]
#    2274
# -> 2275         return super().__getitem__(key)
#    2276
#    2277     def __setitem__(self, key, value):
#
# ~\.conda\envs\geo_env\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2220
#    2221         key = self._convert_key(key)
# -> 2222         return self.obj._get_value(*key, takeable=self._takeable)
#    2223
#    2224     def __setitem__(self, key, value):
#
# ~\.conda\envs\geo_env\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    3578         try:
#    3579             loc = engine.get_loc(index)
# -> 3580             return series._values[loc]
#    3581         except AttributeError:
#    3582             # IntervalTree has no get_loc
#
# ~\.conda\envs\geo_env\lib\site-packages\pandas\core\series.py in _values(self)
#     672         return self._mgr.external_values()
#     673
# --> 674     @property
#     675     def _values(self):
#     676         """
#
# KeyboardInterrupt:
