# %%
! pip install geopandas
! pip install pandas
! pip install pygeos
! pip install boto
! pip install s3fs
! pip install shapely
! pip install gcsfs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gzip
import time
from itertools import groupby
import geopandas as gpd
# Out:
# ...
# /opt/conda/lib/python3.10/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.11.1-CAPI-1.17.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# /tmp/ipykernel_151985/1029240406.py:14: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# ...

# %%
# veh_base = pd.concat([pd.read_csv('vehicles_Baseline2019.csv'),pd.read_csv('vehicles_May2020.csv'),pd.read_csv('vehicles_Aug2020.csv'),pd.read_csv('vehicles_Aug2021.csv'),pd.read_csv('vehicles_Jan2022.csv'),pd.read_csv('vehicles_May2022.csv')])

# %%
for date_ in ['Baseline2019','May2020','Aug2020','Aug2021','Jan2022','May2022']:
    veh_base = pd.read_csv('outputs/vehicles_%s.csv'%(date_))
    agencies = []
    for vehicle in veh_base['vehicle']:
        agencies.append(vehicle[:8])
    veh_base['agencies']=agencies

    trains = []
    notes = []
    vtypes = []

    for veh, ag, cap  in zip(veh_base['vehicle'],veh_base['agencies'],veh_base['0']):

        if ag == 'NJ_Trans':
            if int(cap) == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus') 
            elif int(cap) == 1910:
                trains.append(12)
                notes.append('')
                vtypes.append('CummuterRail') 
            else:
                trains.append('mmmmh')
                notes.append('mmmmh')
                vtypes.append('mmmmh')
        elif ag == 'MTA_Broo':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            elif cap == 160:
                trains.append(1)
                notes.append('bus-60ft')
                vtypes.append('LongBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh')
                vtypes.append('mmmmh')
        elif ag == 'MTA_Bron':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            elif cap == 160:
                trains.append(1)
                notes.append('bus-60ft')
                vtypes.append('LongBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh')
                vtypes.append('mmmmh')
        elif ag == 'MTA_Manh':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            elif cap == 160:
                trains.append(1)
                notes.append('bus-60ft')
                vtypes.append('LongBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh')
                vtypes.append('mmmmh')
        elif ag == 'MTA_Quee':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            elif cap == 160:
                trains.append(1)
                notes.append('bus-60ft')
                vtypes.append('LongBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh')
                vtypes.append('mmmmh')
        elif ag == 'MTA_Stat':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            elif cap == 160:
                trains.append(1)
                notes.append('bus-60ft')
                vtypes.append('LongBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'NYC_Bus_':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            elif cap == 160:
                trains.append(1)
                notes.append('bus-60ft') 
                vtypes.append('LongBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'NYC_Subw':
            if cap == 1270:
                trains.append(6)
                notes.append('') 
                vtypes.append('Subway')
            elif cap == 1290:
                trains.append(4)
                notes.append('') 
                vtypes.append('Subway')
            elif cap == 1400:
                trains.append(5)
                notes.append('') 
                vtypes.append('Subway')
            elif cap == 2110:
                trains.append(10)
                notes.append('') 
                vtypes.append('Subway')
            elif cap == 2250:
                trains.append(8)
                notes.append('') 
                vtypes.append('Subway')
            elif cap == 2580:
                trains.append(8)
                notes.append('') 
                vtypes.append('Subway')
            elif cap == 2800:
                trains.append(10)
                notes.append('')
                vtypes.append('Subway')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'NICE_117':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft') 
                vtypes.append('StandardBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'WCDOT_20':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft') 
                vtypes.append('StandardBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh')
                vtypes.append('mmmmh')
        elif ag == '151_631:':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft') 
                vtypes.append('StandardBus')
            elif cap == 1080:
                trains.append(7)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1240:
                trains.append(8)
                notes.append('') 
                vtypes.append('CummuterRail')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'Suffolk_':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft') 
                vtypes.append('StandardBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh')
                vtypes.append('mmmmh')
        elif ag == 'Long_Isl':
            if cap == 200:
                trains.append(1)
                notes.append('')
                vtypes.append('CummuterRail')
            elif cap == 400:
                trains.append(2)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 790:
                trains.append(4)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 900:
                trains.append(6)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 990:
                trains.append(5)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1180:
                trains.append(6)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1190:
                trains.append(8)
                notes.append('')
                vtypes.append('CummuterRail')
            elif cap == 1490:
                trains.append(10)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1570:
                trains.append(8)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1790:
                trains.append(12)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1980:
                trains.append(10)
                notes.append('') 
                vtypes.append('CummuterRail')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'Metro-No':
            if cap == 460:
                trains.append(3)
                notes.append('')
                vtypes.append('CummuterRail')
            elif cap == 750:
                trains.append(5)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 890:
                trains.append(6)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 990:
                trains.append(6)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1050:
                trains.append(7)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1080:
                trains.append(7)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1180:
                trains.append(8)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1250:
                trains.append(7)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1320:
                trains.append(8)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1340:
                trains.append(9)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1470:
                trains.append(10)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1630:
                trains.append(11)
                notes.append('')
                vtypes.append('CummuterRail')
            elif cap == 1640:
                trains.append(10)
                notes.append('')
                vtypes.append('CummuterRail')
            elif cap == 1980:
                trains.append(12)
                notes.append('')
                vtypes.append('CummuterRail')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'NYC_Ferr':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            elif cap == 5810:
                trains.append(1)
                notes.append('Ferry') 
                vtypes.append('Ferry')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'JFK_Airt':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'Staten_I':
            if cap == 5810:
                trains.append(1)
                notes.append('Ferry')
                vtypes.append('Ferry')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        elif ag == 'path-nj-':
            if cap == 100:
                trains.append(1)
                notes.append('bus-40ft')
                vtypes.append('StandardBus')
            elif cap == 1080:
                trains.append(7)
                notes.append('') 
                vtypes.append('CummuterRail')
            elif cap == 1240:
                trains.append(8)
                notes.append('') 
                vtypes.append('CummuterRail')
            else:
                trains.append('mmmmh')
                notes.append('mmmmh') 
                vtypes.append('mmmmh')
        else:
            trains.append('mmmmh')
            notes.append('mmmmh')
            vtypes.append('mmmmh')

    veh_base['cars'] = trains
    veh_base['notes'] = notes
    veh_base['VehicleType'] = vtypes
    veh_base['capacity'] = veh_base['0']
    veh_base = veh_base.drop('0', axis = 1)
    
    veh_base.to_csv('outputs/vehicles_%s_3.csv'%(date_))

    veh_base['cars'].value_counts()

# %%
veh_base
# Out:
#                                                  vehicle  capacity  agencies  \
# 0      JFK_Airtrain_20200215:0b25edcd-94bb-4122-a5c3-...       100  JFK_Airt
# 1      JFK_Airtrain_20200215:0b25edcd-94bb-4122-a5c3-...       100  JFK_Airt
# 2      JFK_Airtrain_20200215:0b25edcd-94bb-4122-a5c3-...       100  JFK_Airt
# 3      JFK_Airtrain_20200215:0b25edcd-94bb-4122-a5c3-...       100  JFK_Airt
# 4      JFK_Airtrain_20200215:0b25edcd-94bb-4122-a5c3-...       100  JFK_Airt
# ...                                                  ...       ...       ...
# 87825                  path-nj-us:t_2023700_b_33635_tn_0      1240  path-nj-
# 87826                  path-nj-us:t_2023708_b_33635_tn_0      1080  path-nj-
# 87827                  path-nj-us:t_2023709_b_33635_tn_0      1080  path-nj-
# 87828                  path-nj-us:t_2023710_b_33635_tn_0      1080  path-nj-
# 87829                  path-nj-us:t_2023711_b_33635_tn_0      1080  path-nj-
#
#        cars     notes   VehicleType
# ...
