# %%
#Imports
import numpy as np
import pandas as pd
import geopandas as gpd
import difflib
import matplotlib.pyplot as plt
import time
import zipfile

def  processEvents(dataFilepath_sim, nrows):
    PTs = []
    PEVs = []
    print('read', dataFilepath_sim)
    for chunk in pd.read_csv(dataFilepath_sim, compression = 'gzip',chunksize=2500000, nrows = nrows, usecols = ['vehicle','time','endY','endX','startY','startX','mode', 'length', 'type', 'person']):
        if sum((chunk['type'] == 'PathTraversal')) > 0:
            chunk['vehicle'] = chunk['vehicle'].astype(str)
            PT = chunk.loc[(chunk['type'] == 'PathTraversal') & (chunk['length'] > 0)].dropna(how='all', axis=1)

            PTs.append(PT)
            print(chunk.type.value_counts())
            PEV = chunk.loc[(chunk.type == "PersonEntersVehicle") &
                            ~(chunk['person'].apply(str).str.contains('Agent').fillna(False)) &
                            ~(chunk['vehicle'].str.contains('body').fillna(False)), :].dropna(how='all', axis=1)
            if ~PEV.empty:
                PEV['time'] = PEV['time'].astype(int)
                PEVs.append(PEV)

    Events_file_sim_PT = pd.concat(PTs)[['vehicle','time','endY','endX','startY','startX','mode']]
    Events_file_sim_PE = pd.concat(PEVs)[['vehicle','time',]]
    print(Events_file_sim_PE)

    return Events_file_sim_PT, Events_file_sim_PE



#Filter transit trips
def filter_transit(Events_file_sim_PT,Events_file_sim_PE):
    print(Events_file_sim_PT['mode'].value_counts())
    Events_file_sim_PT = Events_file_sim_PT[(Events_file_sim_PT['mode'] == 'bus')|
                                            (Events_file_sim_PT['mode'] == 'tram')|
                                            (Events_file_sim_PT['mode'] == 'subway')|
                                            (Events_file_sim_PT['mode'] == 'cable_car')|
                                            (Events_file_sim_PT['mode'] == 'ferry')|
                                            (Events_file_sim_PT['mode'] == 'rail')]
    print(Events_file_sim_PT['mode'].value_counts())
    Events_file_sim_PE = Events_file_sim_PE[Events_file_sim_PE['vehicle'].isin(Events_file_sim_PT['vehicle'])]
    
    return Events_file_sim_PE, Events_file_sim_PT

def guess_agency(Events_file_sim_PE):

    agencies = []
    for vehicleID in Events_file_sim_PE['vehicle']:
        agency = vehicleID.split(':')[0]
        if agency == 'petalumatransit-petaluma-ca-us':
            agencies.append('PE')
        elif agency == 'westcat-ca-us':
            agencies.append('WC')
        elif agency == 'caltrain-ca-us':
            agencies.append('CA')
        elif agency == 'riovista-ca-us':
            agencies.append('RV')
        elif agency == 'unioncity-ca-us':
            agencies.append('UC')
        else:
            if len(agency) == 2:
                agencies.append(agency)
            elif agency == 'Caltrain':
                agencies.append('CA')
            else:
                print('Warning, this agency is not recognized:', agency)
    Events_file_sim_PE['agency'] = agencies

    print('AGENCIES',np.unique(agencies))
    
    return Events_file_sim_PE

def guess_route(Events_file_sim_PE, GTFS_filepaths):

    GTFS_trip_files = {}

    for GTFS_filepath, GTFS in zip(GTFS_filepaths,GTFSs):
        with zipfile.ZipFile(GTFS_filepath, 'r') as zip_ref:
            trip_file = pd.read_csv(zip_ref.open('trips.txt'))
            trip_to_route = dict(zip(trip_file['trip_id'].astype(str), trip_file['route_id'].astype(str)))
            GTFS_trip_files[str(GTFS)] = trip_to_route

    route_ids = []
    total_routes = len(Events_file_sim_PE['vehicle'])
    i = 0
    time_start = time.time()
    for vehicle, agency in zip(Events_file_sim_PE['vehicle'],Events_file_sim_PE['agency']):
        i+=1
        if i%10000 ==0:
            print(i,'/',total_routes,'. Time = ', time.time()-time_start, '. Estimated remaining time:', (time.time()-time_start)/i*total_routes-(time.time()-time_start))
        if agency == 'SM':
            try:
                route_ids.append(agency+':'+str(GTFS_trip_files[agency][str(vehicle).split(':')[1]+'|'
                         +str(vehicle).split(':')[2]+':'
                         +str(vehicle).split(':')[3]+'|'
                         +str(vehicle).split(':')[4]+':'
                         +str(vehicle).split(':')[5]+':'
                         +str(vehicle).split(':')[6]]))
            except:
                try:
                    route_ids.append(agency+':'+str(GTFS_trip_files[agency][str(vehicle).split(':')[1]+'|'
                             +str(vehicle).split(':')[2]+':'
                             +str(vehicle).split(':')[3]+'|'
                             +str(vehicle).split(':')[4]+':'
                             +str(vehicle).split(':')[5]]))
                except:
                    print('Warning, trip non found for vehicle', vehicle)
        else:
            try:
                route_ids.append(agency+':'+str(GTFS_trip_files[agency][vehicle.split(':')[1]]))
            except:
                print('Warning, trip non found for vehicle', vehicle)
                route_ids.append('tripID not found')

    Events_file_sim_PE['route_id'] = route_ids
    
    return Events_file_sim_PE


def addGeometryIdToDataFrame(df, gdf, xcol, ycol, idColumn="geometry", df_geom='epsg:32610'): 
    gdf.set_crs(epsg = "3310", inplace = True)
    gdf_data = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df[xcol], df[ycol]))
    gdf_data.set_crs(epsg = "32610", inplace = True)
    joined = gpd.sjoin(gdf_data.to_crs('epsg:26910'), gdf.to_crs('epsg:26910'))
    gdf_data = gdf_data.merge(joined['ZCTA'], left_index=True, right_index=True, how="left")
    gdf_data.rename(columns={'ZCTA': idColumn}, inplace=True)
    df = pd.DataFrame(gdf_data.drop(columns='geometry'))
#     df.drop(columns=[xcol, ycol], inplace=True)
    return df#.loc[~df.index.duplicated(keep='first'), :]


#Read
BGs = gpd.read_file('/vsicurl/https://github.com/LBNL-UCB-STI/beam-core-analysis/raw/main/Users/Zach/scenario/sfbay-blockgroups-2010/641aa0d4-ce5b-4a81-9c30-8790c4ab8cfb202047-1-wkkklf.j5ouj.shp')


dataFilepath_dict = {
        'gs://beam-core-outputs/sfbay-baseline-20230526/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'Baseline_10pct', # other corrections...BEAM 0.9.5
        'gs://beam-core-outputs/sfbay-tr-speed0_25-20230626/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'TRspeed-0_25',
        'gs://beam-core-outputs/sfbay-tr-speed0_5-20230626/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'TRspeed-0_5',
        'gs://beam-core-outputs/sfbay-tr-speed1_5-20230623/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'TRspeed-1_5',
        'gs://beam-core-outputs/sfbay-tr-speed2_0-20230623/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'TRspeed-2_0',
        'gs://beam-core-outputs/sfbay-tr-discount-100-20230703/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'TRdisc-100',
        'gs://beam-core-outputs/sfbay-tr-discount-75-20230703/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'TRdisc-75',
        'gs://beam-core-outputs/sfbay-tr-discount-50-20230703/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'TRdisc-50',
        'gs://beam-core-outputs/sfbay-tr-discount-25-20230703/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'TRdisc-25',
        'gs://beam-core-outputs/sfbay-tr_capacity_0_25-20230608/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'capacity-0.25',
        'gs://beam-core-outputs/sfbay-tr_capacity_0_5-20230608/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'capacity-0.5',
        'gs://beam-core-outputs/sfbay-tr_capacity_1_5-20230608/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'capacity-1.5',
        'gs://beam-core-outputs/sfbay-tr_capacity_2-20230607/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'capacity-2',
        'gs://beam-core-outputs/sfbay-tr-frequency_0_25-20230614/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'freq-0.25',
        'gs://beam-core-outputs/sfbay-tr-frequency_0_50-20230614/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'freq-0.5',
        'gs://beam-core-outputs/sfbay-tr-frequency_1_5-20230614/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'freq-1.5',
        'gs://beam-core-outputs/sfbay-tr-frequency_2-20230616/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz':'freq-2',

    }

dataFilepath_sim = dataFilepath_dict.keys()
names = dataFilepath_dict.values()

output_filepath = 'outputs/'

GTFS_filepath1 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath2 = 'inputs/GTFS_Speed025/'
GTFS_filepath3 = 'inputs/GTFS_Speed05/'
GTFS_filepath4 = 'inputs/GTFS_Speed1_5/'
GTFS_filepath5 = 'inputs/GTFS_Speed2/'
GTFS_filepath6 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath7 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath8 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath9 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath10 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath11 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath12 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath13 = 'inputs/GTFS_Baseline10may2023/'
GTFS_filepath14 = 'inputs/GTFS_Freq025/'
GTFS_filepath15 = 'inputs/GTFS_Freq05/'
GTFS_filepath16 = 'inputs/GTFS_Freq1_5/'
GTFS_filepath17 = 'inputs/GTFS_Freq2/'


RA_output = 'agency_ridershipNewitROI2.csv'
RR_output = 'route_ridershipNewitROI2.csv'

GTFSs = ['AC', 'AM', 'AY', 'BA', 'CA', 'CC', 'CE', 'CM', 'DE', 'EM', 'FF', 'GG', 'HF', 'MA', 'PE', 'RV', 'SB', 'SC', 'SF', 'SL', 'SM', 'SO', 'SR', 'ST', 'TD', 'UC', 'VC', 'VN', 'VT', 'WC', 'WH']

GTFS_1 = [GTFS_filepath1 + f'{agency}.zip' for agency in GTFSs]
GTFS_2 = [GTFS_filepath2 + f'{agency}.zip' for agency in GTFSs]
GTFS_3 = [GTFS_filepath3 + f'{agency}.zip' for agency in GTFSs]
GTFS_4 = [GTFS_filepath4 + f'{agency}.zip' for agency in GTFSs]
GTFS_5 = [GTFS_filepath5 + f'{agency}.zip' for agency in GTFSs]
GTFS_6 = [GTFS_filepath6 + f'{agency}.zip' for agency in GTFSs]
GTFS_7 = [GTFS_filepath7 + f'{agency}.zip' for agency in GTFSs]
GTFS_8 = [GTFS_filepath8 + f'{agency}.zip' for agency in GTFSs]
GTFS_9 = [GTFS_filepath9 + f'{agency}.zip' for agency in GTFSs]
GTFS_10 = [GTFS_filepath10 + f'{agency}.zip' for agency in GTFSs]
GTFS_11 = [GTFS_filepath10 + f'{agency}.zip' for agency in GTFSs]
GTFS_12 = [GTFS_filepath10 + f'{agency}.zip' for agency in GTFSs]
GTFS_13 = [GTFS_filepath10 + f'{agency}.zip' for agency in GTFSs]
GTFS_14 = [GTFS_filepath10 + f'{agency}.zip' for agency in GTFSs]
GTFS_15 = [GTFS_filepath10 + f'{agency}.zip' for agency in GTFSs]
GTFS_16 = [GTFS_filepath10 + f'{agency}.zip' for agency in GTFSs]
GTFS_17 = [GTFS_filepath10 + f'{agency}.zip' for agency in GTFSs]
GTFS_filepaths = [GTFS_1, GTFS_2, GTFS_3, GTFS_4, GTFS_5, GTFS_6,GTFS_7, GTFS_8, GTFS_9, GTFS_10,
                 GTFS_11, GTFS_12, GTFS_13, GTFS_14, GTFS_15, GTFS_16, GTFS_17]
nrows = None

# %%
#Ridership route
RR = pd.DataFrame()
#Ridership agency
RA = pd.DataFrame()

for fp, name, GTFS_filepath in zip(dataFilepath_sim,names, GTFS_filepaths):
    print('evaluate ridership', name)
    # import pathtraversal and person enter vehicles
    PT, PE = processEvents(fp, nrows)
    print('filter PE transit trips from PT')
    PE, PT = filter_transit(PT, PE)
    print('Guess transit agency for each PE')
    PE = guess_agency(PE)
    PT = guess_agency(PT)
    print('Guess transit route for each PE')
    PE = guess_route(PE, GTFS_filepath)
    PT = guess_route(PT, GTFS_filepath)
    
    dictionary = dict(zip(PT['vehicle'].values, PT['route_id'].values))
    pd.DataFrame(dictionary.items()).to_csv('outputs/routetovehicledict%s.csv'%(name))
    
    print('Route Ridership')
    rr = PE['route_id'].value_counts()
    for route, count in zip(rr.keys(), rr):
        RR.at[route, name] = count
        
    ra = PE['agency'].value_counts()
    for agency, count in zip(ra.keys(), ra):
        RA.at[agency, name] = count
        
        
    # for route, count in zip(rr.keys(), rr):
    #     RR.at[route, name+' shares'] = count/sum_route
    # for agency, count in zip(ra.keys(), ra):
    #     RA.at[agency, name+' shares'] = count/sum_agency

    RA.to_csv(output_filepath+RA_output)
    RR.to_csv(output_filepath+RR_output)

# tot_NTD = 1756364558 + 15283299+5703705+49795740+110802986+7386518+49247910+27027693 + 8437926+50222832 + 2818648
    
# RA.at['BA', 'clipper BA-SF-VT-AC 2016 share target'] = 350485/773719
# RA.at['BA', 'MTC BA-SF-VT-AC 2016 share target'] = 458900/1564500
# RA.at['BA', 'NTD BA-SF-VT-AC 2019 share target'] = (1756364558 + 15283299)/tot_NTD

# RA.at['SF', 'clipper BA-SF-VT-AC 2016 share target'] = 293991/773719
# RA.at['SF', 'MTC BA-SF-VT-AC 2016 share target'] = 777000/1564500
# RA.at['SF', 'NTD BA-SF-VT-AC 2019 share target'] = (5703705+49795740+110802986+7386518+49247910)/tot_NTD

# RA.at['VT', 'clipper BA-SF-VT-AC 2016 share target'] = 43950/773719
# RA.at['VT', 'MTC BA-SF-VT-AC 2016 share target'] = 146700/1564500
# RA.at['VT', 'NTD BA-SF-VT-AC 2019 share target'] = (27027693 + 8437926)/tot_NTD

# RA.at['AC', 'clipper BA-SF-VT-AC 2016 share target'] = 85293/773719
# RA.at['AC',
#       'MTC BA-SF-VT-AC 2016 share target'] = 181900/1564500
# RA.at['AC', 'NTD BA-SF-VT-AC 2019 share target'] = (50222832 + 2818648)/tot_NTD

# RA.at['BA', 'clipper BA-SF-VT-AC 2020 Jan av ridership target'] = 350485
# RA.at['BA', 'MTC BA-SF-VT-AC 2016 av ridership target'] = 458900
# RA.at['BA', 'NTD BA-SF-VT-AC 2019 ridership target'] = (1756364558 + 15283299)

# RA.at['SF', 'clipper BA-SF-VT-AC 2020 Jan av ridership target'] = 293991
# RA.at['SF', 'MTC BA-SF-VT-AC 2016 av ridership target'] = 777000
# RA.at['SF', 'NTD BA-SF-VT-AC 2019 ridership target'] = (5703705+49795740+110802986+7386518+49247910)

# RA.at['VT', 'clipper BA-SF-VT-AC 2020 Jan av ridership target'] = 43950
# RA.at['VT', 'MTC BA-SF-VT-AC 2016 av ridership target'] = 146700
# RA.at['VT', 'NTD BA-SF-VT-AC 2019 ridership target'] =  (27027693 + 8437926)

# RA.at['AC', 'clipper BA-SF-VT-AC 2020 Jan av ridership target'] = 85293
# RA.at['AC', 'MTC BA-SF-VT-AC 2016 av ridership target'] = 181900
# RA.at['AC', 'NTD BA-SF-VT-AC 2019 ridership target'] = (50222832 + 2818648)

RA.to_csv(output_filepath+RA_output)
RR.to_csv(output_filepath+RR_output)
# Out:
# evaluate ridership Baseline_10pct
# read gs://beam-core-outputs/sfbay-baseline-20230526/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz
# /tmp/ipykernel_1098166/2718096371.py:14: DtypeWarning: Columns (0,14,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(dataFilepath_sim, compression = 'gzip',chunksize=2500000, nrows = nrows, usecols = ['vehicle','time','endY','endX','startY','startX','mode', 'length', 'type', 'person']):
# ParkingEvent            865440
# PathTraversal           429256
# PersonEntersVehicle     246693
# PersonLeavesVehicle     167846
# departure               164767
# ModeChoice              120938
# actend                  120649
# LeavingParkingEvent      96045
# arrival                  95668
# actstart                 95664
# PersonCost               80778
# TeleportationEvent       12460
# Replanning                2052
# ReserveRideHail           1734
# ChargingPlugInEvent          4
# RefuelSessionEvent           3
# ChargingPlugOutEvent         3
# Name: type, dtype: int64
# PathTraversal           596728
# PersonEntersVehicle     309515
# PersonLeavesVehicle     262055
# ModeChoice              201335
# actend                  199574
# departure               199574
# actstart                163054
# arrival                 163051
# LeavingParkingEvent     137722
# PersonCost              121077
# ParkingEvent            106967
# TeleportationEvent       31809
# Replanning                5332
# ReserveRideHail           2189
# ChargingPlugInEvent          6
# RefuelSessionEvent           6
# ChargingPlugOutEvent         6
# Name: type, dtype: int64
# PathTraversal           591863
# PersonEntersVehicle     294167
# PersonLeavesVehicle     279658
# ModeChoice              191274
# departure               188455
# actend                  188455
# arrival                 177637
# actstart                177633
# LeavingParkingEvent     134495
# PersonCost              124377
# ParkingEvent            108457
# TeleportationEvent       35556
# Replanning                5390
# ReserveRideHail           2542
# RefuelSessionEvent          14
# ChargingPlugOutEvent        14
# ChargingPlugInEvent         13
# Name: type, dtype: int64
# PathTraversal           640218
# PersonLeavesVehicle     312545
# PersonEntersVehicle     271956
# actstart                189306
# arrival                 189303
# ModeChoice              161145
# actend                  159404
# departure               159404
# PersonCost              134600
# LeavingParkingEvent     130419
# ParkingEvent            116511
# TeleportationEvent       28501
# Replanning                3793
# ReserveRideHail           2871
# ChargingPlugInEvent          8
# RefuelSessionEvent           8
# ChargingPlugOutEvent         8
# Name: type, dtype: int64
# PathTraversal           633987
# PersonEntersVehicle     290887
# PersonLeavesVehicle     285982
# ModeChoice              176453
# actend                  174574
# departure               174574
# actstart                170888
# arrival                 170886
# LeavingParkingEvent     143547
# PersonCost              129596
# ParkingEvent            117502
# TeleportationEvent       24518
# ReserveRideHail           3697
# Replanning                2883
# ChargingPlugInEvent         10
# RefuelSessionEvent           8
# ChargingPlugOutEvent         8
# Name: type, dtype: int64
# PathTraversal           630600
# PersonEntersVehicle     288397
# PersonLeavesVehicle     285872
# ModeChoice              175913
# actend                  174885
# departure               174885
# actstart                172713
# arrival                 172713
# LeavingParkingEvent     142659
# PersonCost              130324
# ParkingEvent            118990
# TeleportationEvent       25764
# ReserveRideHail           3635
# Replanning                2633
# ChargingPlugInEvent          7
# RefuelSessionEvent           5
# ChargingPlugOutEvent         5
# Name: type, dtype: int64
# PathTraversal           621201
# PersonEntersVehicle     290792
# PersonLeavesVehicle     285144
# ModeChoice              178928
# actend                  177789
# departure               177789
# arrival                 172614
# actstart                172603
# LeavingParkingEvent     141786
# PersonCost              130492
# ParkingEvent            119643
# TeleportationEvent       26105
# ReserveRideHail           3227
# Replanning                1858
# RefuelSessionEvent          11
# ChargingPlugOutEvent        11
# ChargingPlugInEvent          7
# Name: type, dtype: int64
# PathTraversal           619114
# PersonLeavesVehicle     286674
# PersonEntersVehicle     284929
# ModeChoice              178669
# actstart                177936
# arrival                 177928
# actend                  177512
# departure               177512
# LeavingParkingEvent     137018
# PersonCost              129816
# ParkingEvent            118036
# TeleportationEvent       29691
# ReserveRideHail           3259
# Replanning                1865
# ChargingPlugInEvent         15
# RefuelSessionEvent          13
# ChargingPlugOutEvent        13
# Name: type, dtype: int64
# PathTraversal           603805
# PersonEntersVehicle     286549
# PersonLeavesVehicle     276552
# ModeChoice              188640
# departure               188269
# actend                  188269
# arrival                 179582
# actstart                179578
# LeavingParkingEvent     132188
# PersonCost              123938
# ParkingEvent            111242
# TeleportationEvent       35823
# ReserveRideHail           3503
# Replanning                2027
# RefuelSessionEvent          13
# ChargingPlugOutEvent        13
# ChargingPlugInEvent          9
# Name: type, dtype: int64
# PathTraversal           616188
# PersonEntersVehicle     291869
# PersonLeavesVehicle     284161
# ModeChoice              181888
# departure               181149
# actend                  181149
# actstart                177380
# arrival                 177373
# LeavingParkingEvent     134251
# PersonCost              126610
# ParkingEvent            113327
# TeleportationEvent       30068
# ReserveRideHail           2959
# Replanning                1597
# ChargingPlugInEvent         11
# RefuelSessionEvent          10
# ChargingPlugOutEvent        10
# Name: type, dtype: int64
# PathTraversal           611650
# PersonEntersVehicle     303871
# PersonLeavesVehicle     279946
# ModeChoice              185623
# departure               184420
# actend                  184420
# arrival                 169417
# actstart                169411
# LeavingParkingEvent     138296
# PersonCost              127502
# ParkingEvent            113374
# TeleportationEvent       27018
# ReserveRideHail           2907
# Replanning                2113
# ChargingPlugInEvent         12
# RefuelSessionEvent          10
# ChargingPlugOutEvent        10
# Name: type, dtype: int64
# PathTraversal           608008
# PersonEntersVehicle     299085
# PersonLeavesVehicle     291261
# ModeChoice              181992
# actend                  180361
# departure               180360
# actstart                173748
# arrival                 173742
# LeavingParkingEvent     135054
# PersonCost              130592
# ParkingEvent            115945
# TeleportationEvent       24341
# ReserveRideHail           2906
# Replanning                2577
# RefuelSessionEvent          10
# ChargingPlugOutEvent        10
# ChargingPlugInEvent          8
# Name: type, dtype: int64
# PathTraversal           644143
# PersonLeavesVehicle     316936
# PersonEntersVehicle     273308
# arrival                 187678
# actstart                187665
# ModeChoice              157731
# departure               156258
# actend                  156257
# PersonCost              138394
# LeavingParkingEvent     128788
# ParkingEvent            123472
# TeleportationEvent       23905
# Replanning                2870
# ReserveRideHail           2568
# ChargingPlugInEvent          9
# RefuelSessionEvent           9
# ChargingPlugOutEvent         9
# Name: type, dtype: int64
# PathTraversal           624071
# PersonLeavesVehicle     301083
# PersonEntersVehicle     282736
# actstart                182354
# arrival                 182343
# ModeChoice              172763
# actend                  170838
# departure               170838
# PersonCost              132723
# LeavingParkingEvent     129019
# ParkingEvent            119399
# TeleportationEvent       25045
# Replanning                3986
# ReserveRideHail           2776
# RefuelSessionEvent           9
# ChargingPlugOutEvent         9
# ChargingPlugInEvent          8
# Name: type, dtype: int64
# PathTraversal           495156
# PersonLeavesVehicle     234827
# PersonEntersVehicle     179932
# actstart                145148
# arrival                 145146
# ModeChoice              101780
# actend                  100972
# departure               100972
# PersonCost               96545
# ParkingEvent             88294
# LeavingParkingEvent      87096
# TeleportationEvent       15573
# Replanning                2801
# ReserveRideHail           1221
# ChargingPlugInEvent          2
# RefuelSessionEvent           2
# ChargingPlugOutEvent         2
# Name: type, dtype: int64
#          vehicle    time
# 887863    121927   18000
# 887864    192532   18000
# 887865    594467   18000
# 887866    136799   18003
# 887867    218634   18003
# ...          ...     ...
# 36795165   34048  200283
# 36795194   34048  200590
# 36795262  199715  202529
# 36795312  199715  204950
# 36795329  199715  205384
#
# [2011368 rows x 2 columns]
# filter PE transit trips from PT
# car          2655947
# walk         2136186
# bus          1286361
# car_hov2      400194
# car_hov3      284008
# tram           54924
# bike           40763
# cable_car      17836
# subway         14358
# rail            1702
# ferry             73
# Name: mode, dtype: int64
# bus          1286361
# tram           54924
# cable_car      17836
# subway         14358
# rail            1702
# ferry             73
# Name: mode, dtype: int64
# Guess transit agency for each PE
# AGENCIES ['AC' 'AM' 'AY' 'BA' 'CA' 'CC' 'CE' 'CM' 'DE' 'EM' 'FF' 'GG' 'MA' 'PE'
#  'RV' 'SB' 'SC' 'SF' 'SL' 'SM' 'SO' 'SR' 'ST' 'TD' 'UC' 'VC' 'VN' 'VT'
#  'WC' 'WH']
# AGENCIES ['AC' 'AM' 'AY' 'BA' 'CA' 'CC' 'CE' 'CM' 'DE' 'EM' 'FF' 'GG' 'HF' 'MA'
#  'PE' 'RV' 'SB' 'SC' 'SF' 'SL' 'SM' 'SO' 'SR' 'ST' 'TD' 'UC' 'VC' 'VN'
#  'VT' 'WC' 'WH']
# Guess transit route for each PE
# 10000 / 276338 . Time =  0.010488271713256836 . Estimated remaining time: 0.2793726121902466
# 20000 / 276338 . Time =  0.022443056106567383 . Estimated remaining time: 0.28765885791778567
# 30000 / 276338 . Time =  0.031768798828125 . Estimated remaining time: 0.2608637981573741
# 40000 / 276338 . Time =  0.04109930992126465 . Estimated remaining time: 0.2428355582356453
# 50000 / 276338 . Time =  0.051336050033569336 . Estimated remaining time: 0.2323868186950684
# 60000 / 276338 . Time =  0.060242652893066406 . Estimated remaining time: 0.21721377700964611
# 70000 / 276338 . Time =  0.06900930404663086 . Estimated remaining time: 0.20341820405551364
# 80000 / 276338 . Time =  0.07801532745361328 . Estimated remaining time: 0.1914675137341022
# 90000 / 276338 . Time =  0.08707427978515625 . Estimated remaining time: 0.18028077905972795
# 100000 / 276338 . Time =  0.09614849090576172 . Estimated remaining time: 0.16954650789737702
# 110000 / 276338 . Time =  0.10520458221435547 . Estimated remaining time: 0.15908690413128246
# 120000 / 276338 . Time =  0.11429214477539062 . Estimated remaining time: 0.14890178327957787
# 130000 / 276338 . Time =  0.12349319458007812 . Estimated remaining time: 0.13901323084097644
# 140000 / 276338 . Time =  0.13273406028747559 . Estimated remaining time: 0.12926211027417867
# 150000 / 276338 . Time =  0.1421065330505371 . Estimated remaining time: 0.1196899019591014
# 160000 / 276338 . Time =  0.15135502815246582 . Estimated remaining time: 0.11005230626463891
# 170000 / 276338 . Time =  0.160597562789917 . Estimated remaining time: 0.10045613276257237
# 180000 / 276338 . Time =  0.1697533130645752 . Estimated remaining time: 0.0908537484857771
# 190000 / 276338 . Time =  0.17855477333068848 . Estimated remaining time: 0.08113738520521868
# 200000 / 276338 . Time =  0.18738389015197754 . Estimated remaining time: 0.07152240961551665
# 210000 / 276338 . Time =  0.1962423324584961 . Estimated remaining time: 0.06199185523305617
# 220000 / 276338 . Time =  0.20497822761535645 . Estimated remaining time: 0.05249108090617444
# 230000 / 276338 . Time =  0.2138044834136963 . Estimated remaining time: 0.0430749059303947
# 240000 / 276338 . Time =  0.22304034233093262 . Estimated remaining time: 0.03376948734124502
# 250000 / 276338 . Time =  0.23223042488098145 . Estimated remaining time: 0.024465538238525375
# 260000 / 276338 . Time =  0.2415452003479004 . Estimated remaining time: 0.015177881908416735
# 270000 / 276338 . Time =  0.2504415512084961 . Estimated remaining time: 0.005878406687136073
# 10000 / 1375254 . Time =  0.009376287460327148 . Estimated remaining time: 1.2801660195827484
# 20000 / 1375254 . Time =  0.01885986328125 . Estimated remaining time: 1.2780270925045012
# 30000 / 1375254 . Time =  0.028157711029052734 . Estimated remaining time: 1.2626419695854187
# 40000 / 1375254 . Time =  0.03775477409362793 . Estimated remaining time: 1.260313048505783
# 50000 / 1375254 . Time =  0.04713177680969238 . Estimated remaining time: 1.2492312764644622
# 60000 / 1375254 . Time =  0.05652141571044922 . Estimated remaining time: 1.2390052895784378
# 70000 / 1375254 . Time =  0.06597685813903809 . Estimated remaining time: 1.230240750013079
# 80000 / 1375254 . Time =  0.07550716400146484 . Estimated remaining time: 1.222515574258566
# 90000 / 1375254 . Time =  0.0848550796508789 . Estimated remaining time: 1.211784616804123
# 100000 / 1375254 . Time =  0.09434008598327637 . Estimated remaining time: 1.203075243268013
# 110000 / 1375254 . Time =  0.10393786430358887 . Estimated remaining time: 1.1955279454144565
# 120000 / 1375254 . Time =  0.11360907554626465 . Estimated remaining time: 1.1884068038105964
# 130000 / 1375254 . Time =  0.12323117256164551 . Estimated remaining time: 1.1804182804181027
# 140000 / 1375254 . Time =  0.13304495811462402 . Estimated remaining time: 1.173889841570173
# 150000 / 1375254 . Time =  0.14289498329162598 . Estimated remaining time: 1.1672191363716125
# 160000 / 1375254 . Time =  0.15278077125549316 . Estimated remaining time: 1.1604212827771903
# 170000 / 1375254 . Time =  0.16260433197021484 . Estimated remaining time: 1.1528202380124262
# 180000 / 1375254 . Time =  0.17254400253295898 . Estimated remaining time: 1.1457452847719194
# 190000 / 1375254 . Time =  0.18237853050231934 . Estimated remaining time: 1.1377113967293189
# 200000 / 1375254 . Time =  0.19237375259399414 . Estimated remaining time: 1.1304412737488747
# 210000 / 1375254 . Time =  0.20209884643554688 . Estimated remaining time: 1.1214129378795625
# 220000 / 1375254 . Time =  0.21163368225097656 . Estimated remaining time: 1.111322186077725
# 230000 / 1375254 . Time =  0.221588134765625 . Estimated remaining time: 1.1033696715106134
# 240000 / 1375254 . Time =  0.23157095909118652 . Estimated remaining time: 1.0953833909034727
# 250000 / 1375254 . Time =  0.2415943145751953 . Estimated remaining time: 1.0874204717006681
# 260000 / 1375254 . Time =  0.25173330307006836 . Estimated remaining time: 1.0797960807653573
# 270000 / 1375254 . Time =  0.2617495059967041 . Estimated remaining time: 1.071495704952876
# 280000 / 1375254 . Time =  0.27146005630493164 . Estimated remaining time: 1.061849667428221
# 290000 / 1375254 . Time =  0.28136706352233887 . Estimated remaining time: 1.0529480026179345
# 300000 / 1375254 . Time =  0.2909872531890869 . Estimated remaining time: 1.0429513092517853
# 310000 / 1375254 . Time =  0.3009026050567627 . Estimated remaining time: 1.033993754130025
# 320000 / 1375254 . Time =  0.31080198287963867 . Estimated remaining time: 1.024923081994057
# 330000 / 1375254 . Time =  0.32060766220092773 . Estimated remaining time: 1.0155046460541812
# 340000 / 1375254 . Time =  0.33011364936828613 . Estimated remaining time: 1.0051526133775712
# 350000 / 1375254 . Time =  0.33971381187438965 . Estimated remaining time: 0.995123158493042
# 360000 / 1375254 . Time =  0.3496367931365967 . Estimated remaining time: 0.9860283977031707
# 370000 / 1375254 . Time =  0.35935211181640625 . Estimated remaining time: 0.9763251331574208
# 380000 / 1375254 . Time =  0.3689243793487549 . Estimated remaining time: 0.9662463445588161
# 390000 / 1375254 . Time =  0.3786027431488037 . Estimated remaining time: 0.9564615615844727
# 400000 / 1375254 . Time =  0.38810157775878906 . Estimated remaining time: 0.9462443831670284
# 410000 / 1375254 . Time =  0.39752745628356934 . Estimated remaining time: 0.9358907254195796
# 420000 / 1375254 . Time =  0.4071345329284668 . Estimated remaining time: 0.9259929017441615
# 430000 / 1375254 . Time =  0.416797399520874 . Estimated remaining time: 0.9162314696112344
# 440000 / 1375254 . Time =  0.42646288871765137 . Estimated remaining time: 0.9064800922783938
# 450000 / 1375254 . Time =  0.4360055923461914 . Estimated remaining time: 0.8964800703334808
# 460000 / 1375254 . Time =  0.44608306884765625 . Estimated remaining time: 0.8875641960372096
# 470000 / 1375254 . Time =  0.45604586601257324 . Estimated remaining time: 0.8783780084965076
# 480000 / 1375254 . Time =  0.46562647819519043 . Estimated remaining time: 0.8684468604266644
# 490000 / 1375254 . Time =  0.4749171733856201 . Estimated remaining time: 0.8580049421310425
# 500000 / 1375254 . Time =  0.4841492176055908 . Estimated remaining time: 0.8475072575473788
# 510000 / 1375254 . Time =  0.49387097358703613 . Estimated remaining time: 0.8378904438663932
# 520000 / 1375254 . Time =  0.5036492347717285 . Estimated remaining time: 0.828361735704312
# 530000 / 1375254 . Time =  0.5134036540985107 . Estimated remaining time: 0.8187863564680207
# 540000 / 1375254 . Time =  0.5231702327728271 . Estimated remaining time: 0.8092224074045817
# 550000 / 1375254 . Time =  0.5329713821411133 . Estimated remaining time: 0.7997034477251228
# 560000 / 1375254 . Time =  0.5427911281585693 . Estimated remaining time: 0.7902012486662184
# 570000 / 1375254 . Time =  0.5525166988372803 . Estimated remaining time: 0.7805549787621748
# 580000 / 1375254 . Time =  0.5622658729553223 . Estimated remaining time: 0.7709380107731654
# 590000 / 1375254 . Time =  0.5720946788787842 . Estimated remaining time: 0.7614231890177321
# 600000 / 1375254 . Time =  0.581845760345459 . Estimated remaining time: 0.7517971581244469
# 610000 / 1375254 . Time =  0.591240644454956 . Estimated remaining time: 0.7417201723724116
# 620000 / 1375254 . Time =  0.6007945537567139 . Estimated remaining time: 0.7318589066936125
# 630000 / 1375254 . Time =  0.61045241355896 . Estimated remaining time: 0.72213008382661
# 640000 / 1375254 . Time =  0.6201555728912354 . Estimated remaining time: 0.7124563138887285
# 650000 / 1375254 . Time =  0.6299088001251221 . Estimated remaining time: 0.7028364953136443
# 660000 / 1375254 . Time =  0.640601396560669 . Estimated remaining time: 0.6942314007108861
# 670000 / 1375254 . Time =  0.6513400077819824 . Estimated remaining time: 0.6856119446540947
# 680000 / 1375254 . Time =  0.66206955909729 . Estimated remaining time: 0.6769223228826242
# 690000 / 1375254 . Time =  0.6736433506011963 . Estimated remaining time: 0.6690096158442291
# 700000 / 1375254 . Time =  0.6859755516052246 . Estimated remaining time: 0.6617250890438897
# 710000 / 1375254 . Time =  0.6969854831695557 . Estimated remaining time: 0.6530600927232018
# 720000 / 1375254 . Time =  0.7086927890777588 . Estimated remaining time: 0.6449634828209876
# 730000 / 1375254 . Time =  0.719214677810669 . Estimated remaining time: 0.6357204841992627
# 740000 / 1375254 . Time =  0.7301647663116455 . Estimated remaining time: 0.6268108628537203
# 750000 / 1375254 . Time =  0.7411696910858154 . Estimated remaining time: 0.6178923790512085
# 760000 / 1375254 . Time =  0.7525122165679932 . Estimated remaining time: 0.6091922589239323
# 770000 / 1375254 . Time =  0.7627294063568115 . Estimated remaining time: 0.5995389413462056
# 780000 / 1375254 . Time =  0.7732462882995605 . Estimated remaining time: 0.590100056369488
# 790000 / 1375254 . Time =  0.7844979763031006 . Estimated remaining time: 0.5811778858329677
# 800000 / 1375254 . Time =  0.7948133945465088 . Estimated remaining time: 0.5715244136035442
# 810000 / 1375254 . Time =  0.8042862415313721 . Estimated remaining time: 0.5612664469771915
# 820000 / 1375254 . Time =  0.8137631416320801 . Estimated remaining time: 0.5510305413909076
# 830000 / 1375254 . Time =  0.8232457637786865 . Estimated remaining time: 0.5408166840915221
# 840000 / 1375254 . Time =  0.8327133655548096 . Estimated remaining time: 0.5306108179875784
# 850000 / 1375254 . Time =  0.8422787189483643 . Estimated remaining time: 0.5204825750788522
# 860000 / 1375254 . Time =  0.8519961833953857 . Estimated remaining time: 0.510458557308552
# 870000 / 1375254 . Time =  0.8616323471069336 . Estimated remaining time: 0.5003945096607865
# 880000 / 1375254 . Time =  0.8712587356567383 . Estimated remaining time: 0.4903347841186958
# 890000 / 1375254 . Time =  0.8807785511016846 . Estimated remaining time: 0.4802260882441918
# 900000 / 1375254 . Time =  0.8909246921539307 . Estimated remaining time: 0.470461229481697
# 910000 / 1375254 . Time =  0.9006328582763672 . Estimated remaining time: 0.4604648843230781
# 920000 / 1375254 . Time =  0.9102261066436768 . Estimated remaining time: 0.4504173534237821
# 930000 / 1375254 . Time =  0.919933557510376 . Estimated remaining time: 0.44043450193558953
# 940000 / 1375254 . Time =  0.9293498992919922 . Estimated remaining time: 0.43032249013363044
# 950000 / 1375254 . Time =  0.9388923645019531 . Estimated remaining time: 0.4202816931207556
# 960000 / 1375254 . Time =  0.9483809471130371 . Estimated remaining time: 0.41022797076553097
# 970000 / 1375254 . Time =  0.958057165145874 . Estimated remaining time: 0.40026429253411044
# 980000 / 1375254 . Time =  0.9675772190093994 . Estimated remaining time: 0.3902432582222686
# 990000 / 1375254 . Time =  0.976902961730957 . Estimated remaining time: 0.38015710867101493
# 1000000 / 1375254 . Time =  0.9865350723266602 . Estimated remaining time: 0.3702009936122894
# 1010000 / 1375254 . Time =  0.996201753616333 . Estimated remaining time: 0.36026388276827226
# 1020000 / 1375254 . Time =  1.0057799816131592 . Estimated remaining time: 0.3503011795100044
# 1030000 / 1375254 . Time =  1.0154178142547607 . Estimated remaining time: 0.3403657626508507
# 1040000 / 1375254 . Time =  1.025026798248291 . Estimated remaining time: 0.3304270060236636
# 1050000 / 1375254 . Time =  1.0345966815948486 . Estimated remaining time: 0.32048234165327893
# 1060000 / 1375254 . Time =  1.0440199375152588 . Estimated remaining time: 0.31050114024315234
# 1070000 / 1375254 . Time =  1.0533804893493652 . Estimated remaining time: 0.3005127856767065
# 1080000 / 1375254 . Time =  1.0626893043518066 . Estimated remaining time: 0.2905213710824648
# 1090000 / 1375254 . Time =  1.0722737312316895 . Estimated remaining time: 0.280614843176483
# 1100000 / 1375254 . Time =  1.081773042678833 . Estimated remaining time: 0.27069281348098406
# 1110000 / 1375254 . Time =  1.0912396907806396 . Estimated remaining time: 0.260770656120455
# 1120000 / 1375254 . Time =  1.10068678855896 . Estimated remaining time: 0.25085223156724656
# 1130000 / 1375254 . Time =  1.1109402179718018 . Estimated remaining time: 0.24111686005803312
# 1140000 / 1375254 . Time =  1.1207983493804932 . Estimated remaining time: 0.2312908206864408
# 1150000 / 1375254 . Time =  1.1303939819335938 . Estimated remaining time: 0.2214135645518096
# 1160000 / 1375254 . Time =  1.140151023864746 . Estimated remaining time: 0.21157055452239915
# 1170000 / 1375254 . Time =  1.1497526168823242 . Estimated remaining time: 0.2017017894121318
# 1180000 / 1375254 . Time =  1.1594665050506592 . Estimated remaining time: 0.19185613406391466
# 1190000 / 1375254 . Time =  1.1691310405731201 . Estimated remaining time: 0.18200501028589833
# 1200000 / 1375254 . Time =  1.1786458492279053 . Estimated remaining time: 0.1721351294517517
# 1210000 / 1375254 . Time =  1.188093900680542 . Estimated remaining time: 0.16226223872949275
# 1220000 / 1375254 . Time =  1.1975178718566895 . Estimated remaining time: 0.15239274492341948
# 1230000 / 1375254 . Time =  1.2068555355072021 . Estimated remaining time: 0.14252033125598262
# 1240000 / 1375254 . Time =  1.2163217067718506 . Estimated remaining time: 0.13267129707644054
# 1250000 / 1375254 . Time =  1.225724458694458 . Estimated remaining time: 0.12282129855117785
# 1260000 / 1375254 . Time =  1.2352056503295898 . Estimated remaining time: 0.11298557038647794
# 1270000 / 1375254 . Time =  1.2445907592773438 . Estimated remaining time: 0.10314793549597745
# 1280000 / 1375254 . Time =  1.253854751586914 . Estimated remaining time: 0.09330812347047024
# 1290000 / 1375254 . Time =  1.2631983757019043 . Estimated remaining time: 0.0834825173755025
# 1300000 / 1375254 . Time =  1.2723338603973389 . Estimated remaining time: 0.07365224640626167
# 1310000 / 1375254 . Time =  1.2814514636993408 . Estimated remaining time: 0.06383194608397158
# 1320000 / 1375254 . Time =  1.2903714179992676 . Estimated remaining time: 0.05401354605392972
# 1330000 / 1375254 . Time =  1.2992916107177734 . Estimated remaining time: 0.044208899431658955
# 1340000 / 1375254 . Time =  1.3088767528533936 . Estimated remaining time: 0.03443494146581916
# 1350000 / 1375254 . Time =  1.317641258239746 . Estimated remaining time: 0.02464868026415501
# 1360000 / 1375254 . Time =  1.3268423080444336 . Estimated remaining time: 0.014881623312655634
# 1370000 / 1375254 . Time =  1.3353097438812256 . Estimated remaining time: 0.005120485678902664
# Route Ridership
# evaluate ridership TRspeed-0_25
# read gs://beam-core-outputs/sfbay-tr-speed0_25-20230626/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz
# /tmp/ipykernel_1098166/2718096371.py:14: DtypeWarning: Columns (0,22,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(dataFilepath_sim, compression = 'gzip',chunksize=2500000, nrows = nrows, usecols = ['vehicle','time','endY','endX','startY','startX','mode', 'length', 'type', 'person']):
# ParkingEvent            865378
# PathTraversal           433655
# PersonEntersVehicle     239514
# PersonLeavesVehicle     170579
# departure               157418
# ModeChoice              122293
# actend                  121562
# arrival                  97069
# actstart                 97068
# LeavingParkingEvent      96617
# PersonCost               79493
# TeleportationEvent       12431
# Replanning                4566
# ReserveRideHail           2342
# ChargingPlugInEvent          5
# RefuelSessionEvent           5
# ChargingPlugOutEvent         5
# Name: type, dtype: int64
# PathTraversal           586292
# PersonEntersVehicle     306253
# PersonLeavesVehicle     266669
# ModeChoice              200939
# actend                  197861
# departure               197861
# arrival                 166380
# actstart                166380
# LeavingParkingEvent     138061
# PersonCost              118597
# ParkingEvent            108081
# TeleportationEvent       31615
# Replanning               11319
# ReserveRideHail           3670
# ChargingPlugInEvent          8
# RefuelSessionEvent           7
# ChargingPlugOutEvent         7
# Name: type, dtype: int64
# PathTraversal           577095
# PersonEntersVehicle     293288
# PersonLeavesVehicle     278277
# ModeChoice              194832
# departure               190639
# actend                  190639
# actstart                178232
# arrival                 178232
# LeavingParkingEvent     136775
# PersonCost              121171
# ParkingEvent            110275
# TeleportationEvent       35597
# Replanning               11023
# ReserveRideHail           3887
# RefuelSessionEvent          13
# ChargingPlugOutEvent        13
# ChargingPlugInEvent         12
# Name: type, dtype: int64
# PathTraversal           619836
# PersonLeavesVehicle     305916
# PersonEntersVehicle     274721
# arrival                 189420
# actstart                189420
# ModeChoice              167763
# actend                  165696
# departure               165693
# LeavingParkingEvent     134693
# PersonCost              130300
# ParkingEvent            118679
# TeleportationEvent       28270
# Replanning                5935
# ReserveRideHail           3623
# RefuelSessionEvent          12
# ChargingPlugOutEvent        12
# ChargingPlugInEvent         11
# Name: type, dtype: int64
# PathTraversal           619869
# PersonEntersVehicle     289938
# PersonLeavesVehicle     287341
# ModeChoice              177627
# actend                  175414
# departure               175412
# actstart                173876
# arrival                 173875
# LeavingParkingEvent     144885
# PersonCost              129138
# ParkingEvent            120316
# TeleportationEvent       25154
# ReserveRideHail           3791
# Replanning                3354
# ChargingPlugInEvent          4
# RefuelSessionEvent           3
# ChargingPlugOutEvent         3
# Name: type, dtype: int64
# PathTraversal           616109
# PersonEntersVehicle     289858
# PersonLeavesVehicle     286802
# ModeChoice              177504
# departure               176866
# actend                  176861
# arrival                 174656
# actstart                174654
# LeavingParkingEvent     144462
# PersonCost              128777
# ParkingEvent            120246
# TeleportationEvent       25877
# ReserveRideHail           3953
# Replanning                3350
# ChargingPlugInEvent          9
# RefuelSessionEvent           8
# ChargingPlugOutEvent         8
# Name: type, dtype: int64
# PathTraversal           605666
# PersonEntersVehicle     291562
# PersonLeavesVehicle     286005
# ModeChoice              181131
# departure               180204
# actend                  180204
# actstart                174606
# arrival                 174604
# LeavingParkingEvent     143358
# PersonCost              129182
# ParkingEvent            121038
# TeleportationEvent       26459
# ReserveRideHail           3440
# Replanning                2497
# RefuelSessionEvent          15
# ChargingPlugOutEvent        15
# ChargingPlugInEvent         14
# Name: type, dtype: int64
# PathTraversal           608213
# PersonLeavesVehicle     288259
# PersonEntersVehicle     283134
# arrival                 181519
# actstart                181519
# ModeChoice              179033
# actend                  177897
# departure               177897
# LeavingParkingEvent     138126
# PersonCost              127965
# ParkingEvent            119652
# TeleportationEvent       30582
# ReserveRideHail           3630
# Replanning                2547
# RefuelSessionEvent           9
# ChargingPlugOutEvent         9
# ChargingPlugInEvent          9
# Name: type, dtype: int64
# PathTraversal           587913
# PersonEntersVehicle     287654
# PersonLeavesVehicle     274820
# ModeChoice              194114
# actend                  192312
# departure               192308
# arrival                 181253
# actstart                181249
# LeavingParkingEvent     133226
# PersonCost              120002
# ParkingEvent            111615
# TeleportationEvent       36640
# ReserveRideHail           4007
# Replanning                2859
# ChargingPlugInEvent         10
# RefuelSessionEvent           9
# ChargingPlugOutEvent         9
# Name: type, dtype: int64
# PathTraversal           604748
# PersonEntersVehicle     293668
# PersonLeavesVehicle     283278
# ModeChoice              183741
# departure               182849
# actend                  182845
# arrival                 177888
# actstart                177863
# LeavingParkingEvent     137476
# PersonCost              124350
# ParkingEvent            115279
# TeleportationEvent       30028
# ReserveRideHail           3521
# Replanning                2442
# RefuelSessionEvent           9
# ChargingPlugOutEvent         9
# ChargingPlugInEvent          6
# Name: type, dtype: int64
# PathTraversal           595267
# PersonEntersVehicle     301159
# PersonLeavesVehicle     283346
# ModeChoice              189400
# departure               186364
# actend                  186364
# actstart                172654
# arrival                 172628
# LeavingParkingEvent     138880
# PersonCost              125818
# ParkingEvent            115445
# TeleportationEvent       26381
# ReserveRideHail           3357
# Replanning                2897
# ChargingPlugInEvent         16
# RefuelSessionEvent          12
# ChargingPlugOutEvent        12
# Name: type, dtype: int64
# PathTraversal           598523
# PersonEntersVehicle     297513
# PersonLeavesVehicle     292604
# ModeChoice              180533
# actend                  179705
# departure               179705
# arrival                 176495
# actstart                176494
# LeavingParkingEvent     138246
# PersonCost              129112
# ParkingEvent            118881
# TeleportationEvent       25157
# Replanning                3772
# ReserveRideHail           3223
# RefuelSessionEvent          13
# ChargingPlugOutEvent        13
# ChargingPlugInEvent         11
# Name: type, dtype: int64
# PathTraversal           626051
# PersonLeavesVehicle     316662
# PersonEntersVehicle     272466
# actstart                190478
# arrival                 190474
# ModeChoice              161137
# actend                  159214
# departure               159210
# PersonCost              137112
# LeavingParkingEvent     130417
# ParkingEvent            127006
# TeleportationEvent       23639
# Replanning                3297
# ReserveRideHail           2811
# RefuelSessionEvent           9
# ChargingPlugOutEvent         9
# ChargingPlugInEvent          8
# Name: type, dtype: int64
# PathTraversal           611048
# PersonLeavesVehicle     299847
# PersonEntersVehicle     283730
# arrival                 184710
# actstart                184700
# ModeChoice              174479
# departure               172089
# actend                  172085
# LeavingParkingEvent     132212
# PersonCost              130722
# ParkingEvent            120849
# TeleportationEvent       26305
# Replanning                4319
# ReserveRideHail           2873
# RefuelSessionEvent          11
# ChargingPlugOutEvent        11
# ChargingPlugInEvent         10
# Name: type, dtype: int64
# PathTraversal           375294
# PersonLeavesVehicle     180860
# PersonEntersVehicle     132693
# actstart                113485
# arrival                 113475
# ModeChoice               74552
# actend                   74049
# departure                74049
# PersonCost               72648
# ParkingEvent             68089
# LeavingParkingEvent      66015
# TeleportationEvent       10648
# Replanning                1718
# ReserveRideHail            716
# RefuelSessionEvent           1
# ChargingPlugOutEvent         1
# Name: type, dtype: int64
#          vehicle    time
# 872446    414187   18003
# 872447    328505   18000
# 872448    584347   18003
# 872449    244503   18000
# 872452    572096   18003
# ...          ...     ...
# 36358082  144337  203364
# 36358126  144337  205314
# 36358133   33928  205429
# 36358177  144337  206228
# 36358187   33928  206464
#
# [1963107 rows x 2 columns]
# filter PE transit trips from PT
# car          2670565
# walk         2082523
# bus          1028406
# car_hov2      396865
# car_hov3      283368
# tram           45020
# bike           40962
# cable_car      17836
# subway         14358
# rail            1702
# ferry             73
# Name: mode, dtype: int64
# bus          1028406
# tram           45020
# cable_car      17836
# subway         14358
# rail            1702
# ferry             73
# Name: mode, dtype: int64
# Guess transit agency for each PE
# AGENCIES ['AC' 'AM' 'AY' 'BA' 'CA' 'CC' 'CE' 'CM' 'DE' 'EM' 'FF' 'GG' 'MA' 'PE'
#  'RV' 'SB' 'SC' 'SF' 'SM' 'SR' 'ST' 'TD' 'UC' 'VC' 'VT' 'WC' 'WH']
# AGENCIES ['AC' 'AM' 'AY' 'BA' 'CA' 'CC' 'CE' 'CM' 'DE' 'EM' 'FF' 'GG' 'HF' 'MA'
#  'PE' 'RV' 'SB' 'SC' 'SF' 'SM' 'SO' 'SR' 'ST' 'TD' 'UC' 'VC' 'VT' 'WC'
#  'WH']
# Guess transit route for each PE
# 10000 / 222062 . Time =  0.009073019027709961 . Estimated remaining time: 0.1924189471244812
# 20000 / 222062 . Time =  0.017820358276367188 . Estimated remaining time: 0.18004303205013275
# 30000 / 222062 . Time =  0.026395797729492188 . Estimated remaining time: 0.1689889447371165
# 40000 / 222062 . Time =  0.035575151443481445 . Estimated remaining time: 0.16192377406358718
# 50000 / 222062 . Time =  0.04455256462097168 . Estimated remaining time: 0.1533164110946655
# 60000 / 222062 . Time =  0.052954912185668945 . Estimated remaining time: 0.14303403251171112
# 70000 / 222062 . Time =  0.06158328056335449 . Estimated remaining time: 0.13377851963043214
# 80000 / 222062 . Time =  0.07029938697814941 . Estimated remaining time: 0.12483607887029649
# 90000 / 222062 . Time =  0.07915472984313965 . Estimated remaining time: 0.11614848242865669
# 100000 / 222062 . Time =  0.08790969848632812 . Estimated remaining time: 0.10730438876628876
# 110000 / 222062 . Time =  0.09675383567810059 . Estimated remaining time: 0.09856753924543207
# 120000 / 222062 . Time =  0.1054694652557373 . Estimated remaining time: 0.08970370516379675
# 130000 / 222062 . Time =  0.11441349983215332 . Estimated remaining time: 0.08102405058787421
# 140000 / 222062 . Time =  0.12334537506103516 . Estimated remaining time: 0.07229967396259307
# 150000 / 222062 . Time =  0.13224434852600098 . Estimated remaining time: 0.06353147145271301
# 160000 / 222062 . Time =  0.14107084274291992 . Estimated remaining time: 0.054719232156872744
# 170000 / 222062 . Time =  0.14980053901672363 . Estimated remaining time: 0.04587580908046049
# 180000 / 222062 . Time =  0.15834617614746094 . Estimated remaining time: 0.037002038274870974
# 190000 / 222062 . Time =  0.16703057289123535 . Estimated remaining time: 0.028185731202677672
# 200000 / 222062 . Time =  0.17566752433776855 . Estimated remaining time: 0.019377460372447974
# 210000 / 222062 . Time =  0.1843712329864502 . Estimated remaining time: 0.01058972140947978
# 220000 / 222062 . Time =  0.19296526908874512 . Estimated remaining time: 0.0018083746563304637
# 10000 / 1107395 . Time =  0.008804559707641602 . Estimated remaining time: 0.9662593542337418
# 20000 / 1107395 . Time =  0.01747274398803711 . Estimated remaining time: 0.9500144095420837
# 30000 / 1107395 . Time =  0.02599024772644043 . Estimated remaining time: 0.9334004222551981
# 40000 / 1107395 . Time =  0.03485107421875 . Estimated remaining time: 0.9300026828944683
# 50000 / 1107395 . Time =  0.0434262752532959 . Estimated remaining time: 0.9183793300628662
# 60000 / 1107395 . Time =  0.052227020263671875 . Estimated remaining time: 0.9117092550396919
# 70000 / 1107395 . Time =  0.060964107513427734 . Estimated remaining time: 0.9034834803513118
# 80000 / 1107395 . Time =  0.06970024108886719 . Estimated remaining time: 0.8951238133758307
# 90000 / 1107395 . Time =  0.07827091217041016 . Estimated remaining time: 0.8848072866201401
# 100000 / 1107395 . Time =  0.0870356559753418 . Estimated remaining time: 0.8767950099110603
# 110000 / 1107395 . Time =  0.0959014892578125 . Estimated remaining time: 0.8695646840659055
# 120000 / 1107395 . Time =  0.10475373268127441 . Estimated remaining time: 0.8619440272549788
# 130000 / 1107395 . Time =  0.1137387752532959 . Estimated remaining time: 0.8551377867185153
# 140000 / 1107395 . Time =  0.1226968765258789 . Estimated remaining time: 0.8478324438078063
# 150000 / 1107395 . Time =  0.13157033920288086 . Estimated remaining time: 0.839766515994072
# 160000 / 1107395 . Time =  0.14042186737060547 . Estimated remaining time: 0.8314683555662632
# 170000 / 1107395 . Time =  0.14929962158203125 . Estimated remaining time: 0.8232510484807632
# 180000 / 1107395 . Time =  0.15821480751037598 . Estimated remaining time: 0.8151544422441058
# 190000 / 1107395 . Time =  0.16720819473266602 . Estimated remaining time: 0.8073480801645079
# 200000 / 1107395 . Time =  0.17626023292541504 . Estimated remaining time: 0.7996888751387596
# 210000 / 1107395 . Time =  0.18518590927124023 . Estimated remaining time: 0.7913574901819229
# 220000 / 1107395 . Time =  0.19402074813842773 . Estimated remaining time: 0.7826054586984894
# 230000 / 1107395 . Time =  0.20294523239135742 . Estimated remaining time: 0.7741882022826568
# 240000 / 1107395 . Time =  0.21179485321044922 . Estimated remaining time: 0.7654583479315042
# 250000 / 1107395 . Time =  0.22094249725341797 . Estimated remaining time: 0.7577403105688095
# 260000 / 1107395 . Time =  0.2300419807434082 . Estimated remaining time: 0.7497557781888889
# 270000 / 1107395 . Time =  0.23917746543884277 . Estimated remaining time: 0.7418008142709732
# 280000 / 1107395 . Time =  0.24797892570495605 . Estimated remaining time: 0.732773763367108
# 290000 / 1107395 . Time =  0.25693821907043457 . Estimated remaining time: 0.7242073838546359
# 300000 / 1107395 . Time =  0.2658233642578125 . Estimated remaining time: 0.7154152538577715
# 310000 / 1107395 . Time =  0.2745180130004883 . Estimated remaining time: 0.7061268815186715
# 320000 / 1107395 . Time =  0.28312087059020996 . Estimated remaining time: 0.6966496300138533
# 330000 / 1107395 . Time =  0.29189109802246094 . Estimated remaining time: 0.6876205661043976
# 340000 / 1107395 . Time =  0.30084967613220215 . Estimated remaining time: 0.6790321293368059
# 350000 / 1107395 . Time =  0.30938124656677246 . Estimated remaining time: 0.6694961210012436
# 360000 / 1107395 . Time =  0.3179206848144531 . Estimated remaining time: 0.6600345071918434
# 370000 / 1107395 . Time =  0.3267049789428711 . Estimated remaining time: 0.6511095398181194
# 380000 / 1107395 . Time =  0.3352038860321045 . Estimated remaining time: 0.6416470708690192
# 390000 / 1107395 . Time =  0.34374165534973145 . Estimated remaining time: 0.6323041612735162
# 400000 / 1107395 . Time =  0.352489709854126 . Estimated remaining time: 0.6233731689184904
# 410000 / 1107395 . Time =  0.36126232147216797 . Estimated remaining time: 0.6144943974512379
# 420000 / 1107395 . Time =  0.3699638843536377 . Estimated remaining time: 0.6055029146415847
# 430000 / 1107395 . Time =  0.3786439895629883 . Estimated remaining time: 0.5964914890000986
# 440000 / 1107395 . Time =  0.38721776008605957 . Estimated remaining time: 0.5873343002010476
# 450000 / 1107395 . Time =  0.39577436447143555 . Estimated remaining time: 0.578178083952268
# 460000 / 1107395 . Time =  0.40435361862182617 . Estimated remaining time: 0.5690794687089712
# 470000 / 1107395 . Time =  0.41335535049438477 . Estimated remaining time: 0.560575577811992
# 480000 / 1107395 . Time =  0.42264509201049805 . Estimated remaining time: 0.5524276959275206
# 490000 / 1107395 . Time =  0.43210530281066895 . Estimated remaining time: 0.544448758667829
# 500000 / 1107395 . Time =  0.44140052795410156 . Estimated remaining time: 0.5362089985632896
# 510000 / 1107395 . Time =  0.45189428329467773 . Estimated remaining time: 0.5293327684355718
# 520000 / 1107395 . Time =  0.461000919342041 . Estimated remaining time: 0.5207495983288838
# 530000 / 1107395 . Time =  0.4707510471343994 . Estimated remaining time: 0.5128475203739022
# 540000 / 1107395 . Time =  0.479755163192749 . Estimated remaining time: 0.5040938654652348
# 550000 / 1107395 . Time =  0.48906850814819336 . Estimated remaining time: 0.49564425974975934
# 560000 / 1107395 . Time =  0.49796152114868164 . Estimated remaining time: 0.48675316852331163
# 570000 / 1107395 . Time =  0.506840705871582 . Estimated remaining time: 0.47784850102558474
# 580000 / 1107395 . Time =  0.5156686305999756 . Estimated remaining time: 0.46889835326424956
# 590000 / 1107395 . Time =  0.5244982242584229 . Estimated remaining time: 0.4599540081125195
# 600000 / 1107395 . Time =  0.5336370468139648 . Estimated remaining time: 0.45127457881569866
# 610000 / 1107395 . Time =  0.5427563190460205 . Estimated remaining time: 0.44256391547742435
# 620000 / 1107395 . Time =  0.5530178546905518 . Estimated remaining time: 0.4347386416965915
# 630000 / 1107395 . Time =  0.5631401538848877 . Estimated remaining time: 0.426730747936264
# 640000 / 1107395 . Time =  0.5729045867919922 . Estimated remaining time: 0.4183948409240693
# 650000 / 1107395 . Time =  0.5822553634643555 . Estimated remaining time: 0.40972407084795137
# 660000 / 1107395 . Time =  0.5918123722076416 . Estimated remaining time: 0.401172254876657
# 670000 / 1107395 . Time =  0.6012074947357178 . Estimated remaining time: 0.39248506331265864
# 680000 / 1107395 . Time =  0.6101605892181396 . Estimated remaining time: 0.38349915132978374
# 690000 / 1107395 . Time =  0.6192812919616699 . Estimated remaining time: 0.37461572444093405
# 700000 / 1107395 . Time =  0.6281435489654541 . Estimated remaining time: 0.3655748203396797
# 710000 / 1107395 . Time =  0.6370995044708252 . Estimated remaining time: 0.35659153281970757
# 720000 / 1107395 . Time =  0.6458694934844971 . Estimated remaining time: 0.3475087070912122
# 730000 / 1107395 . Time =  0.6547539234161377 . Estimated remaining time: 0.3384942093973291
# 740000 / 1107395 . Time =  0.6639828681945801 . Estimated remaining time: 0.32965367312205807
# 750000 / 1107395 . Time =  0.6736664772033691 . Estimated remaining time: 0.32101965521653486
# 760000 / 1107395 . Time =  0.6829564571380615 . Estimated remaining time: 0.3121780006367909
# 770000 / 1107395 . Time =  0.6922814846038818 . Estimated remaining time: 0.303340157965561
# 780000 / 1107395 . Time =  0.701108455657959 . Estimated remaining time: 0.2942811473470468
# 790000 / 1107395 . Time =  0.7098402976989746 . Estimated remaining time: 0.2851891902021215
# 800000 / 1107395 . Time =  0.7187275886535645 . Estimated remaining time: 0.2761664370849729
# 810000 / 1107395 . Time =  0.7277724742889404 . Estimated remaining time: 0.2672049837038841
# 820000 / 1107395 . Time =  0.7368457317352295 . Estimated remaining time: 0.2582506403734044
# 830000 / 1107395 . Time =  0.7457718849182129 . Estimated remaining time: 0.24924465346767233
# 840000 / 1107395 . Time =  0.7545828819274902 . Estimated remaining time: 0.24020422999206048
# 850000 / 1107395 . Time =  0.7632002830505371 . Estimated remaining time: 0.23111034772676575
# 860000 / 1107395 . Time =  0.7720346450805664 . Estimated remaining time: 0.22208989067410323
# 870000 / 1107395 . Time =  0.7806506156921387 . Estimated remaining time: 0.21301425527293105
# 880000 / 1107395 . Time =  0.7893316745758057 . Estimated remaining time: 0.2039658188034188
# 890000 / 1107395 . Time =  0.797935962677002 . Estimated remaining time: 0.1949065890124675
# 900000 / 1107395 . Time =  0.8066534996032715 . Estimated remaining time: 0.18588396921157835
# 910000 / 1107395 . Time =  0.8151841163635254 . Estimated remaining time: 0.17682758104539176
# 920000 / 1107395 . Time =  0.8236384391784668 . Estimated remaining time: 0.16776690287304963
# 930000 / 1107395 . Time =  0.8320467472076416 . Estimated remaining time: 0.15871048740417726
# 940000 / 1107395 . Time =  0.8404498100280762 . Estimated remaining time: 0.14966692738964205
# 950000 / 1107395 . Time =  0.848780632019043 . Estimated remaining time: 0.14062488274197837
# 960000 / 1107395 . Time =  0.8571648597717285 . Estimated remaining time: 0.13160557993998134
# 970000 / 1107395 . Time =  0.8655140399932861 . Estimated remaining time: 0.12259498533391466
# 980000 / 1107395 . Time =  0.8738219738006592 . Estimated remaining time: 0.11359219089332895
# 990000 / 1107395 . Time =  0.882321834564209 . Estimated remaining time: 0.1046257774179632
# 1000000 / 1107395 . Time =  0.8909933567047119 . Estimated remaining time: 0.0956877803111077
# 1010000 / 1107395 . Time =  0.8996813297271729 . Estimated remaining time: 0.08675672472113427
# 1020000 / 1107395 . Time =  0.9084036350250244 . Estimated remaining time: 0.07783283429636678
# 1030000 / 1107395 . Time =  0.9173257350921631 . Estimated remaining time: 0.06892810929863202
# 1040000 / 1107395 . Time =  0.9260187149047852 . Estimated remaining time: 0.06000846096529411
# 1050000 / 1107395 . Time =  0.9344990253448486 . Estimated remaining time: 0.05108104595116203
# 1060000 / 1107395 . Time =  0.9431452751159668 . Estimated remaining time: 0.04216994357558923
# 1070000 / 1107395 . Time =  0.9514186382293701 . Estimated remaining time: 0.03325051755548636
# 1080000 / 1107395 . Time =  0.9598584175109863 . Estimated remaining time: 0.024347287395486084
# 1090000 / 1107395 . Time =  0.9680452346801758 . Estimated remaining time: 0.015448520166064572
# 1100000 / 1107395 . Time =  0.9760720729827881 . Estimated remaining time: 0.006561629529432733
# Route Ridership
# evaluate ridership TRspeed-0_5
# read gs://beam-core-outputs/sfbay-tr-speed0_5-20230626/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz
# /tmp/ipykernel_1098166/2718096371.py:14: DtypeWarning: Columns (0,22,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(dataFilepath_sim, compression = 'gzip',chunksize=2500000, nrows = nrows, usecols = ['vehicle','time','endY','endX','startY','startX','mode', 'length', 'type', 'person']):
# ...
# Warning, trip non found for vehicle BA:38DCM10-clone-1
# Warning, trip non found for vehicle SF:7595069-clone-1
# Warning, trip non found for vehicle ST:9569780-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle AC:5572452-clone-1
# Warning, trip non found for vehicle AC:5572452-clone-1
# Warning, trip non found for vehicle AC:5572452-clone-1
# Warning, trip non found for vehicle AC:5572805-clone-1
# Warning, trip non found for vehicle AC:5578786-clone-1
# Warning, trip non found for vehicle ST:9568730-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle ST:9559829-124-C-Weekday-52-clone-1
# Warning, trip non found for vehicle SO:t_147921_b_2690_tn_0-clone-1
# Warning, trip non found for vehicle UC:40093-clone-1
# Warning, trip non found for vehicle AC:5595001-clone-1
# Warning, trip non found for vehicle AC:5571778-clone-1
# Warning, trip non found for vehicle VT:2733238-clone-1
# Warning, trip non found for vehicle VT:2359471-clone-1
# Warning, trip non found for vehicle VT:2359471-clone-1
# Warning, trip non found for vehicle SF:7597711-clone-1
# Warning, trip non found for vehicle SF:7594347-clone-1
# Warning, trip non found for vehicle AC:5577840-clone-1
# Warning, trip non found for vehicle WH:492391-clone-1
# Warning, trip non found for vehicle VT:2477959-clone-1
# Warning, trip non found for vehicle GG:5185888-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle SF:7679250-clone-1
# Warning, trip non found for vehicle SF:7679250-clone-1
# Warning, trip non found for vehicle GG:5186382-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle AC:5593961-clone-1
# Warning, trip non found for vehicle SF:7627222-clone-1
# Warning, trip non found for vehicle GG:5186370-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle VT:2629210-clone-1
# Warning, trip non found for vehicle SF:7619872-clone-1
# Warning, trip non found for vehicle SF:7619872-clone-1
# Warning, trip non found for vehicle SF:7613253-clone-1
# Warning, trip non found for vehicle VT:2733411-clone-1
# Warning, trip non found for vehicle VT:2733411-clone-1
# Warning, trip non found for vehicle SF:7619872-clone-1
# Warning, trip non found for vehicle AC:5570810-clone-1
# Warning, trip non found for vehicle AC:5577833-clone-1
# Warning, trip non found for vehicle AC:5577833-clone-1
# Warning, trip non found for vehicle AC:5577833-clone-1
# Warning, trip non found for vehicle AC:5570876-clone-1
# Warning, trip non found for vehicle SF:7619775-clone-1
# Warning, trip non found for vehicle VT:2762527-clone-1
# Warning, trip non found for vehicle VT:2723861-clone-1
# Warning, trip non found for vehicle AC:5578259-clone-1
# Warning, trip non found for vehicle BA:51SFO10-clone-1
# Warning, trip non found for vehicle SF:7634339-clone-1
# Warning, trip non found for vehicle SM:3:10807468:T24:13:34:00-clone-1
# Warning, trip non found for vehicle SF:7676467-clone-1
# Warning, trip non found for vehicle VT:2351052-clone-1
# Warning, trip non found for vehicle AC:5571571-clone-1
# Warning, trip non found for vehicle SF:7624219-clone-1
# Warning, trip non found for vehicle SF:7590182-clone-1
# Warning, trip non found for vehicle BA:51SFO10-clone-1
# Warning, trip non found for vehicle VT:2427193-clone-1
# Warning, trip non found for vehicle ST:9569189-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle GG:5185844-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle GG:5185844-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle GG:5185844-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle ST:9569531-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle SF:7676611-clone-1
# Warning, trip non found for vehicle SF:7619872-clone-1
# Warning, trip non found for vehicle SF:7598839-clone-1
# Warning, trip non found for vehicle SF:7607455-clone-1
# Warning, trip non found for vehicle VT:2359503-clone-1
# Warning, trip non found for vehicle VT:2359503-clone-1
# Warning, trip non found for vehicle VT:2359503-clone-1
# Warning, trip non found for vehicle AC:5594164-clone-1
# Warning, trip non found for vehicle VT:2365174-clone-1
# Warning, trip non found for vehicle VT:2365174-clone-1
# Warning, trip non found for vehicle SF:7588250-clone-1
# Warning, trip non found for vehicle AC:5593961-clone-1
# Warning, trip non found for vehicle AC:5593961-clone-1
# Warning, trip non found for vehicle WH:491251-clone-1
# Warning, trip non found for vehicle VT:2238903-clone-1
# Warning, trip non found for vehicle VT:2238903-clone-1
# Warning, trip non found for vehicle AC:5596049-clone-1
# Warning, trip non found for vehicle SF:7597576-clone-1
# Warning, trip non found for vehicle SF:7597576-clone-1
# Warning, trip non found for vehicle SF:7628573-clone-1
# Warning, trip non found for vehicle SF:7628573-clone-1
# Warning, trip non found for vehicle SF:7628573-clone-1
# Warning, trip non found for vehicle AC:5595400-clone-1
# Warning, trip non found for vehicle VT:2247706-clone-1
# Warning, trip non found for vehicle VT:2247706-clone-1
# Warning, trip non found for vehicle SF:7607354-clone-1
# Warning, trip non found for vehicle SF:7614583-clone-1
# Warning, trip non found for vehicle SF:7614583-clone-1
# Warning, trip non found for vehicle SF:7679251-clone-1
# Warning, trip non found for vehicle SF:7599269-clone-1
# Warning, trip non found for vehicle SF:7599269-clone-1
# Warning, trip non found for vehicle SF:7586400-clone-1
# Warning, trip non found for vehicle SF:7603426-clone-1
# Warning, trip non found for vehicle VN:3598-clone-1
# Warning, trip non found for vehicle VT:2630863-clone-1
# Warning, trip non found for vehicle ST:9559900-124-C-Weekday-52-clone-1
# Warning, trip non found for vehicle AC:5572247-clone-1
# Warning, trip non found for vehicle SF:7677860-clone-1
# Warning, trip non found for vehicle SF:7628575-clone-1
# Warning, trip non found for vehicle SF:7874904-clone-1
# Warning, trip non found for vehicle AC:5593925-clone-1
# Warning, trip non found for vehicle AC:5593996-clone-1
# Warning, trip non found for vehicle AC:5578528-clone-1
# Warning, trip non found for vehicle GG:5186382-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle AC:5572695-clone-1
# Warning, trip non found for vehicle AC:5577683-clone-1
# Warning, trip non found for vehicle VT:2398342-clone-1
# Warning, trip non found for vehicle VT:2724050-clone-1
# Warning, trip non found for vehicle SF:7631848-clone-1
# Warning, trip non found for vehicle SF:7678019-clone-1
# Warning, trip non found for vehicle SR:420-clone-1
# Warning, trip non found for vehicle VT:2395044-clone-1
# Warning, trip non found for vehicle VT:2629211-clone-1
# Warning, trip non found for vehicle VT:2661988-clone-1
# Warning, trip non found for vehicle AC:5577833-clone-1
# Warning, trip non found for vehicle WH:491159-clone-1
# Warning, trip non found for vehicle AC:5579324-clone-1
# Warning, trip non found for vehicle VT:2319754-clone-1
# Warning, trip non found for vehicle AC:5577932-clone-1
# Warning, trip non found for vehicle AC:5577932-clone-1
# Warning, trip non found for vehicle SF:7595069-clone-1
# Warning, trip non found for vehicle SF:7676889-clone-1
# Warning, trip non found for vehicle BA:38R10-clone-1
# Warning, trip non found for vehicle BA:38R10-clone-1
# Warning, trip non found for vehicle BA:38R10-clone-1
# Warning, trip non found for vehicle BA:38R10-clone-1
# Warning, trip non found for vehicle BA:07SFO11-clone-1
# Warning, trip non found for vehicle SF:7625011-clone-1
# Warning, trip non found for vehicle BA:32DC10-clone-1
# Warning, trip non found for vehicle BA:32DC10-clone-1
# Warning, trip non found for vehicle BA:32DC10-clone-1
# Warning, trip non found for vehicle BA:32DC10-clone-1
# Warning, trip non found for vehicle BA:38DCM10-clone-1
# Warning, trip non found for vehicle BA:38DCM10-clone-1
# Warning, trip non found for vehicle BA:38DCM10-clone-1
# Warning, trip non found for vehicle SF:7603425-clone-1
# Warning, trip non found for vehicle SF:7594420-clone-1
# Warning, trip non found for vehicle BA:32DC10-clone-1
# Warning, trip non found for vehicle BA:32DC10-clone-1
# Warning, trip non found for vehicle VT:2724052-clone-1
# Warning, trip non found for vehicle SM:59:10807358:T55:13:45:00-clone-1
# Warning, trip non found for vehicle AC:5578126-clone-1
# Warning, trip non found for vehicle VT:2661308-clone-1
# Warning, trip non found for vehicle SF:7595131-clone-1
# Warning, trip non found for vehicle VT:2420367-clone-1
# Warning, trip non found for vehicle CC:81002017_merged_421007258-clone-1
# Warning, trip non found for vehicle VT:2427035-clone-1
# Warning, trip non found for vehicle TD:590-clone-1
# Warning, trip non found for vehicle SF:7594342-clone-1
# Warning, trip non found for vehicle AC:5595400-clone-1
# Warning, trip non found for vehicle VN:3648-clone-1
# Warning, trip non found for vehicle SF:7631848-clone-1
# Warning, trip non found for vehicle SF:7598839-clone-1
# Warning, trip non found for vehicle ST:9568758-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle SM:28:10806622:T20:14:05:00-clone-1
# Warning, trip non found for vehicle AC:5577944-clone-1
# Warning, trip non found for vehicle SR:615-clone-1
# Warning, trip non found for vehicle VN:3848-clone-1
# Warning, trip non found for vehicle VC:RTD6055444-clone-1
# Warning, trip non found for vehicle ST:9559615-124-C-Weekday-52-clone-1
# Warning, trip non found for vehicle ST:9559615-124-C-Weekday-52-clone-1
# Warning, trip non found for vehicle AC:5570791-clone-1
# Warning, trip non found for vehicle ST:9569053-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle ST:9559775-124-C-Weekday-52-clone-1
# Warning, trip non found for vehicle CC:181002020-clone-1
# Warning, trip non found for vehicle CC:181002020-clone-1
# Warning, trip non found for vehicle VN:3895-clone-1
# Warning, trip non found for vehicle VT:2420369-clone-1
# Warning, trip non found for vehicle AC:5572249-clone-1
# Warning, trip non found for vehicle VT:2427120-clone-1
# Warning, trip non found for vehicle VT:2427120-clone-1
# Warning, trip non found for vehicle ST:9569854-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle VC:RTD6744553-clone-1
# Warning, trip non found for vehicle GG:5192399-16MARCH-01-WKDY-Weekday-05-clone-1
# Warning, trip non found for vehicle GG:5192399-16MARCH-01-WKDY-Weekday-05-clone-1
# Warning, trip non found for vehicle MA:35038-clone-1
# Warning, trip non found for vehicle SM:53:10813549:T12:13:30:00-clone-1
# Warning, trip non found for vehicle VT:2630116-clone-1
# Warning, trip non found for vehicle VT:2630116-clone-1
# Warning, trip non found for vehicle GG:5186370-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle ST:9570188-124-D-Weekday-54-SDoff-clone-1
# Warning, trip non found for vehicle VT:2629210-clone-1
# Warning, trip non found for vehicle SF:7678276-clone-1
# Warning, trip non found for vehicle SF:7678276-clone-1
# Warning, trip non found for vehicle SF:7678276-clone-1
# Warning, trip non found for vehicle AC:5595491-clone-1
# Warning, trip non found for vehicle ST:9569239-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle AC:5577410-clone-1
# Warning, trip non found for vehicle AC:5577410-clone-1
# Warning, trip non found for vehicle AC:5577410-clone-1
# Warning, trip non found for vehicle AC:5578379-clone-1
# Warning, trip non found for vehicle SF:7622130-clone-1
# Warning, trip non found for vehicle VT:2723861-clone-1
# Warning, trip non found for vehicle SF:7594419-clone-1
# Warning, trip non found for vehicle VT:2629286-clone-1
# Warning, trip non found for vehicle VT:2629286-clone-1
# Warning, trip non found for vehicle VT:2629286-clone-1
# Warning, trip non found for vehicle VT:2733238-clone-1
# Warning, trip non found for vehicle VT:2365175-clone-1
# Warning, trip non found for vehicle VT:2365175-clone-1
# Warning, trip non found for vehicle WH:491251-clone-1
# Warning, trip non found for vehicle VT:2365094-clone-1
# Warning, trip non found for vehicle AC:5571571-clone-1
# Warning, trip non found for vehicle VT:2426924-clone-1
# Warning, trip non found for vehicle VT:2368638-clone-1
# Warning, trip non found for vehicle WH:492453-clone-1
# Warning, trip non found for vehicle AC:5594062-clone-1
# Warning, trip non found for vehicle CC:301002047-clone-1
# Warning, trip non found for vehicle SF:7686689-clone-1
# Warning, trip non found for vehicle AC:5577932-clone-1
# Warning, trip non found for vehicle AC:5577932-clone-1
# Warning, trip non found for vehicle VT:2398342-clone-1
# Warning, trip non found for vehicle BA:53SFO10-clone-1
# Warning, trip non found for vehicle BA:53SFO10-clone-1
# Warning, trip non found for vehicle BA:53SFO10-clone-1
# Warning, trip non found for vehicle BA:46SFO11-clone-1
# Warning, trip non found for vehicle ST:9559576-124-C-Weekday-52-clone-1
# Warning, trip non found for vehicle ST:9559576-124-C-Weekday-52-clone-1
# Warning, trip non found for vehicle AC:5572423-clone-1
# Warning, trip non found for vehicle AC:5572423-clone-1
# Warning, trip non found for vehicle CC:51002029_merged_421004121-clone-1
# Warning, trip non found for vehicle BA:45SFO11-clone-1
# Warning, trip non found for vehicle CC:71002023_merged_421003233-clone-1
# Warning, trip non found for vehicle BA:53SFO10-clone-1
# Warning, trip non found for vehicle BA:51SFO10-clone-1
# Warning, trip non found for vehicle ST:9559576-124-C-Weekday-52-clone-1
# Warning, trip non found for vehicle VT:2733414-clone-1
# Warning, trip non found for vehicle VT:2733414-clone-1
# Warning, trip non found for vehicle VT:2733414-clone-1
# Warning, trip non found for vehicle ST:9569859-124-D-Weekday-54-clone-1
# Warning, trip non found for vehicle VT:2360032-clone-1
# Warning, trip non found for vehicle VT:2426148-clone-1
# Warning, trip non found for vehicle CC:180002020_merged_421006532-clone-1
# Warning, trip non found for vehicle CC:50002023_merged_421007511-clone-1
# Warning, trip non found for vehicle VT:2368770-clone-1
# Warning, trip non found for vehicle VT:2477960-clone-1
# Warning, trip non found for vehicle AC:5570844-clone-1
# Warning, trip non found for vehicle SF:7612499-clone-1
# Warning, trip non found for vehicle SF:7622128-clone-1
# Warning, trip non found for vehicle VT:2629282-clone-1
# Warning, trip non found for vehicle VT:2629282-clone-1
# Warning, trip non found for vehicle SF:7679254-clone-1
# Warning, trip non found for vehicle VT:2426926-clone-1
# Warning, trip non found for vehicle SF:7686476-clone-1
# Warning, trip non found for vehicle VT:2319754-clone-1
# Warning, trip non found for vehicle VT:2426925-clone-1
# Warning, trip non found for vehicle VT:2426925-clone-1
# Warning, trip non found for vehicle VT:2319724-clone-1
# Warning, trip non found for vehicle VT:2319724-clone-1
# Warning, trip non found for vehicle SF:7603482-clone-1
# Warning, trip non found for vehicle GG:5186062-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle VT:2395044-clone-1
# Warning, trip non found for vehicle SF:7586400-clone-1
# Warning, trip non found for vehicle GG:5186382-16MARCH-01-WKDY-Weekday-04-clone-1
# Warning, trip non found for vehicle SF:7619775-clone-1
# Warning, trip non found for vehicle AC:5571657-clone-1
# Warning, trip non found for vehicle AC:5571657-clone-1
# Warning, trip non found for vehicle AC:5641682-clone-1
# Warning, trip non found for vehicle AC:5577410-clone-1
# Warning, trip non found for vehicle SF:7603482-clone-1
# Warning, trip non found for vehicle AC:5582539-clone-1
# Warning, trip non found for vehicle SF:7632809-clone-1
# Warning, trip non found for vehicle AC:5594024-clone-1
# Warning, trip non found for vehicle AC:5573151-clone-1
# Warning, trip non found for vehicle VT:2630047-clone-1
# Warning, trip non found for vehicle SF:7628573-clone-1
# Warning, trip non found for vehicle SF:7627626-clone-1
# Warning, trip non found for vehicle SF:7676335-clone-1
# Warning, trip non found for vehicle TD:623-clone-1
# Warning, trip non found for vehicle VT:2720946-clone-1
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
RA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 RA
#
# NameError: name 'RA' is not defined

# %%
RR[RR.index=='SF:18608']
# Out:
#           Baseline  Baseline shares      TR  TR shares  TR-BA  TR-BA shares  \
# SF:18608       NaN              NaN  7379.0   0.077666    NaN           NaN
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:18608      NaN             NaN       NaN              NaN      NaN
#
#           TR-CORE shares  TR-1T  TR-1T shares  TR-CA  TR-CA shares  TR-CS  \
# SF:18608             NaN    NaN           NaN    NaN           NaN    NaN
#
#           TR-CS shares   TR-VN  TR-VN shares
# SF:18608           NaN  7722.0      0.081277

# %%
RR[RR.index=='SF:12327']
# Out:
#           Baseline  Baseline shares  TR  TR shares   TR-BA  TR-BA shares  \
# SF:12327    4634.0         0.048774 NaN        NaN  4700.0      0.049469
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12327   4517.0        0.047543    4575.0         0.048153   4899.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares  TR-CS  \
# SF:12327        0.051564  4606.0       0.04848  4605.0      0.048469    NaN
#
#           TR-CS shares  TR-VN  TR-VN shares
# SF:12327           NaN    NaN           NaN

# %%
#30 Stockton
RR[RR.index=='SF:12311']
# Out:
#           Baseline  Baseline shares      TR  TR shares   TR-BA  TR-BA shares  \
# SF:12311    3520.0         0.037049  3261.0   0.034323  3471.0      0.036533
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12311   3681.0        0.038744    3504.0         0.036881   3623.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares   TR-CS  \
# SF:12311        0.038133  3512.0      0.036965  3580.0      0.037681  3313.0
#
#           TR-CS shares   TR-VN  TR-VN shares
# SF:12311       0.03487  3556.0      0.037428

# %%
#45
RR[RR.index=='SF:12324']
# Out:
#           Baseline  Baseline shares      TR  TR shares   TR-BA  TR-BA shares  \
# SF:12324    2266.0          0.02385  2254.0   0.023724  2369.0      0.024934
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12324   2367.0        0.024913    2254.0         0.023724   2333.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares   TR-CS  \
# SF:12324        0.024556  2262.0      0.023808  2363.0      0.024871  2129.0
#
#           TR-CS shares   TR-VN  TR-VN shares
# SF:12324      0.022408  2276.0      0.023956

# %%
RR[RR.index.str.contains('AC:1-142')]
# Out:
#           Baseline  Baseline shares  TR  TR shares   TR-BA  TR-BA shares  \
# AC:1-142    4364.0         0.045932 NaN        NaN  4373.0      0.046027
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# AC:1-142   4411.0        0.046427    4589.0         0.048301   4210.0
#
#           TR-CORE shares  TR-1T  TR-1T shares   TR-CA  TR-CA shares   TR-CS  \
# AC:1-142        0.044312    NaN           NaN  4492.0       0.04728  4372.0
#
#           TR-CS shares   TR-VN  TR-VN shares
# AC:1-142      0.046017  4276.0      0.045006

# %%
RR[RR.index.str.contains('AC:1T-142')]
# Out:
#            Baseline  Baseline shares      TR  TR shares  TR-BA  TR-BA shares  \
# AC:1T-142       NaN              NaN  5135.0   0.054048    NaN           NaN
#
#            TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# AC:1T-142      NaN             NaN       NaN              NaN      NaN
#
#            TR-CORE shares   TR-1T  TR-1T shares  TR-CA  TR-CA shares  TR-CS  \
# AC:1T-142             NaN  5189.0      0.054616    NaN           NaN    NaN
#
#            TR-CS shares  TR-VN  TR-VN shares
# AC:1T-142           NaN    NaN           NaN

# %%
RR[RR.index.str.contains('CA:')]
# Out:
#           Baseline  Baseline shares      TR  TR shares   TR-BA  TR-BA shares  \
# CA:12868    2979.0         0.031355  3287.0   0.034597  2924.0      0.030776
# CA:12869    1814.0         0.019093  2136.0   0.022482  1802.0      0.018967
# CA:12867     934.0         0.009831   961.0   0.010115   848.0      0.008925
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# CA:12868   2868.0        0.030187    2977.0         0.031334   2941.0
# CA:12869   1804.0        0.018988    1818.0         0.019135   1721.0
# CA:12867    829.0        0.008725     838.0         0.008820    874.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares   TR-CS  \
# CA:12868        0.030955  2932.0      0.030860  3304.0      0.034776  3010.0
# CA:12869        0.018114  1729.0      0.018198  2183.0      0.022977  1759.0
# CA:12867        0.009199   910.0      0.009578  1063.0      0.011188   900.0
#
#           TR-CS shares   TR-VN  TR-VN shares
# CA:12868      0.031681  2929.0      0.030829
# CA:12869      0.018514  1767.0      0.018598
# CA:12867      0.009473   956.0      0.010062

# %%
#T TR
RR[RR.index.str.contains('SF:1001')]
# Out:
#          Baseline  Baseline shares      TR  TR shares  TR-BA  TR-BA shares  \
# SF:1001       NaN              NaN  3846.0    0.04048    NaN           NaN
#
#          TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:1001      NaN             NaN       NaN              NaN      NaN
#
#          TR-CORE shares  TR-1T  TR-1T shares  TR-CA  TR-CA shares   TR-CS  \
# SF:1001             NaN    NaN           NaN    NaN           NaN  3888.0
#
#          TR-CS shares  TR-VN  TR-VN shares
# SF:1001      0.040922    NaN           NaN

# %%
#K TR
RR[RR.index.str.contains('SF:1002')]
# Out:
#          Baseline  Baseline shares      TR  TR shares  TR-BA  TR-BA shares  \
# SF:1002       NaN              NaN  4970.0   0.052311    NaN           NaN
#
#          TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:1002      NaN             NaN       NaN              NaN      NaN
#
#          TR-CORE shares  TR-1T  TR-1T shares  TR-CA  TR-CA shares   TR-CS  \
# SF:1002             NaN    NaN           NaN    NaN           NaN  5114.0
#
#          TR-CS shares  TR-VN  TR-VN shares
# SF:1002      0.053826    NaN           NaN

# %%
#T -OWL
RR[RR.index.str.contains('SF:1106')]
# Out:
# Empty DataFrame
# Columns: [Baseline, Baseline shares, TR, TR shares, TR-BA, TR-BA shares, TR-BSVI, TR-BSVI shares, TR-BSVII, TR-BSVII shares, TR-CORE, TR-CORE shares, TR-1T, TR-1T shares, TR-CA, TR-CA shares, TR-CS, TR-CS shares, TR-VN, TR-VN shares]
# Index: []

# %%
#K-OWL
RR[RR.index.str.contains('SF:1102')]
# Out:
#          Baseline  Baseline shares  TR  TR shares  TR-BA  TR-BA shares  \
# SF:1102      25.0         0.000263 NaN        NaN   25.0      0.000263
#
#          TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:1102     16.0        0.000168      31.0         0.000326     25.0
#
#          TR-CORE shares  TR-1T  TR-1T shares  TR-CA  TR-CA shares  TR-CS  \
# SF:1102        0.000263   31.0      0.000326   22.0      0.000232    NaN
#
#          TR-CS shares  TR-VN  TR-VN shares
# SF:1102           NaN   17.0      0.000179

# %%
#L-OWL
RR[RR.index.str.contains('SF:1103')]
# Out:
#          Baseline  Baseline shares  TR  TR shares  TR-BA  TR-BA shares  \
# SF:1103       NaN              NaN NaN        NaN    1.0      0.000011
#
#          TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:1103      NaN             NaN       NaN              NaN      NaN
#
#          TR-CORE shares  TR-1T  TR-1T shares  TR-CA  TR-CA shares  TR-CS  \
# SF:1103             NaN    NaN           NaN    1.0      0.000011    NaN
#
#          TR-CS shares  TR-VN  TR-VN shares
# SF:1103           NaN    NaN           NaN

# %%
#M-OWL
RR[RR.index.str.contains('SF:1104')]
# Out:
# Empty DataFrame
# Columns: [Baseline, Baseline shares, TR, TR shares, TR-BA, TR-BA shares, TR-BSVI, TR-BSVI shares, TR-BSVII, TR-BSVII shares, TR-CORE, TR-CORE shares, TR-1T, TR-1T shares, TR-CA, TR-CA shares, TR-CS, TR-CS shares, TR-VN, TR-VN shares]
# Index: []

# %%
#N-OWL
RR[RR.index.str.contains('SF:1105')]
# Out:
#          Baseline  Baseline shares  TR  TR shares  TR-BA  TR-BA shares  \
# SF:1105       NaN              NaN NaN        NaN    NaN           NaN
#
#          TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:1105      3.0        0.000032       3.0         0.000032      NaN
#
#          TR-CORE shares  TR-1T  TR-1T shares  TR-CA  TR-CA shares  TR-CS  \
# SF:1105             NaN    2.0      0.000021    1.0      0.000011    1.0
#
#          TR-CS shares  TR-VN  TR-VN shares
# SF:1105      0.000011    2.0      0.000021

# %%
#E
RR[RR.index.str.contains('SF:12344')]
# Out:
#           Baseline  Baseline shares     TR  TR shares  TR-BA  TR-BA shares  \
# SF:12344     249.0         0.002621  315.0   0.003315  250.0      0.002631
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12344    279.0        0.002937     270.0         0.002842    266.0
#
#           TR-CORE shares  TR-1T  TR-1T shares  TR-CA  TR-CA shares  TR-CS  \
# SF:12344          0.0028  277.0      0.002916  259.0      0.002726  291.0
#
#           TR-CS shares  TR-VN  TR-VN shares
# SF:12344      0.003063  255.0      0.002684

# %%
#NX
RR[RR.index.str.contains('SF:12351')]
# Out:
#           Baseline  Baseline shares     TR  TR shares  TR-BA  TR-BA shares  \
# SF:12351     313.0         0.003294  310.0   0.003263  293.0      0.003084
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12351    294.0        0.003094     285.0            0.003    293.0
#
#           TR-CORE shares  TR-1T  TR-1T shares  TR-CA  TR-CA shares  TR-CS  \
# SF:12351        0.003084  313.0      0.003294  314.0      0.003305  333.0
#
#           TR-CS shares  TR-VN  TR-VN shares
# SF:12351      0.003505  283.0      0.002979

# %%
#J
RR[RR.index.str.contains('SF:12475')]
# Out:
#           Baseline  Baseline shares      TR  TR shares   TR-BA  TR-BA shares  \
# SF:12475    3001.0         0.031586  2751.0   0.028955  3113.0      0.032765
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12475   2973.0        0.031292    2998.0         0.031555   3123.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares   TR-CS  \
# SF:12475        0.032871  3008.0       0.03166  3036.0      0.031955  2917.0
#
#           TR-CS shares   TR-VN  TR-VN shares
# SF:12475      0.030702  2855.0       0.03005

# %%
#K/T
RR[RR.index.str.contains('SF:12476')]
# Out:
#           Baseline  Baseline shares  TR  TR shares   TR-BA  TR-BA shares  \
# SF:12476    8651.0         0.091055 NaN        NaN  8506.0      0.089528
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12476   8621.0        0.090739    8564.0         0.090139   8576.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares  TR-CS  \
# SF:12476        0.090265  8678.0      0.091339  8580.0      0.090307    NaN
#
#           TR-CS shares   TR-VN  TR-VN shares
# SF:12476           NaN  8564.0      0.090139

# %%
#L
RR[RR.index.str.contains('SF:12477')]
# Out:
#           Baseline  Baseline shares      TR  TR shares   TR-BA  TR-BA shares  \
# SF:12477    6098.0         0.064183  6035.0    0.06352  6061.0      0.063794
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12477   6074.0        0.063931    5945.0         0.062573   5935.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares   TR-CS  \
# SF:12477        0.062468  5979.0      0.062931  6053.0       0.06371  6138.0
#
#           TR-CS shares   TR-VN  TR-VN shares
# SF:12477      0.064604  6005.0      0.063205

# %%
#M
RR[RR.index.str.contains('SF:12478')]
# Out:
#           Baseline  Baseline shares      TR  TR shares   TR-BA  TR-BA shares  \
# SF:12478    5239.0         0.055142  4813.0   0.050658  5086.0      0.053532
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12478   5270.0        0.055468    5124.0         0.053932   5290.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares   TR-CS  \
# SF:12478        0.055679  5298.0      0.055763  5240.0      0.055153  4945.0
#
#           TR-CS shares   TR-VN  TR-VN shares
# SF:12478      0.052048  5374.0      0.056563

# %%
#N
RR[RR.index.str.contains('SF:12479')]
# Out:
#           Baseline  Baseline shares       TR  TR shares   TR-BA  TR-BA shares  \
# SF:12479    9250.0         0.097359  10265.0   0.108042  9435.0      0.099306
#
#           TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# SF:12479   9457.0        0.099538    9393.0         0.098864   9542.0
#
#           TR-CORE shares   TR-1T  TR-1T shares   TR-CA  TR-CA shares    TR-CS  \
# SF:12479        0.100433  9571.0      0.100738  9477.0      0.099748  10281.0
#
#           TR-CS shares   TR-VN  TR-VN shares
# SF:12479      0.108211  9299.0      0.097875

# %%
RR[RR.index.str.contains('BA:')]
# Out:
#        Baseline  Baseline shares       TR  TR shares    TR-BA  TR-BA shares  \
# BA:1    47235.0         0.497163  24130.0   0.253976  24236.0      0.255092
# BA:7    40534.0         0.426633  19575.0   0.206033  19232.0      0.202423
# BA:11   29621.0         0.311770  13433.0   0.141387  13231.0      0.139260
# BA:3    20145.0         0.212033  14459.0   0.152186  14421.0      0.151786
# BA:5    17193.0         0.180962  11123.0   0.117073  11046.0      0.116263
# BA:13      17.0         0.000179      NaN        NaN      NaN           NaN
# BA:19       9.0         0.000095      NaN        NaN      NaN           NaN
# BA:2        NaN              NaN  21173.0   0.222853  21147.0      0.222579
# BA:8        NaN              NaN  16913.0   0.178015  16974.0      0.178657
# BA:12       NaN              NaN  15861.0   0.166942  15684.0      0.165079
# BA:6        NaN              NaN  15326.0   0.161311  15311.0      0.161153
# BA:4        NaN              NaN  13117.0   0.138061  13107.0      0.137955
#
#        TR-BSVI  TR-BSVI shares  TR-BSVII  TR-BSVII shares  TR-CORE  \
# BA:1   47290.0        0.497742   47094.0         0.495679  24118.0
# BA:7   40337.0        0.424560   40328.0         0.424465  19398.0
# BA:11  29504.0        0.310539   29591.0         0.311455  13292.0
# BA:3   21229.0        0.223442   25450.0         0.267869  10871.0
# BA:5   18058.0        0.190066   19783.0         0.208222  10090.0
# BA:13     21.0        0.000221      23.0         0.000242      NaN
# BA:19     15.0        0.000158       9.0         0.000095      NaN
# BA:2       NaN             NaN       NaN              NaN  21245.0
# BA:8       NaN             NaN       NaN              NaN  17012.0
# BA:12      NaN             NaN       NaN              NaN  15781.0
# BA:6       NaN             NaN       NaN              NaN  13686.0
# BA:4       NaN             NaN       NaN              NaN  10234.0
#
#        TR-CORE shares    TR-1T  TR-1T shares    TR-CA  TR-CA shares    TR-CS  \
# BA:1         0.253850  47299.0      0.497837  47299.0      0.497837  47101.0
# BA:7         0.204170  40295.0      0.424118  40209.0      0.423213  40466.0
# BA:11        0.139903  29459.0      0.310065  29380.0      0.309234  29735.0
# BA:3         0.114421  19907.0      0.209528  20031.0      0.210833  20150.0
# BA:5         0.106200  17043.0      0.179383  17137.0      0.180372  17476.0
# BA:13             NaN     20.0      0.000211     20.0      0.000211     18.0
# BA:19             NaN      6.0      0.000063      3.0      0.000032      7.0
# BA:2         0.223610      NaN           NaN      NaN           NaN      NaN
# BA:8         0.179057      NaN           NaN      NaN           NaN      NaN
# BA:12        0.166100      NaN           NaN      NaN           NaN      NaN
# BA:6         0.144050      NaN           NaN      NaN           NaN      NaN
# BA:4         0.107716      NaN           NaN      NaN           NaN      NaN
#
#        TR-CS shares    TR-VN  TR-VN shares
# BA:1       0.495753  47320.0      0.498058
# BA:7       0.425918  40515.0      0.426433
# BA:11      0.312970  29698.0      0.312581
# BA:3       0.212085  20333.0      0.214011
# BA:5       0.183940  17371.0      0.182835
# BA:13      0.000189     11.0      0.000116
# BA:19      0.000074      6.0      0.000063
# BA:2            NaN      NaN           NaN
# BA:8            NaN      NaN           NaN
# BA:12           NaN      NaN           NaN
# BA:6            NaN      NaN           NaN
# BA:4            NaN      NaN           NaN

# %% [markdown]
# # **Create Person Experience Table**

# %%
#Imports
import numpy as np
import pandas as pd
import difflib
import matplotlib.pyplot as plt
import time
import traceback
from tqdm import tqdm
import time
from tqdm.notebook import tqdm
import sys



#########Analysis of what agents used in the baseline

dataFilepath_PT = [
        'gs://beam-core-outputs/sfbay-baseline2018-30pct-20230825/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-30pct-20231014/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSV-30pct-20230825/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSVI-30pct-20230828/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSVII-30pct-20230828/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTCORE-30pct-20230828/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-TempoBRT-30pct-20230825/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-CAElectrification-30pct-20230828/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-SF_CS-30pct-20231014/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-SF_VN-30pct-20231014/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',
    ]

dataFilepath_Plan = [
        'gs://beam-core-outputs/sfbay-baseline2018-30pct-20230825/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-30pct-20231014/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSV-30pct-20230825/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSVI-30pct-20230828/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSVII-30pct-20230828/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTCORE-30pct-20230828/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-TempoBRT-30pct-20230825/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-CAElectrification-30pct-20230828/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-SF_CS-30pct-20231014/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-SF_VN-30pct-20231014/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz',
    ]

dataFilepath_PTO = [
        'gs://beam-core-outputs/sfbay-baseline2018-30pct-20230825/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-30pct-20231014/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-BARTBSV-30pct-20230825/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-BARTBSVI-30pct-20230828/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-BARTBSVII-30pct-20230828/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-BARTCORE-30pct-20230828/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-TempoBRT-30pct-20230825/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-CAElectrification-30pct-20230828/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-SF_CS-30pct-20231014/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
        'gs://beam-core-outputs/sfbay-tr-SF_VN-30pct-20231014/postprocessOutputs/year-2018-iteration-10/personToVehicles.csv',
    ]

dataFilepath_inex = [
        'gs://beam-core-outputs/sfbay-baseline2018-30pct-20230825/inexus/sfbay_baseline_base-1.0_2018__20230825.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-30pct-20231014/inexus/sfbay_baseline_TR-1.0_2018__20231014.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSV-30pct-20230825/inexus/sfbay_baseline_BART-BSV-1.0_2018__20230824.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSVI-30pct-20230828/inexus/sfbay_baseline_BSVI-1.0_2018__20230826.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTBSVII-30pct-20230828/inexus/sfbay_baseline_BSVII-1.0_2018__20230826.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-BARTCORE-30pct-20230828/inexus/sfbay_baseline_CORE-1.0_2018__20230826.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-TempoBRT-30pct-20230825/inexus/sfbay_baseline_1T-1.0_2018__20230825.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-CAElectrification-30pct-20230828/inexus/sfbay_baseline_CA-electr-1.0_2018__20230826.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-SF_CS-30pct-20231014/inexus/sfbay_baseline_CS-1.0_2018__20231014.csv.gz',
        'gs://beam-core-outputs/sfbay-tr-SF_VN-30pct-20231014/inexus/sfbay_baseline_VN-1.0_2018__20231014.csv.gz',
    ]

AgencyIDs = [[':'],
            ['BA:','AC:','CA:','SF:'],
            ['BA:'],
            ['BA:'],
            ['BA:'],
            ['BA:'],
            ['AC:'],
            ['CA:'],
            ['SF:'],
            ['SF:']]

RouteIDs = [[':'],
            ['BA:','AC:1T-142','CA:','SF:1001', 'SF:18608'],
            ['BA:'],
            ['BA:3','BA:4','BA:5','BA:6'],
            ['BA:3','BA:4','BA:5','BA:6'],
            ['BA:'],
            ['AC:1T-142'],
            ['CA:'],
            ['SF:1001'],
            ['SF:18608']]

Route_names = [[':'],
            ['BART - TR','1TEMPO - TR','CA - TR','SF:T - TR', 'SF:49 - TR'],
            ['BART - BSV CORE'],
            ['BA:3 - BSVI','BA:4 - BSVI','BA:5 - BSVI','BA:6 - BSVI'],
            ['BA:3 - BSVII','BA:4 - BSVII','BA:5 - BSVII','BA:6V'],
            ['BART - CORE'],
            ['1TEMPO - 1T'],
            ['CALTRAIN - CA'],
            ['SF:T - CS'],
            ['SF:49 - VN']]

dataFilepath_VtoR = ['outputs/routetovehicledictBaseline.csv',
                          'outputs/routetovehicledictTR.csv',
                          'outputs/routetovehicledictTR-BA.csv',
                          'outputs/routetovehicledictTR-BSVI.csv',
                          'outputs/routetovehicledictTR-BSVII.csv',
                          'outputs/routetovehicledictTR-CORE.csv',
                          'outputs/routetovehicledictTR-1T.csv',
                          'outputs/routetovehicledictTR-CA.csv',
                          'outputs/routetovehicledictTR-CS.csv',
                          'outputs/routetovehicledictTR-VN.csv',
]

names = ['Baseline','TR','TR-BA','TR-BSVI','TR-BSVII','TR-CORE','TR-1T','TR-CA','TR-CS','TR-VN']

# %%
# # person_trips_baseline
# # plans_baseline
# # events_baseline
# # mode_choice_baseline
# # PTs_baseline
# # PtoPTss_baseline
# # PtoPTss_baseline_dict


persons_baseline = pd.DataFrame()
persons_baseline = pd.DataFrame(columns = ['Person',
                                           'Plan Index',
                                           'Planned Depart Time Baseline',
                                           'Planned Depart Time TR',
                                           'Activity From Baseline',
                                           'Activity To Baseline',
                                           'Activity From TR',
                                           'Activity To TR',
                                           'Project Tried',
                                           'Vehicles Used Baseline',
                                           'Vehicle Types Used Baseline',                                          
                                           'Bus agencies Used Baseline',
                                           'First Bus agency Used Baseline',
                                           'Vehicles Used TR',
                                           'Vehicle Types Used TR',                                          
                                           'Bus agencies Used TR',
                                           'First Bus agency Used TR',
                                           'Switch From',
                                           'Trip Length Baseline',                       
                                           'Trip Duration Baseline',
                                           'Trip Length TR',
                                           'Trip Duration TR',
                                           'Diff Length',
                                           'Diff Duration',
                                           'Planned Mode Baseline',                                         
                                           'Planned Mode TR',                                          
                                           'Chosen Mode Baseline',                                          
                                           'Chosen Mode TR',
                                           'X Activity From TR',
                                           'Y Activity From TR',
                                           'X Activity To TR',
                                           'Y Activity To TR',
                                           'X Activity From Baseline',
                                           'Y Activity From Baseline',
                                           'X Activity To Baseline',
                                           'Y Activity To Baseline',
                                           'Log Sum Baseline',
                                           'Log Sum TR',
                                           'Diff Log Sum',
#                                            'ZIP Departure TR',                                          
#                                            'ZIP Arrival TR',                                          
#                                            'ZIP Departure Baseline',                                          
#                                            'ZIP Arrival Baseline',                                          
                                          ])



print('Read person_trips_baseline...')
person_trips_baseline = pd.read_csv(dataFilepath_inex[0], compression = 'gzip', 
                                    usecols = ['logsum_trip_Potential_INEXUS','person_id', 'destination_logsum_x',
                                               'destination_logsum_y','logsum_tours_mode_AS_tours','workplace_location_logsum'])
print('Read plans_baseline...')
plans_baseline = pd.read_csv(dataFilepath_Plan[0], usecols = ['activityType','personId','planElementIndex','activityEndTime','activityLocationX','activityLocationY','legMode','planSelected'])
plans_baseline = plans_baseline[plans_baseline.planSelected == True]
print('Read events_baseline...')
events_baseline = pd.read_csv(dataFilepath_PT[0], usecols = ['type','time','departureTime','mode','person','length','duration'])
mode_choice_baseline = events_baseline[events_baseline['type']=='ModeChoice']
PTs_baseline = events_baseline[events_baseline['type']=='PathTraversal']
dict_time_baseline = dict(zip(PTs_baseline.index, PTs_baseline.departureTime))
print('Read PtoPTss_Baseline...')
PtoPTss_baseline = pd.read_csv(dataFilepath_PTO[0])
PtoPTss_baseline_bus =  PtoPTss_baseline[(PtoPTss_baseline['mode'] =='bus')|
                                         (PtoPTss_baseline['mode'] =='subway')|
                                         (PtoPTss_baseline['mode'] =='tram')|
                                         (PtoPTss_baseline['mode'] =='rail')|
                                         (PtoPTss_baseline['mode'] =='cable_car')|
                                         (PtoPTss_baseline['mode'] =='ferry')]
PtoPTss_baseline['departureTime'] =  PtoPTss_baseline['pathTraversalID'].map(dict_time_baseline)
print('Create PTO dict...')
PtoPTss_baseline_dict = PtoPTss_baseline.groupby(['personID', 'planIndex']).apply(lambda x: [sum(x.length),
                                                    sum(x.duration),min(x.departureTime)]).to_dict()
# Out:
# Read person_trips_baseline...
# Read plans_baseline...

# %%
i = 0

#SCENARIO
for dt_fp, pto_fp, plan_fp, inex_fp, vtoR_fp, agID, rouIDs, names in zip(dataFilepath_PT[1:], dataFilepath_PTO[1:], dataFilepath_Plan[1:], dataFilepath_inex[1:], dataFilepath_VtoR[1:], AgencyIDs[1:], RouteIDs[1:], Route_names[1:]):
    
    print('Analyzing', names)
    print('Read person_trips_baseline...')
    person_trips_TR = pd.read_csv(inex_fp, compression = 'gzip', 
                                    usecols = ['logsum_trip_Potential_INEXUS','person_id', 'destination_logsum_x',
                                               'destination_logsum_y','logsum_tours_mode_AS_tours','workplace_location_logsum'])
    print('Read plans_baseline...')
    plans_TR = pd.read_csv(plan_fp, usecols = ['activityType','personId','planElementIndex','activityEndTime','activityLocationX','activityLocationY','legMode', 'planSelected'])
    plans_TR = plans_TR[plans_TR.planSelected == True]
    print('Read events_baseline...')
    events_TR = pd.read_csv(dt_fp, usecols = ['type','time','departureTime','mode','person','length','duration'])
    mode_choice_TR = events_TR[events_TR['type']=='ModeChoice']
    PTs_TR = events_TR[events_TR['type']=='PathTraversal'] 
    dict_time_TR = dict(zip(PTs_TR.index, PTs_TR.departureTime))
    print('Read PtoPTss_Baseline...')
    PtoPTss_TR = pd.read_csv(pto_fp) 
    VtoR_TR = pd.read_csv(vtoR_fp)
    VtoR_TR = VtoR_TR.set_index('0')['1'].to_dict()
    PtoPTss_TR['route_id'] =  PtoPTss_TR['vehicleID'].map(VtoR_TR)
    PtoPTss_TR['departureTime'] =  PtoPTss_TR['pathTraversalID'].map(dict_time_TR)

    
 
    #ROUTE
    for rt, nm in zip(rouIDs, names):
        
        print('Analyze', nm)
                      
        print('Filter PtoPTss_TR_rt...')
        PtoPTss_TR_rt =  PtoPTss_TR[(PtoPTss_TR['mode'] =='bus')|
                                     (PtoPTss_TR['mode'] =='subway')|
                                     (PtoPTss_TR['mode'] =='tram')|
                                     (PtoPTss_TR['mode'] =='rail')|
                                     (PtoPTss_TR['mode'] =='cable_car')|
                                     (PtoPTss_TR['mode'] =='ferry')]
        PtoPTss_TR_rt = PtoPTss_TR_rt[PtoPTss_TR_rt['vehicle2'].isin(agID)]
        PtoPTss_TR_rt = PtoPTss_TR_rt[PtoPTss_TR_rt['vehicleID'].str.startswith(tuple(rouIDs))]
        
        print('Create PTO dict...')
        PtoPTss_TR_dict = PtoPTss_TR_rt.groupby(['personID', 'planIndex']).apply(lambda x: [sum(x.length),
                                                    sum(x.duration),min(x.departureTime)]).to_dict()
        
        #PTO
        total_rows = len(PtoPTss_TR_dict.keys())
        print('Number of rows:',total_rows)
        
        
        with tqdm(total=total_rows, position=0, file=sys.stdout, leave=True) as pbar:

            start_time = time.time()
            
            for row in PtoPTss_TR_dict.keys():

                pbar.update(1)
                i+=1
                # if i%50==0:
                #     print(i)


                try:

                    Plan_minus1 = plans_baseline[(plans_baseline['personId']==row[0])&(plans_baseline['planElementIndex']==row[1]-1)]
                    Plan_minus1_TR = plans_TR[(plans_TR['personId']==row[0])&(plans_TR['planElementIndex']==row[1]-1)]
                    Plan_plus1 = plans_baseline[(plans_baseline['personId']==row[0])&(plans_baseline['planElementIndex']==row[1]+1)]
                    Plan_plus1_TR = plans_TR[(plans_TR['personId']==row[0])&(plans_TR['planElementIndex']==row[1]+1)]
                    person_trips_baseline_person = person_trips_baseline[(person_trips_baseline['person_id']==row[0])]
                    person_trips_TR_person = person_trips_TR[(person_trips_TR['person_id']==row[0])]
                    PtoPTss_baseline_person = PtoPTss_baseline[(PtoPTss_baseline['personID']==row[0])&(PtoPTss_baseline['planIndex']==row[1])]
                    PtoPTss_TR_person = PtoPTss_TR[(PtoPTss_TR['personID']==row[0])&(PtoPTss_TR['planIndex']==row[1])]


                    persons_baseline.at[i,'Person'] = row[0]

                    persons_baseline.at[i,'Plan Index'] = int(row[1])

                    persons_baseline.at[i,'Activity From Baseline'] = list(Plan_minus1['activityType'])[0]

                    persons_baseline.at[i,'Activity To Baseline'] = list(Plan_plus1['activityType'])[0]

                    persons_baseline.at[i,'Activity From TR'] = list(Plan_minus1_TR['activityType'])[0]

                    persons_baseline.at[i,'Activity To TR'] = list(Plan_plus1_TR['activityType'])[0]

                    persons_baseline.at[i,'Planned Depart Time Baseline'] = int(list(Plan_minus1['activityEndTime'])[0])

                    persons_baseline.at[i,'Planned Depart Time TR'] = int(list(Plan_minus1_TR['activityEndTime'])[0])
                    
                    #### We sure mode choice was before the end of previous activityi???
                    mode_choice_baseline_person = mode_choice_baseline[(mode_choice_baseline['person']==row[0])&(mode_choice_baseline['time']<=persons_baseline.at[i,'Planned Depart Time Baseline'] +1)]
                    mode_choice_TR_person = mode_choice_TR[(mode_choice_TR['person']==row[0])&(mode_choice_TR['time']<=persons_baseline.at[i,'Planned Depart Time TR'] +1)]

                    persons_baseline.at[i,'Project Tried'] = nm

                    persons_baseline.at[i,'Potential INEXUS Baseline'] = np.mean(list(person_trips_baseline_person['logsum_trip_Potential_INEXUS']))

                    persons_baseline.at[i,'Potential INEXUS TR'] = np.mean(list(person_trips_TR_person['logsum_trip_Potential_INEXUS']))

                    persons_baseline.at[i,'Destination LOG SUM X Baseline'] = np.mean(list(person_trips_baseline_person['destination_logsum_x']))

                    persons_baseline.at[i,'Destination LOG SUM X TR'] = np.mean(list(person_trips_TR_person['destination_logsum_x']))

                    persons_baseline.at[i,'Destination LOG SUM Y Baseline'] = np.mean(list(person_trips_baseline_person['destination_logsum_y']))

                    persons_baseline.at[i,'Destination LOG SUM Y TR'] = np.mean(list(person_trips_TR_person['destination_logsum_y']))

                    persons_baseline.at[i,'LOG SUM Tours Mode AS Baseline'] = np.mean(list(person_trips_baseline_person['logsum_tours_mode_AS_tours']))

                    persons_baseline.at[i,'LOG SUM Tours Mode AS TR'] = np.mean(list(person_trips_TR_person['logsum_tours_mode_AS_tours']))

                    persons_baseline.at[i,'LOG SUM Work PLace Location Baseline'] = np.mean(list(person_trips_baseline_person['workplace_location_logsum']))

                    persons_baseline.at[i,'LOG SUM Work PLace Location TR'] = np.mean(list(person_trips_TR_person['workplace_location_logsum']))

                    persons_baseline.at[i,'Diff Potential INEXUS'] = persons_baseline.at[i,'Potential INEXUS TR']-persons_baseline.at[i,'Potential INEXUS Baseline']

                    persons_baseline.at[i,'Diff Destination LOG SUM X'] = persons_baseline.at[i,'Destination LOG SUM X TR']-persons_baseline.at[i,'Destination LOG SUM X Baseline']

                    persons_baseline.at[i,'Diff Destination LOG SUM Y'] = persons_baseline.at[i,'Destination LOG SUM Y TR']-persons_baseline.at[i,'Destination LOG SUM Y Baseline']

                    persons_baseline.at[i,'Diff LOG SUM Tours Mode AS'] = persons_baseline.at[i,'LOG SUM Tours Mode AS TR']-persons_baseline.at[i,'LOG SUM Tours Mode AS Baseline']

                    persons_baseline.at[i,'Diff LOG SUM Work PLace Location'] = persons_baseline.at[i,'LOG SUM Work PLace Location TR']-persons_baseline.at[i,'LOG SUM Work PLace Location Baseline']

                    persons_baseline.at[i,'Vehicles Used Baseline'] = np.unique(list(PtoPTss_baseline_person['vehicleID']))

                    persons_baseline.at[i,'Vehicles Used TR'] = np.unique(list(PtoPTss_TR_person['vehicleID']))

                    persons_baseline.at[i,'Bus agencies Used Baseline'] = np.unique(list(PtoPTss_baseline_bus['vehicle2'][(PtoPTss_baseline_bus['personID']==row[0])&(PtoPTss_baseline_bus['planIndex']==row[1])]))

                    persons_baseline.at[i,'Bus agencies Used TR'] = np.unique(list(PtoPTss_TR_rt['vehicle2'][(PtoPTss_TR_rt['personID']==row[0])&(PtoPTss_TR_rt['planIndex']==row[1])]))

                    first_bus_agency_baseline = list(PtoPTss_baseline_bus['vehicle2'][(PtoPTss_baseline_bus['personID']==row[0])&(PtoPTss_baseline_bus['planIndex']==row[1])])
                    persons_baseline.at[i,'First Bus agency Used Baseline'] = first_bus_agency_baseline[0] if first_bus_agency_baseline else ''

                    persons_baseline.at[i,'First Bus agency Used TR'] = list(PtoPTss_TR_rt['vehicle2'][(PtoPTss_TR_rt['personID']==row[0])&(PtoPTss_TR_rt['planIndex']==row[1])])[0]

                    #### GEt that from MODE CHOICE
                    
#                     persons_baseline.at[i,'Trip Length TR'] = int(PtoPTss_TR_dict[row][0])

#                     persons_baseline.at[i,'Trip Duration TR'] = int(PtoPTss_TR_dict[row][1])
                        
                    persons_baseline.at[i,'X Activity From TR'] = list(Plan_minus1_TR['activityLocationX'])[0]

                    persons_baseline.at[i,'Y Activity From TR'] = list(Plan_minus1_TR['activityLocationY'])[0]

                    persons_baseline.at[i,'X Activity To TR'] = list(Plan_plus1_TR['activityLocationX'])[0]

                    persons_baseline.at[i,'Y Activity To TR'] = list(Plan_plus1_TR['activityLocationY'])[0]

                    persons_baseline.at[i,'X Activity From Baseline'] = list(Plan_minus1['activityLocationX'])[0]

                    persons_baseline.at[i,'Y Activity From Baseline'] = list(Plan_minus1['activityLocationY'])[0]

                    persons_baseline.at[i,'X Activity To Baseline'] = list(Plan_plus1['activityLocationX'])[0]

                    persons_baseline.at[i,'Y Activity To Baseline'] = list(Plan_plus1['activityLocationY'])[0]

                    persons_baseline.at[i,'Vehicle Types Used Baseline'] = np.unique(list(PtoPTss_baseline_person['mode']))

                    persons_baseline.at[i,'Vehicle Types Used TR'] = np.unique(list(PtoPTss_TR_person['mode']))

                    persons_baseline.at[i,'Planned Mode Baseline'] = list(plans_baseline['legMode'][(plans_baseline['personId']==row[0])&(plans_baseline['planElementIndex']==row[1])])[0]

                    persons_baseline.at[i,'Planned Mode TR'] = list(plans_TR['legMode'][(plans_TR['personId']==row[0])&(plans_TR['planElementIndex']==row[1])])[0]

                    persons_baseline.at[i,'Chosen Mode Baseline'] = list(mode_choice_baseline_person['mode'])[-1]

                    persons_baseline.at[i,'Chosen Mode TR'] = list(mode_choice_TR_person['mode'])[-1]
                    
                    
                    persons_baseline.at[i,'Trip Length Baseline'] = list(mode_choice_baseline_person['length'])[-1]

                    persons_baseline.at[i,'Trip Duration Baseline'] = list(mode_choice_baseline_person['duration'])[-1]
                    
                    persons_baseline.at[i,'Trip Length TR'] = list(mode_choice_TR_person['length'])[-1]

                    persons_baseline.at[i,'Trip Duration TR'] = list(mode_choice_TR_person['duration'])[-1]
                    
                    persons_baseline.at[i,'Diff Length'] = int(persons_baseline.at[i,'Trip Length TR']-persons_baseline.at[i,'Trip Length Baseline'])

                    persons_baseline.at[i,'Diff Duration'] = int(persons_baseline.at[i,'Trip Duration TR']-persons_baseline.at[i,'Trip Duration Baseline'])
                    
                    
                    
                    
#                     persons_baseline.at[i,'Chosen Mode Baseline'] = list(mode_choice_baseline['mode'][(mode_choice_baseline['person']==row[0])&(mode_choice_baseline['time']<=PtoPTss_baseline_dict[row][2]+1)])[-1]

#                     persons_baseline.at[i,'Chosen Mode TR'] = list(mode_choice_TR['mode'][(mode_choice_TR['person']==row[0])&(mode_choice_TR['time']<=PtoPTss_TR_dict[row][2]+1)])[-1]
                    
                    
#                     #Not for people that were using HOV
#                     try:
#                         persons_baseline.at[i,'Trip Length Baseline'] = int(PtoPTss_baseline_dict[row][0])

#                         persons_baseline.at[i,'Trip Duration Baseline'] = int(PtoPTss_baseline_dict[row][1])

#                     except:
#                         print('HoV', PtoPTss_TR_dict[row], row, list(plans_baseline['legMode'][(plans_baseline['personId']==row[0])&(plans_baseline['planElementIndex']==row[1])])[0])
                            
#                             persons_baseline.at[i,'Diff Length'] = int(persons_baseline.at[i,'Trip Length TR']-persons_baseline.at[i,'Trip Length Baseline'])

#                             persons_baseline.at[i,'Diff Duration'] = int(persons_baseline.at[i,'Trip Duration TR']-persons_baseline.at[i,'Trip Duration Baseline'])                            
                            
#                         continue
                    
                    
                    

                except Exception as e:
                    # Print the error message to stderr
                    print(f'Error type: {type(e)}', file=sys.stderr)
                    print(f'Error message: {str(e)}', file=sys.stderr)

                    # Print the traceback to stderr
                    traceback.print_exc(file=sys.stderr)

                    print('Warning', row, PtoPTss_TR_dict[row], file=sys.stderr)
                    continue

                # Calculate and display progress information
                # Calculate and display progress information
                processed_rows = pbar.n
                remaining_rows = total_rows - processed_rows
                progress_percent = (processed_rows / total_rows) * 100

                # Estimate the remaining time based on the processing rate
                elapsed_time = time.time() - start_time
                rows_per_second = processed_rows / elapsed_time
                remaining_time_seconds = remaining_rows / rows_per_second
                remaining_time_hours = remaining_rows / rows_per_second / 3600

                pbar.set_postfix_str(f"Processed {processed_rows}/{total_rows} rows ({progress_percent:.2f}%), "
                              f"Estimated Remaining Time: {remaining_time_seconds:.2f} seconds"
                            f" or {remaining_time_hours:.2f} hours", 
                                    refresh=True)

        persons_baseline.to_csv('outputs/person_databaseTR.csv')

persons_baseline.to_csv('outputs/person_databaseTR.csv')

# %%
# plans_baseline = pd.read_csv('gs://beam-core-outputs/sfbay-baseline2018-30pct-20230825/beam/year-2018-iteration-10/ITERS/it.0/0.plans.csv.gz', usecols = ['activityType','personId','planElementIndex','activityEndTime','activityLocationX','activityLocationY','legMode','planSelected'])

plans_baseline[plans_baseline.personId ==46419]
# Out:
#           personId  planSelected  planElementIndex activityType  \
# 22212872     46419         False                 0         Home
# 22212873     46419         False                 1          NaN
# 22212874     46419         False                 2         work
# 22212875     46419         False                 3          NaN
# 22212876     46419         False                 4         work
# ...            ...           ...               ...          ...
# 22212959     46419          True                18         Home
# 22212960     46419          True                19          NaN
# 22212961     46419          True                20     othdiscr
# 22212962     46419          True                21          NaN
# 22212963     46419          True                22         Home
#
#           activityLocationX  activityLocationY  activityEndTime       legMode
# 22212872      563023.283987       4.186661e+06          18482.0           NaN
# 22212873                NaN                NaN              NaN  walk_transit
# 22212874      551061.842321       4.180518e+06          21536.0           NaN
# 22212875                NaN                NaN              NaN  walk_transit
# 22212876      550798.154015       4.181218e+06          28292.0           NaN
# ...                     ...                ...              ...           ...
# 22212959      561311.817495       4.184990e+06          58874.4           NaN
# 22212960                NaN                NaN              NaN  walk_transit
# 22212961      552687.406690       4.182358e+06          68806.8           NaN
# 22212962                NaN                NaN              NaN  walk_transit
# 22212963      562976.262888       4.186630e+06             -inf           NaN
#
# [92 rows x 8 columns]

# %%
PtoPTss_baseline['mode'].value_counts()
# Out:
# car                   7330285
# walk                  6209170
# bus                   4258767
# car_hov2              1053447
# car_hov3               754981
# subway                 625754
# car_emer               414094
# tram                   365671
# car_hov2_emer          128687
# car_RideHail           111586
# bike                   105773
# car_hov3_emer           89647
# cable_car               41051
# rail                    21705
# car_RideHail_empty       1036
# ferry                      39
# bus_empty                  17
# Name: mode, dtype: int64

# %%
plans_baseline[plans_baseline.personId ==317]
# Out:
#           personId  planSelected  planElementIndex activityType  \
# 45133305       317          True                 0         Home
# 45133306       317          True                 1          NaN
# 45133307       317          True                 2         work
# 45133308       317          True                 3          NaN
# 45133309       317          True                 4         Home
# 45133310       317          True                 5          NaN
# 45133311       317          True                 6     othdiscr
# 45133312       317          True                 7          NaN
# 45133313       317          True                 8         Home
#
#           activityLocationX  activityLocationY  activityEndTime  \
# 45133305      567054.747829       4.190684e+06          26060.4
# 45133306                NaN                NaN              NaN
# 45133307      551778.854568       4.182412e+06          65430.0
# 45133308                NaN                NaN              NaN
# 45133309      567054.747829       4.190684e+06          66337.2
# 45133310                NaN                NaN              NaN
# 45133311      570433.395782       4.190380e+06          66391.2
# 45133312                NaN                NaN              NaN
# 45133313      567054.747829       4.190684e+06             -inf
#
#                      legMode
# 45133305                 NaN
# 45133306        walk_transit
# 45133307                 NaN
# 45133308        walk_transit
# 45133309                 NaN
# 45133310  hov2_teleportation
# 45133311                 NaN
# 45133312  hov2_teleportation
# 45133313                 NaN

# %%
plans_TR[plans_TR.personId ==317]
# Out:
#           personId  planSelected  planElementIndex activityType  \
# 45132831       317          True                 0         Home
# 45132832       317          True                 1          NaN
# 45132833       317          True                 2         work
# 45132834       317          True                 3          NaN
# 45132835       317          True                 4         Home
# 45132836       317          True                 5          NaN
# 45132837       317          True                 6     othdiscr
# 45132838       317          True                 7          NaN
# 45132839       317          True                 8         Home
#
#           activityLocationX  activityLocationY  activityEndTime  \
# 45132831      567054.747829       4.190684e+06          26899.2
# 45132832                NaN                NaN              NaN
# 45132833      552059.356848       4.182366e+06          65552.4
# 45132834                NaN                NaN              NaN
# 45132835      567054.747829       4.190684e+06          66502.8
# 45132836                NaN                NaN              NaN
# 45132837      571240.239682       4.189103e+06          68234.4
# 45132838                NaN                NaN              NaN
# 45132839      567054.747829       4.190684e+06             -inf
#
#                      legMode
# 45132831                 NaN
# 45132832        walk_transit
# 45132833                 NaN
# 45132834        walk_transit
# 45132835                 NaN
# 45132836  hov2_teleportation
# 45132837                 NaN
# 45132838  hov2_teleportation
# 45132839                 NaN

# %%
import pandas as pd


plans_df = plans_df.sort_values(by=['PersonID', 'PlanIndex'])
plans_df_shifted = plans_df.shift(periods=1)
filtered_rows = plans_df['PlanIndex'] == (plans_df_shifted['PlanIndex'] + 1)
result_df = plans_df[filtered_rows]
result_dict = dict(zip(zip(result_df['PersonID'], result_df['PlanIndex']), result_df['ActivityType']))

# %%
PtoPTss_TR['vehicleID']
# Out:
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        1
#                          ...
# 21473553    westcat-ca-us:160436A2376B3650
# 21473554    westcat-ca-us:160436A2376B3650
# 21473555    westcat-ca-us:160436A2376B3650
# 21473556    westcat-ca-us:160436A2376B3650
# 21473557    westcat-ca-us:160436A2376B3650
# Name: vehicleID, Length: 21473558, dtype: object

# %%
VtoR_TR
# Out:
#        Unnamed: 0                        0           1
# 0               0               AC:5593910  AC:851-142
# 1               1               AC:5593819  AC:802-142
# 2               2               AC:5573008  AC:840-142
# 3               3               AC:5572515  AC:800-142
# 4               4  SM:43:10748241:T1:15:00       SM:43
# ...           ...                      ...         ...
# 41465       41465               SF:7596614    SF:12297
# 41466       41466               SF:7605335    SF:12306
# 41467       41467               SF:7600910    SF:12303
# 41468       41468               SF:7605295    SF:12306
# 41469       41469               SF:7605334    SF:12306
#
# [41470 rows x 3 columns]
