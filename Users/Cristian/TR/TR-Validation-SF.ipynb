# %%
#Imports
import numpy as np
import pandas as pd
import geopandas as gpd
import difflib
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # ***Observed Data***

# %%
SF_jan2020 = pd.read_excel('/Users/cpoliziani/Downloads/Transit Rich/ObsRidershipSF/SFMTA_2020_01_25.xlsx')
SF_mar2021 = pd.read_excel('/Users/cpoliziani/Downloads/Transit Rich/ObsRidershipSF/SFMTA_2021_03_20.xlsx')
SF_sep2021 = pd.read_excel('/Users/cpoliziani/Downloads/Transit Rich/ObsRidershipSF/SFMTA_2021_09_04.xlsx')
SF_jan2023 = pd.read_excel('/Users/cpoliziani/Downloads/Transit Rich/ObsRidershipSF/SFMTA_2023_01_07.xlsx')
SF_feb2023 = pd.read_excel('/Users/cpoliziani/Downloads/Transit Rich/ObsRidershipSF/SFMTA_2023_02_18.xlsx')
SF_apr2023 = pd.read_excel('/Users/cpoliziani/Downloads/Transit Rich/ObsRidershipSF/SFMTA_2023_04_15.xlsx')

# %%
for route in np.unique(list(SF_jan2020.ROUTE_ALPHA.value_counts().keys())):
    df = SF_jan2020[(SF_jan2020['ROUTE_ALPHA']==route) & (SF_jan2020.SERVICE_DAY_OF_WEEK == 'WEEKDAY')]
    print(route)
    print("Ridership:", df['AVG_VEH_ONS (SUM)'].sum(skipna=True))

# %%
# Create a list of dataframes
dfs = [SF_jan2020, SF_mar2021, SF_sep2021, SF_jan2023, SF_feb2023, SF_apr2023]

# Iterate over the dataframes in the list
for df in dfs:
    
    
    print(df['ROUTE_ALPHA'].value_counts().keys()) 
    print("----------------------49--------------------------")
    
    df_filt = df[df['ROUTE_ALPHA']=='049']
    
    print(len(df_filt))
    
    print("Sum of AVG_VEH_DEPARTING_LOAD (AVG):", df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_DEPARTING_LOAD (AVG)']) - df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].isna().sum())
    
    print("Sum of AVG_VEH_DEPARTING_LOAD (SUM):", df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_DEPARTING_LOAD (SUM)']) - df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].isna().sum())
    
    print("Sum of AVG_VEH_ONS (SUM):", df_filt['AVG_VEH_ONS (SUM)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_ONS (SUM)']) - df_filt['AVG_VEH_ONS (SUM)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_ONS (SUM)'].isna().sum())
    
    
    print("--------------------------------------------------")
    
    print("----------------------30--------------------------")
    
    df_filt = df[df['ROUTE_ALPHA']=='030']
    
    print(len(df_filt))
    
    print("Sum of AVG_VEH_DEPARTING_LOAD (AVG):", df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_DEPARTING_LOAD (AVG)']) - df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].isna().sum())
    
    print("Sum of AVG_VEH_DEPARTING_LOAD (SUM):", df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_DEPARTING_LOAD (SUM)']) - df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].isna().sum())
    
    print("Sum of AVG_VEH_ONS (SUM):", df_filt['AVG_VEH_ONS (SUM)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_ONS (SUM)']) - df_filt['AVG_VEH_ONS (SUM)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_ONS (SUM)'].isna().sum())
    
    
    print("--------------------------------------------------")
    
    
    
    print("----------------------T--------------------------")
    
    df_filt = df[df['ROUTE_ALPHA']=='T']
    
    print(len(df_filt))
    
    print("Sum of AVG_VEH_DEPARTING_LOAD (AVG):", df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_DEPARTING_LOAD (AVG)']) - df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].isna().sum())
    
    print("Sum of AVG_VEH_DEPARTING_LOAD (SUM):", df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_DEPARTING_LOAD (SUM)']) - df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].isna().sum())
    
    print("Sum of AVG_VEH_ONS (SUM):", df_filt['AVG_VEH_ONS (SUM)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_ONS (SUM)']) - df_filt['AVG_VEH_ONS (SUM)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_ONS (SUM)'].isna().sum())
    
    
    print("--------------------------------------------------")
        
    print("----------------------K--------------------------")
    
    df_filt = df[df['ROUTE_ALPHA']=='K']
    
    print(len(df_filt))
    
    print("Sum of AVG_VEH_DEPARTING_LOAD (AVG):", df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_DEPARTING_LOAD (AVG)']) - df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_DEPARTING_LOAD (AVG)'].isna().sum())
    
    print("Sum of AVG_VEH_DEPARTING_LOAD (SUM):", df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_DEPARTING_LOAD (SUM)']) - df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_DEPARTING_LOAD (SUM)'].isna().sum())
    
    print("Sum of AVG_VEH_ONS (SUM):", df_filt['AVG_VEH_ONS (SUM)'].sum(skipna=True))
    print("Used values:", len(df_filt['AVG_VEH_ONS (SUM)']) - df_filt['AVG_VEH_ONS (SUM)'].isna().sum())
    print("Discarded values:", df_filt['AVG_VEH_ONS (SUM)'].isna().sum())
    
    
    print("--------------------------------------------------")
# Out:
# Index(['029', '043', '054', '048', '044', '024', '019', '023', '031', '010',
#        '036', '014', '022', '038', '007', '001', '008', '009', '006', '018',
#        '033', '037', '027', '057', '028', '012', '049', '005', '030', 'F',
#        '052', '091', '045', '002', '060', '021', '047', '009R', '035', '003',
#        '066', '059', '005R', '067', '038R', '061', '056', '014R', 'N-OWL',
#        '025', '055', 'L-OWL', '041', '039', '090', '008BX', 'E', '028R',
#        '007X', '014X', 'KLM', '008AX', '030X', '031AX', '001AX', '038BX',
#        '031BX', '001BX', '038AX', 'NX', '082X', 'K-OWL', '083X', '088', '081X',
#        '714'],
#       dtype='object')
# ----------------------49--------------------------
# 1560
# Sum of AVG_VEH_DEPARTING_LOAD (AVG): 29578.733316008205
# Used values: 1560
# Discarded values: 0
# Sum of AVG_VEH_DEPARTING_LOAD (SUM): 194160.92176996474
# Used values: 1560
# Discarded values: 0
# Sum of AVG_VEH_ONS (SUM): 25152.441069744105
# Used values: 1560
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a list of dataframes
dfs = [SF_jan2020, SF_mar2021, SF_sep2021, SF_jan2023, SF_feb2023, SF_apr2023]

ridership_data = []  # This list will hold ridership data for each day for plotting.

# Iterate over the dataframes in the list
for df in dfs:
    # ... (Your existing print statements here)

    df_filtered = df[df['ROUTE_ALPHA'] == '049']
    
    # Store the sum of ridership for the column 'AVG_VEH_ONS (SUM)1' for plotting
    ridership_data.append(df_filtered['AVG_VEH_ONS (SUM)'].sum(skipna=True))

# Plotting the data
dates = ['Jan 2020', 'Mar 2021', 'Sep 2021', 'Jan 2023', 'Feb 2023', 'Apr 2023']  # You might adjust these based on your data
plt.figure(figsize=(10, 6))
plt.plot(dates, ridership_data, marker='o', linestyle='-')
plt.title('Ridership per Day')
plt.xlabel('Date')
plt.xticks(rotation=45)


plt.ylabel('Ridership')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
scale = 0.3
events_baseline = pd.read_csv('gs://beam-core-outputs/sfbay-baseline2018-30pct-20230710/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz',nrows = None,
                             usecols=['type','startX','startY','vehicle','time','numPassengers'])
# Out:
# KeyboardInterrupt

# %%
path_trav = events_baseline[events_baseline.type == 'PathTraversal']
path_trav = path_trav.dropna(axis=1, how='any')
path_trav = path_trav[path_trav.vehicle.str.contains('SF:')]


SF_GTFS_trips = pd.read_csv('/Users/cpoliziani/Documents/repo/beam-data-sfbay/r5-simple-no-local/SF/trips.txt')
SF_GTFS_trips = SF_GTFS_trips[SF_GTFS_trips.route_id == 12327]#12327]


trips_49 = ["SF:" + str(i) for i in list(SF_GTFS_trips.trip_id.value_counts().keys())]
result = path_trav[path_trav['vehicle'].isin(trips_49)] ## change path_trav=path_trav

result['numPassengers']/=scale
result['numPassengers'] = result['numPassengers'].astype(int)
print('Ridership SUM', routeID, ': ', sum(result.numPassengers))

pers_enter = events_baseline[events_baseline.type == 'PersonEntersVehicle']
pers_enter = pers_enter[pers_enter.vehicle.str.contains('SF:')]
pers_enter = pers_enter[pers_enter['vehicle'].isin(trips_49)]
print('Ridership ', routeID, ': ', len(pers_enter)/scale)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample DataFrame
df = SF_49
variable = 'AVG_VEH_DEPARTING_LOAD (SUM)'
# Determine the range and create custom bins
min_val = df[variable].min()
max_val = df[variable].max()
bins = np.linspace(min_val, max_val, 11)  # 10 bins

# Plotting the distribution of all values
df[variable].hist(bins=bins, edgecolor='black', color='lightblue', alpha=0.7, label='Other Values')

# Highlight the zero bar with a different color
zero_count = (df[variable] < 1).sum()
plt.bar(0, zero_count, width=(max_val - min_val)/10, color='red', label='Zero Value')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of AVG_VEH_OFFS (SUM) values')
plt.legend()
plt.show()

# %%
import seaborn as sns

df = SF_49


plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='TRIP_START_HOUR', weights='AVG_VEH_DEPARTING_LOAD (SUM)', bins=20, kde=True)

plt.title(f'Stop: {stop}, Direction: {direction}')
plt.xlabel('Hour')
plt.ylabel('Number of Passengers')

plt.show()
print('Wrong:',wrong)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample DataFrame
df = SF_49
variable = 'AVG_VEH_OFFS (SUM)'
# Determine the range and create custom bins
min_val = df[variable].min()
max_val = df[variable].max()
bins = np.linspace(min_val, max_val, 11)  # 10 bins

# Plotting the distribution of all values
df[variable].hist(bins=bins, edgecolor='black', color='lightblue', alpha=0.7, label='Other Values')

# Highlight the zero bar with a different color
zero_count = (df[variable] < 1).sum()
plt.bar(0, zero_count, width=(max_val - min_val)/10, color='red', label='Zero Value')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of AVG_VEH_OFFS (SUM) values')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample DataFrame
df = SF_49
variable = 'AVG_VEH_ONS (SUM)'
# Determine the range and create custom bins
min_val = df[variable].min()
max_val = df[variable].max()
bins = np.linspace(min_val, max_val, 11)  # 10 bins

# Plotting the distribution of all values
df[variable].hist(bins=bins, edgecolor='black', color='lightblue', alpha=0.7, label='Other Values')

# Highlight the zero bar with a different color
zero_count = (df[variable] < 1).sum()
plt.bar(0, zero_count, width=(max_val - min_val)/10, color='red', label='Zero Value')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of AVG_VEH_OFFS (SUM) values')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample DataFrame
df = SF_49
variable = 'AVG_VEH_ONS (SUM)1'
# Determine the range and create custom bins
min_val = df[variable].min()
max_val = df[variable].max()
bins = np.linspace(min_val, max_val, 11)  # 10 bins

# Plotting the distribution of all values
df[variable].hist(bins=bins, edgecolor='black', color='lightblue', alpha=0.7, label='Other Values')

# Highlight the zero bar with a different color
zero_count = (df[variable] < 1).sum()
plt.bar(0, zero_count, width=(max_val - min_val)/10, color='red', label='Zero Value')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distribution of AVG_VEH_OFFS (SUM) values')
plt.legend()
plt.show()

# %% [markdown]
# # ***Line by Line Comparison***

# %%
#Determine SUM of hourly load per direction per starting stop and hour
scale = 0.3
nrows = None
events_baseline = pd.read_csv('gs://beam-core-outputs/sfbay-baseline2018-30pct-20230825/beam/year-2018-iteration-4/ITERS/it.0/0.events.csv.gz',
                             usecols=['type','startX','startY','vehicle','time','numPassengers'], nrows = nrows)
# 'gs://beam-core-outputs/sfbay-baseline2018-30pct-20230710/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz':'Base18.10',\n",
#     "            # 'gs://beam-core-outputs/sfbay-tr-30pct-20230716/beam/year-2018-iteration-10/ITERS/it.0/0.events.csv.gz':'TR18.10',\n",
# Out:
# /var/folders/h9/g8d27p9s5js3dx9z7b5y8k5c0000gr/T/ipykernel_31028/3200115508.py:4: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   events_baseline = pd.read_csv('gs://beam-core-outputs/sfbay-baseline2018-30pct-20230825/beam/year-2018-iteration-4/ITERS/it.0/0.events.csv.gz',

# %%
Route_ID_dict = {
    '044': '12323',
    '010': '12295',
    '019': '12301',
    '006': '12289',
    '057': '12332',
    '039': '12320',
    '036': '12316',
    '009': '12293',
#     '090': '12341',
    '009R': '12294',
    '012': '12296',
    '047': '12325',
    '027': '12307',
    '037': '12317',
#     'L-OWL': '1103',
    '043': '12322',
    '048': '12326',
    '066': '12335',
    '014': '12297',
    '049': '12327',
    '035': '12315',
    '008': '1110',
    '008BX': '1109',
    '091': '12342',
    '055': '12330',
    '022': '12303',
    '033': '12314',
#     'F': '12345',
#     'E': '12344',
    'NX': '12351',
    '028': '12308',
    '028R': '12309',
    '018': '12300',
    '029': '12310',
    '007': '1071',
    '007X': '12291',
    '067': '12336',
    '024': '12305',
    '054': '12329',
    '038': '12318',
    '001': '12283',
    '001AX': '1033',
    '056': '12331',
    '008AX': '1108',
    '030': '12311',
    '045': '12324',
    '081X': '1081',
    '031': '12313',
    '031AX': '1031',
    '038AX': '1038',
    '038R': '12319',
    '005': '12287',
    '005R': '12288',
#     'N-OWL': '1105',
    '052': '12328',
    '001BX': '1034',
    '014X': '12299',
    '083X': '12339',
    '025': '12304',
    '002': '12285',
    '041': '12321',
    '088': '12340',
#     '714': None,
    '031BX': '1032',
    '082X': '1082',
    '023': '12304',
    '030X': '12312',
#     'KLM': None,
    '003': '12286',
    '038BX': '1039',
#     '061': None,
#     'K-OWL': 1102,
#     '059': None,
    '014R': '12298',
    '021': '12302',
#     '060': None
}

# %%
Obs_database = SF_jan2020

route_names =  Route_ID_dict.keys()

sims = []
obss = []
sims2 = []
obss2 = []
path_trav = events_baseline[events_baseline.type == 'PathTraversal']
person_enter = events_baseline[events_baseline.type == 'PersonEntersVehicle']
path_trav = path_trav.dropna(axis=1, how='any')
path_trav.keys()
path_trav = path_trav[path_trav.vehicle.str.contains('SF:')]
person_enter = person_enter[person_enter.vehicle.str.contains('SF:')]

for routeID in route_names:

    SF_GTFS_trips = pd.read_csv('/Users/cpoliziani/Documents/repo/beam-data-sfbay/r5-simple-no-local/SF/trips.txt')
    SF_GTFS_trips = SF_GTFS_trips[SF_GTFS_trips.route_id == int(Route_ID_dict[routeID])]#12327]
    

    trips_incr = ["SF:" + str(i) for i in list(SF_GTFS_trips.trip_id.value_counts().keys())]
    result = path_trav[path_trav['vehicle'].isin(trips_incr)] ## change path_trav=path_trav
    per_enter = person_enter[person_enter['vehicle'].isin(trips_incr)]

    result['numPassengers']/=scale
    result['numPassengers'] = result['numPassengers'].astype(int)
    print('Ridership ', routeID, ': ', sum(result.numPassengers))
    print('Ridership ', routeID, ': ', len(per_enter)/scale)
    sims.append( sum(result.numPassengers))
    sims2.append(len(per_enter)/scale)
    #Observed
    obs = sum(Obs_database[Obs_database['ROUTE_ALPHA'] == routeID]['AVG_VEH_DEPARTING_LOAD (SUM)'])
    obs2 = sum(Obs_database[Obs_database['ROUTE_ALPHA'] == routeID]['AVG_VEH_ONS (SUM)'])
    print('Obs Ridership ', routeID, ': ', obs)
    print('Obs Ridership ', routeID, ': ', obs2)
    obss.append( obs)
    obss2.append( obs2)
df = pd.DataFrame({
    'Route - SF': route_names,
    'Observed average daily boardings': obss2,
    'Simulated daily boardings': sims2
})
df.to_csv('SF - ridership by line')
# Out:
# /var/folders/h9/g8d27p9s5js3dx9z7b5y8k5c0000gr/T/ipykernel_31028/2777607897.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['numPassengers']/=scale
# /var/folders/h9/g8d27p9s5js3dx9z7b5y8k5c0000gr/T/ipykernel_31028/2777607897.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['numPassengers'] = result['numPassengers'].astype(int)
# Ridership  044 :  150420
# Ridership  044 :  16533.333333333336
# Obs Ridership  044 :  205335.82279392195
# ...

# %%
route_names
# Out:
# dict_keys(['044', '010', '019', '006', '057', '039', '036', '009', '009R', '012', '047', '027', '037', '043', '048', '066', '014', '049', '035', '008', '008BX', '091', '055', '022', '033', 'NX', '028', '028R', '018', '029', '007', '007X', '067', '024', '054', '038', '001', '001AX', '056', '008AX', '030', '045', '081X', '031', '031AX', '038AX', '038R', '005', '005R', '052', '001BX', '014X', '083X', '025', '002', '041', '088', '031BX', '082X', '023', '030X', '003', '038BX', '014R', '021'])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress



cleaned_pairs = [(x, y) for x, y in zip(obss2, sims2) if not np.isnan(x) and not x == 0]
cleaned_list1, cleaned_list2 = zip(*cleaned_pairs)

obsss = cleaned_list1
simss = cleaned_list2

# For demonstration purposes, let's create a dummy list of route names
# Compute the regression line
slope, intercept, r_value, _, _ = linregress(obsss, simss)
line = [slope*xi + intercept for xi in obsss]

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(obsss, simss, color='blue', label='Average Daily Ridership')

# Add labels for specific routes
for x, y, route in zip(obsss, simss, route_names):
    if route == '049':
        plt.text(x+5000, y-1400, '49 Van Ness', fontsize=12, ha='right')
    if route == '030':
        plt.text(x+5000, y-1400, '30 Stockton', fontsize=12, ha='right')
plt.plot(obsss, line, color='red', label=f'Regression line: y = {slope:.2f}x + {intercept:.2f} \nR-squared value: {r_value**2:.2f}')
plt.xlabel('Observed',fontsize=12)
plt.ylabel('Simulated',fontsize=12)
plt.legend(fontsize=12, title_fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)
plt.savefig("SF_LinebyLine_Ridership.png", dpi=300)

plt.show()

# %%
route_names =  Route_ID_dict.keys()

sims = []
obss = []
path_trav = events_baseline[events_baseline.type == 'PathTraversal']
path_trav = path_trav.dropna(axis=1, how='any')
path_trav.keys()
path_trav = path_trav[path_trav.vehicle.str.contains('SF:')]

for routeID in route_names:

    #filter line 49 trips
    SF_GTFS_trips = pd.read_csv('/Users/cpoliziani/Documents/repo/beam-data-sfbay/r5-simple-no-local/SF/trips.txt')
    SF_GTFS_trips = SF_GTFS_trips[SF_GTFS_trips.route_id == int(Route_ID_dict[routeID])]#12327]
    

    trips_49 = ["SF:" + str(i) for i in list(SF_GTFS_trips.trip_id.value_counts().keys())]

    final_df = path_trav[path_trav['vehicle'].isin(trips_49)] ## change path_trav=path_trav

    final_df['hour'] = (final_df['time']/3600).astype(int)

    result = final_df.groupby(['hour'])['numPassengers'].sum().reset_index()


    result['numPassengers']/=scale
    result['numPassengers'] = result['numPassengers'].astype(int)
    print('Ridership ', routeID, ': ', sum(result.numPassengers))
    
    result_dict = dict(zip(result['hour'], result['numPassengers']))

    for hour in list(range(5, 25)):
        try:
            sims.append(result_dict[hour])
        except:
            sims.append(0)
        try:
            obss.append(sum(SF_jan2020[(SF_jan2020['ROUTE_ALPHA'] == routeID)&(SF_jan2020['TRIP_START_HOUR'] == hour)]['AVG_VEH_DEPARTING_LOAD (SUM)']))
        except:
            obss.append(0)

    #Observed
    
#     obs = sum(SF_jan2020[SF_jan2020['ROUTE_ALPHA'] == routeID]['AVG_VEH_DEPARTING_LOAD (SUM)'])
    print('Obs Ridership ', routeID, ': ', obs)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Compute the regression line with intercept set to 0
slope, _, r_value, _, _ = linregress(obss, sims)
line = [slope*xi for xi in obss]  # intercept is 0

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(obss, sims, color='blue', label='Data points')
plt.plot(obss, line, color='red', label=f'Regression line: y = {slope:.2f}x')
plt.title(f'R-squared value: {r_value**2:.2f}')
plt.xlabel('Observed')
plt.ylabel('Simulated')
plt.legend()
plt.grid(True)
plt.show()

# %%
route_names =  Route_ID_dict.keys()

sims = []
obss = []
person_enters = events_baseline[events_baseline.type == 'PersonEntersVehicle']
person_enters = person_enters.dropna(axis=1, how='any')
person_enters = person_enters[person_enters.vehicle.str.contains('SF:')]

for routeID in route_names:

    #filter line 49 trips
    SF_GTFS_trips = pd.read_csv('/Users/cpoliziani/Documents/repo/beam-data-sfbay/r5-simple-no-local/SF/trips.txt')
    SF_GTFS_trips = SF_GTFS_trips[SF_GTFS_trips.route_id == int(Route_ID_dict[routeID])]#12327]
    

    trips_49 = ["SF:" + str(i) for i in list(SF_GTFS_trips.trip_id.value_counts().keys())]

    final_df = person_enters[person_enters['vehicle'].isin(trips_49)] ## change person_enters=person_enters

    final_df['hour'] = (final_df['time']/3600).astype(int)
    final_df['numPassengers'] = 1.

    result = final_df.groupby(['hour'])['numPassengers'].sum().reset_index()


    result['numPassengers']/=scale
    result['numPassengers'] = result['numPassengers'].astype(int)
    
    result_dict = dict(zip(result['hour'], result['numPassengers']))
    simss = []
    obsss = []
    for hour in list(range(5, 25)):
        try:
            simss.append(result_dict[hour])
        except:
            simss.append(0)
        try:
            obsss.append(sum(SF_jan2020[(SF_jan2020['ROUTE_ALPHA'] == routeID)&(SF_jan2020['TRIP_START_HOUR'] == hour)]['AVG_VEH_ONS (SUM)']))
        except:
            obsss.append(0)
    sims.append(simss)
    obss.append(obsss)
    #Observed
    
#     obs = sum(SF_jan2020[SF_jan2020['ROUTE_ALPHA'] == routeID]['AVG_VEH_DEPARTING_LOAD (SUM)'])
    print('Sim Ridership ', routeID, ': ', np.sum(simss))

    print('Obs Ridership ', routeID, ': ', np.sum(obsss))
# Out:
# /var/folders/h9/g8d27p9s5js3dx9z7b5y8k5c0000gr/T/ipykernel_3185/2218823860.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['hour'] = (final_df['time']/3600).astype(int)
# /var/folders/h9/g8d27p9s5js3dx9z7b5y8k5c0000gr/T/ipykernel_3185/2218823860.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['numPassengers'] = 1.
# /var/folders/h9/g8d27p9s5js3dx9z7b5y8k5c0000gr/T/ipykernel_3185/2218823860.py:20: SettingWithCopyWarning:
# ...

# %%
nrows = 13
ncols = 5

fig, axes = plt.subplots(nrows, ncols, figsize=(20, 40))

# Create a list to store the line objects for the legend
lines = []

for i, (ax, name) in enumerate(zip(axes.ravel(), Route_ID_dict.keys())):
    try:
        if i < len(obss):
            # Plot absolute values
            line1, = ax.plot(obss[i], marker='o', label='Observed')
            line2, = ax.plot(sims[i], marker='x', label='Simulated')

            ax.set_title(name)
#             ax.set_xlabel('Day')
#             ax.set_ylabel('Number of Trips')  # Updated ylabel to 'Number of Trips'
            ax.grid(True)

            # Append the line objects to the list
            if i == 0:
                lines.extend([line1, line2])
        else:
            # Turn off the axis for any extra subplots
            ax.axis('off')
    except:
        print('Warning')

# Add a single legend for the entire figure
fig.legend(handles=lines, loc='lower center', ncol=2, bbox_to_anchor=(0.5, 0))

plt.tight_layout()
plt.subplots_adjust(bottom=0.08)  # Adjust the bottom space to accommodate the legend
plt.savefig('/Users/cpoliziani/Downloads/Transit Rich/distribution_trips_SF2.png', dpi = 600)
plt.show()

# %%
import numpy as np
from scipy.stats import pearsonr, spearmanr, ks_2samp
from sklearn.metrics import mean_squared_error

# Sample data (replace these with your actual lists)

for obs, sim in zip(obss, sims):
    # Pearson Correlation Coefficient
    pearson_corr, _ = pearsonr(obs, sim)
    print(f"Pearson Correlation: {pearson_corr:.2f}")
    print("  (Range: -1 to 1. Closer to 1 or -1 indicates stronger linear relationship. 0 indicates no linear relationship.)")
    
    # RMSE
    rmse = np.sqrt(mean_squared_error(obs, sim))
    print(f"RMSE: {rmse:.2f}")
    print("  (Range: >= 0. Lower values indicate better fit. Depends on the scale of your data.)")
    
    # Kolmogorov-Smirnov Test
    ks_stat, ks_pvalue = ks_2samp(obs, sim)
    print(f"KS Statistic: {ks_stat:.2f}, P-value: {ks_pvalue:.2f}")
    print("  (KS Statistic Range: 0 to 1. Closer to 0 indicates more similar distributions. P-value < 0.05 typically indicates statistically different distributions.)")
    
    # Spearman Rank Correlation
    spearman_corr, _ = spearmanr(obs, sim)
    print(f"Spearman Correlation: {spearman_corr:.2f}")
    print("  (Range: -1 to 1. Closer to 1 or -1 indicates stronger monotonic relationship. 0 indicates no monotonic relationship.)")
    
    print("------")
# Out:
# Pearson Correlation: 0.66
#   (Range: -1 to 1. Closer to 1 or -1 indicates stronger linear relationship. 0 indicates no linear relationship.)
# RMSE: 4895.07
#   (Range: >= 0. Lower values indicate better fit. Depends on the scale of your data.)
# KS Statistic: 0.25, P-value: 0.57
#   (KS Statistic Range: 0 to 1. Closer to 0 indicates more similar distributions. P-value < 0.05 typically indicates statistically different distributions.)
# Spearman Correlation: 0.67
#   (Range: -1 to 1. Closer to 1 or -1 indicates stronger monotonic relationship. 0 indicates no monotonic relationship.)
# ------
# Pearson Correlation: 0.62
#   (Range: -1 to 1. Closer to 1 or -1 indicates stronger linear relationship. 0 indicates no linear relationship.)
# RMSE: 3298.60
#   (Range: >= 0. Lower values indicate better fit. Depends on the scale of your data.)
# KS Statistic: 0.40, P-value: 0.08
# ...

# %%
pearson_corrs = []
rmses = []
ks_stats = []
spearman_corrs = []

for obs, sim in zip(obss, sims):
    # Pearson Correlation Coefficient
    pearson_corr, _ = pearsonr(obs, sim)
    pearson_corrs.append(pearson_corr)
    
    # RMSE
    rmse = np.sqrt(mean_squared_error(obs, sim))
    rmses.append(rmse)
    
    # Kolmogorov-Smirnov Test
    ks_stat, _ = ks_2samp(obs, sim)
    ks_stats.append(ks_stat)
    
    # Spearman Rank Correlation
    spearman_corr, _ = spearmanr(obs, sim)
    spearman_corrs.append(spearman_corr)

# Aggregated metrics
print(f"Average Pearson Correlation: {np.mean(pearson_corrs):.2f}")
print(f"Average RMSE: {np.mean(rmses):.2f}")
print(f"Average KS Statistic: {np.mean(ks_stats):.2f}")
print(f"Average Spearman Correlation: {np.mean(spearman_corrs):.2f}")
# Out:
# Average Pearson Correlation: 0.61
# Average RMSE: 2922.27
# Average KS Statistic: 0.39
# Average Spearman Correlation: 0.62

# %%
route_names =  Route_ID_dict.keys()

sims = []
obss = []
path_trav = events_baseline[events_baseline.type == 'PathTraversal']
path_trav = path_trav.dropna(axis=1, how='any')
path_trav.keys()
path_trav = path_trav[path_trav.vehicle.str.contains('SF:')]

for routeID in route_names:

    #filter line 49 trips
    SF_GTFS_trips = pd.read_csv('/Users/cpoliziani/Documents/repo/beam-data-sfbay/r5-simple-no-local/SF/trips.txt')
    SF_GTFS_trips = SF_GTFS_trips[SF_GTFS_trips.route_id == int(Route_ID_dict[routeID])]#12327]
    
    ###
    #filter line 49 stoptimes
    SF_GTFS_stoptimes = pd.read_csv('/Users/cpoliziani/Documents/repo/beam-data-sfbay/r5-simple-no-local/SF/stop_times.txt')
    SF_GTFS_stoptimes = SF_GTFS_stoptimes[SF_GTFS_stoptimes.trip_id.isin(list(SF_GTFS_trips.trip_id))]
    #filter line 49 stops
    SF_stops = pd.read_csv('/Users/cpoliziani/Documents/repo/beam-data-sfbay/r5-simple-no-local/SF/stops.txt')
    SF_stops = SF_stops[SF_stops.stop_id.isin(list(SF_GTFS_stoptimes.stop_id))]
    ###
    trips_49 = ["SF:" + str(i) for i in list(SF_GTFS_trips.trip_id.value_counts().keys())]
    #filter pathtraversal based on line 49 trips
    path_trav = path_trav[path_trav['vehicle'].isin(trips_49)] ## change path_trav=path_trav
    # add trip info, in particular direction
    ###
    SF_GTFS_trips['trip_id'] = 'SF:' + SF_GTFS_trips['trip_id'].astype(str)
    merged_df = path_trav.merge(SF_GTFS_trips, left_on='vehicle', right_on='trip_id', how='left')
    merged_df['is_outbound'] = merged_df['direction_id'] == 0
    # add stop info, in particular stop name
    def euclidean_distance(x1, y1, x2, y2):
        return np.sqrt((x1 - x2)**2 + (y1 - y2)**2)
    # Find the closest stop for each row in merged_df
    def closest_stop(row):
        distances = SF_stops.apply(lambda stop: euclidean_distance(row['startX'], row['startY'], stop['stop_lon'], stop['stop_lat']), axis=1)
        return distances.idxmin()
    ### Add stop
    merged_df['closest_stop_idx'] = merged_df.apply(closest_stop, axis=1)
    final_df = merged_df.merge(SF_stops, left_on='closest_stop_idx', right_index=True, how='left')
    ###
    #add hour info
    final_df['hour'] = (final_df['time']/3600).astype(int)
    pers_enter = events_baseline[events_baseline.type == 'PersonEntersVehicle']
    pers_enter = pers_enter[pers_enter.vehicle.str.contains('SF:')]
    pers_enter = pers_enter[pers_enter['vehicle'].isin(trips_49)]
    result = final_df.groupby(['hour', 'direction_id', 'stop_name'])['numPassengers'].sum().reset_index()
    # 30%
    ###

    result['numPassengers']/=scale
    result['numPassengers'] = result['numPassengers'].astype(int)
    print('Ridership ', routeID, ': ', sum(result.numPassengers))
    sims.append( sum(result.numPassengers))
    #Observed
    obs = sum(SF_jan2020[SF_jan2020['ROUTE_ALPHA'] == routeID]['AVG_VEH_DEPARTING_LOAD (SUM)'])
    print('Obs Ridership ', routeID, ': ', obs)
    obss.append( obs)

# %%
sum(result.numPassengers)

# %% [markdown]
# # ***Compare all SF riderships***

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import contextily as ctx

# Given lats and lons
lats = list(SF_49['STOP_LAT'])
lons = list(SF_49['STOP_LONG'])

# Convert the coordinates to a GeoDataFrame
gdf = gpd.GeoDataFrame(
    {'geometry': gpd.points_from_xy(lons, lats)},
    crs="EPSG:4326"
)

# Plot the coordinates
ax = gdf.plot(figsize=(10, 10), markersize=50, color='red')

# Add OSM basemap
ctx.add_basemap(ax, crs=gdf.crs.to_string(), source=ctx.providers.OpenStreetMap.Mapnik)

plt.show()

# %%
min(lats)
# Out:
# 37.72286

# %%
max(lats)
# Out:
# 37.805161
