# %%
#Imports
import numpy as np
import pandas as pd
import difflib
import matplotlib.pyplot as plt

# %%
GTFS_filepath_old = '/Users/cpoliziani/Downloads/Data/TR/Jan2020 GTFS/SF20201222/'
GTFS_filepath_new = '/Users/cpoliziani/Downloads/Data/TR/old-new GTFS/SF20220611/'

agency1 = pd.read_csv(GTFS_filepath_old+'agency.txt')
agency2 = pd.read_csv(GTFS_filepath_new+'agency.txt')
# calendar_dates = pd.read_csv(GTFS_filepath+'calendar_dates.txt')
# calendar = pd.read_csv(GTFS_filepath+'calendar.txt')
# fare_attributes = pd.read_csv(GTFS_filepath+'fare_attributes.txt')
# fare_rules = pd.read_csv(GTFS_filepath+'fare_rules.txt')
# feed_info = pd.read_csv(GTFS_filepath+'feed_info.txt')
routes1 = pd.read_csv(GTFS_filepath_old+'routes.txt')
routes2 = pd.read_csv(GTFS_filepath_new+'routes.txt')
# shapes = pd.read_csv(GTFS_filepath+'shapes.txt')
# stop_times = pd.read_csv(GTFS_filepath+'stop_times.txt')
# stops = pd.read_csv(GTFS_filepath+'stops.txt')
# trips = pd.read_csv(GTFS_filepath+'trips.txt')

# %%
new_routes_long = []
new_routes_short = []

for new_short, new_long in zip(routes2['route_short_name'],routes2['route_long_name']):
    if str(new_long) not in list(routes1['route_long_name']) :
        new_routes_long.append(new_long)
    if str(new_short) not in list(routes1['route_short_name']) :
        new_routes_short.append(new_long)
print(new_routes_long)
print(new_routes_short)
# Out:
# ['FULTON RAPID', 'BAYSHORE A EXPRESS', 'BAYSHORE B EXPRESS', 'BAYVIEW HUNTERS POINT EXPRESS', '46TH AVENUE', 'MONTEREY', 'BRYANT', 'BALBOA', 'ASHBURY-18TH ST', 'EUREKA', 'TERESITA', 'COIT', 'EXCELSIOR', 'DOGPATCH', 'RUTLAND', 'PARKMERCED', 'LAKE MERCED', 'POWELL-MASON CABLE CAR', 'POWELL-HYDE CABLE CAR', 'CALIFORNIA STREET CABLE CAR', 'QUINTARA', 'MARKET & WHARVES', 'INGLESIDE-THIRD', 'OCEAN VIEW', 'JUDAH', 'THIRD BUS SHUTTLE']
# ['FULTON RAPID', 'BAYSHORE A EXPRESS', 'BAYSHORE B EXPRESS', 'BAYVIEW HUNTERS POINT EXPRESS', '46TH AVENUE', 'MONTEREY', 'BRYANT', 'BALBOA', 'ASHBURY-18TH ST', 'EUREKA', 'TERESITA', 'COIT', 'EXCELSIOR', 'DOGPATCH', 'RUTLAND', 'PARKMERCED', 'LAKE MERCED', 'POWELL-MASON CABLE CAR', 'POWELL-HYDE CABLE CAR', 'CALIFORNIA STREET CABLE CAR', 'QUINTARA', 'MARKET & WHARVES', 'INGLESIDE-THIRD', 'OCEAN VIEW', 'JUDAH']

# %%
new_routes_long = []
new_routes_short = []

for new_short, new_long in zip(routes1['route_short_name'],routes1['route_long_name']):
    if str(new_long) not in list(routes2['route_long_name']) :
        new_routes_long.append(new_long)
    if str(new_short) not in list(routes2['route_short_name']) :
        new_routes_short.append(new_long)
print(new_routes_long)
print(new_routes_short)
# Out:
# ['OCEAN VIEW BUS', 'THIRD BUS']
# ['OCEAN VIEW BUS']

# %%
routes1
# Out:
#     route_id agency_id route_short_name       route_long_name route_desc  \
# 0      15761     SFMTA                1            CALIFORNIA
# 1      15766     SFMTA                5                FULTON
# 2      15769     SFMTA                7        HAIGHT-NORIEGA
# 3      15771     SFMTA                8              BAYSHORE
# 4      15774     SFMTA                9             SAN BRUNO
# 5      15775     SFMTA               9R       SAN BRUNO RAPID
# 6      15777     SFMTA               12        FOLSOM-PACIFIC
# 7      15778     SFMTA               14               MISSION
# 8      15779     SFMTA              14R         MISSION RAPID
# 9      15782     SFMTA               19                  POLK
# 10     15784     SFMTA               22              FILLMORE
# 11     15786     SFMTA               24            DIVISADERO
# 12     15787     SFMTA               25       TREASURE ISLAND
# 13     15789     SFMTA               28           19TH AVENUE
# ...

# %%
routes2
# Out:
#     route_id agency_id route_short_name    route_long_name route_desc  \
# 0      18609     SFMTA                1         CALIFORNIA
# 1      18614     SFMTA                5             FULTON
# 2      18615     SFMTA               5R       FULTON RAPID
# 3      18617     SFMTA                7     HAIGHT-NORIEGA
# 4      18619     SFMTA                8           BAYSHORE
# ..       ...       ...              ...                ...        ...
# 56     18697     SFMTA                M         OCEAN VIEW
# 57     18700     SFMTA                N              JUDAH
# 58     18701     SFMTA            N-OWL          OWL JUDAH
# 59     18702     SFMTA             NBUS          JUDAH BUS
# 60     18709     SFMTA             TBUS  THIRD BUS SHUTTLE
#
#     route_type                          route_url route_color route_text_color
# 0            3  https://SFMTA.com/1                   005B95           FFFFFF
# 1            3  https://SFMTA.com/5                   005B95           FFFFFF
# ...

# %%
agency1
# Out:
#   agency_id                                    agency_name         agency_url  \
# 0     SFMTA  San Francisco Municipal Transportation Agency  https://SFMTA.com
#
#        agency_timezone agency_lang
# 0  America/Los_Angeles          en

# %%
agency2
# Out:
#           agency_url                                    agency_name  \
# 0  https://SFMTA.com  San Francisco Municipal Transportation Agency
#
#        agency_timezone agency_id agency_lang
# 0  America/Los_Angeles     SFMTA          en
