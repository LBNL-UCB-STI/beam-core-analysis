# %%
#! pip install geopandas
#! pip install pandas
#! pip install pygeos
#! pip install boto
#! pip install s3fs
#! pip install shapely
#! pip install gcsfs
#!pip install contextily
#!pip install matplotlib-scalebar
#!pip install sklearn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gzip
import time
from itertools import groupby
import geopandas as gpd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib_scalebar.scalebar import ScaleBar
import matplotlib.ticker as ticker
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# Out:
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\geopandas\_compat.py:124: UserWarning: The Shapely GEOS version (3.11.2-CAPI-1.17.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\128990315.py:18: DeprecationWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas still uses PyGEOS by default. However, starting with version 0.14, the default will switch to Shapely. To force to use Shapely 2.0 now, you can either uninstall PyGEOS or set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In the next release, GeoPandas will switch to using Shapely by default, even if PyGEOS is installed. If you only have PyGEOS installed to get speed-ups, this switch should be smooth. However, if you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
# measure time
import time

start = time.time()

# %%
cordon_zones = ['060750615006',
'060750615005',
'060750615004',
'060750615003',
'060750615002',
'060750615001',
'060750611003',
'060750611002',
'060750611001',
'060750607003',
'060750607002',
'060750607001',
'060750202001',
'060750201004',
'060750201003',
'060750201002',
'060750201001',
'060750180002',
'060750180001',
'060750178022',
'060750178021',
'060750178012',
'060750178011',
'060750177002',
'060750177001',
'060750176015',
'060750176014',
'060750176013',
'060750176012',
'060750176011',
'060750168023',
'060750168021',
'060750162003',
'060750162002',
'060750162001',
'060750125022',
'060750125021',
'060750125012',
'060750125011',
'060750124023',
'060750124022',
'060750124021',
'060750124012',
'060750124011',
'060750123022',
'060750123021',
'060750123012',
'060750123011',
'060750122021',
'060750122012',
'060750122011',
'060750121002',
'060750121001',
'060750120002',
'060750120001',
'060750119022',
'060750119021',
'060750119012',
'060750119011',
'060750118001',
'060750117002',
'060750117001',
'060750113002',
'060750113001',
'060750112003',
'060750112002',
'060750112001',
'060750111003',
'060750111002',
'060750111001',
'060750110003',
'060750110002',
'060750110001',
'060750109003',
'060750109002',
'060750109001',
'060750108003',
'060750108002',
'060750108001',
'060750107004',
'060750107003',
'060750107002',
'060750107001',
'060750106003',
'060750106002',
'060750106001',
'060750105002',
'060750105001',
'060750104004',
'060750104003',
'060750104002',
'060750104001',
'060750103003',
'060750103002',
'060750103001',
'060750102003',
'060750102002',
'060750102001',
'060750101002',
'060750101001']

SF_zones = ['060750101001',
'060750101002',
'060750102001',
'060750102002',
'060750102003',
'060750103001',
'060750103002',
'060750103003',
'060750104001',
'060750104002',
'060750104003',
'060750104004',
'060750105001',
'060750105002',
'060750106001',
'060750106002',
'060750106003',
'060750107001',
'060750107002',
'060750107003',
'060750107004',
'060750108001',
'060750108002',
'060750108003',
'060750109001',
'060750109002',
'060750109003',
'060750110001',
'060750110002',
'060750110003',
'060750111001',
'060750111002',
'060750111003',
'060750112001',
'060750112002',
'060750112003',
'060750113001',
'060750113002',
'060750117001',
'060750117002',
'060750118001',
'060750119011',
'060750119012',
'060750119021',
'060750119022',
'060750120001',
'060750120002',
'060750121001',
'060750121002',
'060750122011',
'060750122012',
'060750122021',
'060750123011',
'060750123012',
'060750123021',
'060750123022',
'060750124011',
'060750124012',
'060750124021',
'060750124022',
'060750124023',
'060750125011',
'060750125012',
'060750125021',
'060750125022',
'060750126011',
'060750126021',
'060750126022',
'060750127001',
'060750127002',
'060750127003',
'060750128001',
'060750128002',
'060750128003',
'060750128004',
'060750129011',
'060750129012',
'060750129021',
'060750129022',
'060750129023',
'060750130001',
'060750130002',
'060750130003',
'060750130004',
'060750131011',
'060750131012',
'060750131021',
'060750131022',
'060750132001',
'060750132002',
'060750132003',
'060750133001',
'060750133002',
'060750133003',
'060750133004',
'060750133005',
'060750134001',
'060750134002',
'060750134003',
'060750135001',
'060750135002',
'060750151001',
'060750151002',
'060750152001',
'060750152002',
'060750152003',
'060750153001',
'060750153002',
'060750154001',
'060750154002',
'060750154003',
'060750154004',
'060750154005',
'060750155001',
'060750155002',
'060750155003',
'060750156001',
'060750156002',
'060750156003',
'060750157001',
'060750157002',
'060750157003',
'060750157004',
'060750158011',
'060750158012',
'060750158013',
'060750158021',
'060750158022',
'060750159001',
'060750159002',
'060750160001',
'060750161001',
'060750161002',
'060750161003',
'060750161004',
'060750162001',
'060750162002',
'060750162003',
'060750163001',
'060750163002',
'060750163003',
'060750164001',
'060750164002',
'060750165001',
'060750165002',
'060750165003',
'060750165004',
'060750166001',
'060750166002',
'060750166003',
'060750166004',
'060750167001',
'060750167002',
'060750167003',
'060750167004',
'060750168011',
'060750168012',
'060750168013',
'060750168021',
'060750168022',
'060750168023',
'060750169001',
'060750169002',
'060750170001',
'060750170002',
'060750170003',
'060750171011',
'060750171012',
'060750171013',
'060750171021',
'060750171022',
'060750171023',
'060750176011',
'060750176012',
'060750176013',
'060750176014',
'060750176015',
'060750177001',
'060750177002',
'060750178011',
'060750178012',
'060750178021',
'060750178022',
'060750180001',
'060750180002',
'060750201001',
'060750201002',
'060750201003',
'060750201004',
'060750202001',
'060750202002',
'060750202003',
'060750203001',
'060750203002',
'060750203003',
'060750204011',
'060750204012',
'060750204013',
'060750204021',
'060750204022',
'060750205001',
'060750205002',
'060750205003',
'060750206001',
'060750206002',
'060750206003',
'060750206004',
'060750207001',
'060750207002',
'060750207003',
'060750208001',
'060750208002',
'060750208003',
'060750208004',
'060750209001',
'060750209002',
'060750209003',
'060750209004',
'060750210001',
'060750210002',
'060750210003',
'060750210004',
'060750211001',
'060750211002',
'060750211003',
'060750211004',
'060750212001',
'060750212002',
'060750212003',
'060750213001',
'060750213002',
'060750214001',
'060750214002',
'060750214003',
'060750215001',
'060750215002',
'060750215003',
'060750215004',
'060750215005',
'060750216001',
'060750216002',
'060750217001',
'060750217002',
'060750217003',
'060750218001',
'060750218002',
'060750218003',
'060750218004',
'060750226001',
'060750226002',
'060750227021',
'060750227022',
'060750227041',
'060750227042',
'060750228011',
'060750228012',
'060750228013',
'060750228021',
'060750228022',
'060750228031',
'060750228032',
'060750228033',
'060750229011',
'060750229012',
'060750229013',
'060750229021',
'060750229022',
'060750229031',
'060750229032',
'060750229033',
'060750230011',
'060750230012',
'060750230013',
'060750230031',
'060750230032',
'060750231021',
'060750231022',
'060750231031',
'060750231032',
'060750232001',
'060750232002',
'060750232003',
'060750233001',
'060750234001',
'060750234002',
'060750251001',
'060750251002',
'060750251003',
'060750252001',
'060750252002',
'060750252003',
'060750252004',
'060750253001',
'060750253002',
'060750253003',
'060750253004',
'060750254011',
'060750254012',
'060750254013',
'060750254021',
'060750254022',
'060750254023',
'060750254031',
'060750254032',
'060750255001',
'060750255002',
'060750255003',
'060750255004',
'060750255005',
'060750255006',
'060750256001',
'060750256002',
'060750256003',
'060750256004',
'060750257011',
'060750257012',
'060750257013',
'060750257021',
'060750257022',
'060750257023',
'060750258001',
'060750258002',
'060750259001',
'060750259002',
'060750259003',
'060750260011',
'060750260012',
'060750260021',
'060750260022',
'060750260031',
'060750260032',
'060750260041',
'060750260042',
'060750261001',
'060750261002',
'060750261003',
'060750261004',
'060750262001',
'060750262002',
'060750262003',
'060750262004',
'060750262005',
'060750263011',
'060750263012',
'060750263013',
'060750263021',
'060750263022',
'060750263023',
'060750263031',
'060750263032',
'060750264011',
'060750264012',
'060750264021',
'060750264022',
'060750264023',
'060750264031',
'060750264032',
'060750264041',
'060750264042',
'060750301011',
'060750301012',
'060750301013',
'060750301014',
'060750301021',
'060750301022',
'060750301023',
'060750302011',
'060750302012',
'060750302013',
'060750302021',
'060750302022',
'060750302023',
'060750303011',
'060750303012',
'060750303013',
'060750303014',
'060750303021',
'060750303022',
'060750303023',
'060750304001',
'060750304002',
'060750304003',
'060750304004',
'060750304005',
'060750305001',
'060750305002',
'060750305003',
'060750306001',
'060750306002',
'060750306003',
'060750307001',
'060750307002',
'060750307003',
'060750308001',
'060750308002',
'060750308003',
'060750308004',
'060750308005',
'060750309001',
'060750309002',
'060750309003',
'060750309004',
'060750309005',
'060750309006',
'060750309007',
'060750310001',
'060750310002',
'060750310003',
'060750311001',
'060750311002',
'060750311003',
'060750311004',
'060750311005',
'060750312011',
'060750312012',
'060750312013',
'060750312014',
'060750312021',
'060750312022',
'060750313011',
'060750313012',
'060750313013',
'060750313021',
'060750313022',
'060750313023',
'060750314001',
'060750314002',
'060750314003',
'060750314004',
'060750314005',
'060750326011',
'060750326012',
'060750326013',
'060750326021',
'060750326022',
'060750326023',
'060750327001',
'060750327002',
'060750327003',
'060750327004',
'060750327005',
'060750327006',
'060750327007',
'060750328011',
'060750328012',
'060750328013',
'060750328021',
'060750328022',
'060750328023',
'060750329011',
'060750329012',
'060750329013',
'060750329014',
'060750329021',
'060750329022',
'060750329023',
'060750330001',
'060750330002',
'060750330003',
'060750330004',
'060750330005',
'060750330006',
'060750331001',
'060750331002',
'060750331003',
'060750331004',
'060750332011',
'060750332031',
'060750332032',
'060750332041',
'060750332042',
'060750332043',
'060750351001',
'060750351002',
'060750351003',
'060750351004',
'060750351005',
'060750351006',
'060750351007',
'060750352011',
'060750352012',
'060750352013',
'060750352014',
'060750352015',
'060750352021',
'060750352022',
'060750352023',
'060750353001',
'060750353002',
'060750353003',
'060750353004',
'060750353005',
'060750353006',
'060750354001',
'060750354002',
'060750354003',
'060750354004',
'060750354005',
'060750401001',
'060750401002',
'060750401003',
'060750401004',
'060750402001',
'060750402002',
'060750402003',
'060750402004',
'060750426011',
'060750426012',
'060750426021',
'060750426022',
'060750426023',
'060750427001',
'060750427002',
'060750427003',
'060750428001',
'060750428002',
'060750428003',
'060750451001',
'060750451002',
'060750451003',
'060750452001',
'060750452002',
'060750452003',
'060750452004',
'060750452005',
'060750476001',
'060750476002',
'060750476003',
'060750476004',
'060750477011',
'060750477012',
'060750477013',
'060750477021',
'060750477022',
'060750477023',
'060750478011',
'060750478012',
'060750478013',
'060750478021',
'060750478022',
'060750478023',
'060750479011',
'060750479012',
'060750479013',
'060750479014',
'060750479015',
'060750479021',
'060750479022',
'060750479023',
'060750601001',
'060750604001',
'060750605021',
'060750605022',
'060750605023',
'060750607001',
'060750607002',
'060750607003',
'060750610001',
'060750610002',
'060750611001',
'060750611002',
'060750611003',
'060750612001',
'060750612002',
'060750614001',
'060750614002',
'060750614003',
'060750615001',
'060750615002',
'060750615003',
'060750615004',
'060750615005',
'060750615006',
'060759802001',
'060759803001',
'060759805011',
'060759806001',
'060759809001',
'060816004012',
'060816007001']

# %%
def addGeometryIdToDataFrame(df, gdf, xcol, ycol, idColumn="geometry", df_geom='epsg:32610'): 
    gdf.crs = {'init': 'epsg:4326'}
    gdf_data = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df[xcol], df[ycol]))
    gdf_data.crs = {'init': df_geom}
    joined = gpd.sjoin(gdf_data.to_crs('epsg:26910'), gdf.to_crs('epsg:26910'))
    gdf_data = gdf_data.merge(joined['blkgrpid'], left_index=True, right_index=True, how="left")
    gdf_data.rename(columns={'blkgrpid': idColumn}, inplace=True)
    df = pd.DataFrame(gdf_data.drop(columns='geometry'))
    # df.drop(columns=[xcol, ycol], inplace=True)
    
    return df.loc[~df.index.duplicated(keep='first'), :]

# %%
def addGeometryIdToDataFrame2(df, gdf, xcol, ycol, idColumn="geometry", df_geom='epsg:32610'): 
    gdf.crs = {'init': 'epsg:32610'}
    gdf_data = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df[xcol], df[ycol]))
    gdf_data.crs = {'init': df_geom}
    joined = gpd.sjoin(gdf_data.to_crs('epsg:26910'), gdf.to_crs('epsg:26910'))
    gdf_data = gdf_data.merge(joined['blkgrpid'], left_index=True, right_index=True, how="left")
    gdf_data.rename(columns={'blkgrpid': idColumn}, inplace=True)
    df = pd.DataFrame(gdf_data.drop(columns='geometry'))
    # df.drop(columns=[xcol, ycol], inplace=True)
    
    return df.loc[~df.index.duplicated(keep='first'), :]

# %%
def process(plans, events_base, BGs, zones):

    #ADD ORIGIN AND DESTINATION COORDINATES TO PLANS 
    plans = plans[plans['planSelected']==True]
    plans_orig_to_des = plans.sort_values(by=['personId','planElementIndex'], ascending=True)
    print(plans_orig_to_des)

    xs = []
    ys = []
    starts = []
    for x, y, start in zip(plans_orig_to_des['activityLocationX'], plans_orig_to_des['activityLocationY'],plans_orig_to_des['activityEndTime']):
        if x > -999999999999999999:
            xs.append(x)
            ys.append(y)
            starts.append(0)
            current_start = start
            current_x = x
            current_y = y
        else:
            xs.append(current_x)
            ys.append(current_y)           
            starts.append(current_start)
            
    plans_orig_to_des['tripOriginX'] = xs
    plans_orig_to_des['tripOriginY'] = ys
    plans_orig_to_des['legDepartureTime'] = starts
    
    plans_orig_to_des = plans_orig_to_des.sort_values(by=['personId','planElementIndex'], ascending=False)
    
    xs = []
    ys = []
    for x, y in zip(plans_orig_to_des['activityLocationX'], plans_orig_to_des['activityLocationY']):
        if x > -999999999999999999:
            xs.append(x)
            ys.append(y)
            current_x = x
            current_y = y
        else:
            xs.append(current_x)
            ys.append(current_y)
    plans_orig_to_des['tripDestX'] = xs
    plans_orig_to_des['tripDestY'] = ys

    plans_orig_to_des = plans_orig_to_des.sort_values(by=['personId','planElementIndex'], ascending=True)
    
    plans_orig_to_des.dropna(subset=['legMode'], inplace=True)

    
    #ADD BLOCK ID TO PLANS

    plans_orig_to_des = addGeometryIdToDataFrame(plans_orig_to_des, BGs, 'tripOriginX', 'tripOriginY', 'ZIPo')
    plans_orig_to_des = addGeometryIdToDataFrame(plans_orig_to_des, BGs, 'tripDestX', 'tripDestY', 'ZIPd')
    plans_orig_to_des_zone = plans_orig_to_des[(plans_orig_to_des['ZIPo'].isin(zones))|(plans_orig_to_des['ZIPd'].isin(zones))]

    #READ AND ADD BLOCK ID TO EVENTS

    
    PTs = events_base[events_base['type']=='PathTraversal']
    
    PTs['duration'] = PTs['arrivalTime'] - PTs['departureTime']

    PTs['isCAV'] = PTs['vehicleType'].str.contains('L5')
    PTs['isRH'] = PTs['vehicle'].str.contains('rideHail')
    PTs['is_pool'] = PTs['numPassengers'] >1
    PTs['isRHpool'] = PTs['vehicle'].str.contains('rideHail')*PTs['is_pool']
    PTs['isBS'] = PTs['vehicle'].str.contains('bay_wheels')
    PTs['isRH_WC'] = PTs['vehicleType'].str.contains('RH_Car-wheelchair')
    PTs['is_empty'] = PTs['numPassengers'] == 0
    PTs['is_RHempty'] = PTs['isRH']*PTs['is_empty']
    PTs['is_car_emer'] = PTs['vehicle'].str.contains('emergency')
    
    PTs.loc[PTs['mode'] == 'car', 'capacity'] += 1
    PTs.loc[PTs['mode'] == 'car_hov2', 'capacity'] += 1
    PTs.loc[PTs['mode'] == 'car_hov3', 'capacity'] += 1
    PTs.loc[PTs['mode'] == 'walk', 'capacity'] = 1
    PTs.loc[PTs['mode'] == 'bike', 'capacity'] = 1
    
    PTs.loc[PTs['isRH'], 'mode'] += '_RideHail'
    PTs.loc[PTs['isRHpool'], 'mode'] += '_Pool'
    PTs.loc[PTs['isBS'], 'mode'] += '_Sharing'
    PTs.loc[PTs['isRH_WC'], 'mode'] += '_WC'
    PTs.loc[PTs['isCAV'], 'mode'] += '_CAV'
    PTs.loc[PTs['is_RHempty'], 'mode'] += '_empty'
    PTs.loc[PTs['is_car_emer'], 'mode'] += '_emer'
    
    PTs.loc[PTs['mode'] == 'car', 'occupancy'] = 1
    PTs.loc[PTs['mode'] == 'car_emer', 'occupancy'] = 1
    PTs.loc[PTs['mode'] == 'car_hov2', 'occupancy'] += 1
    PTs.loc[PTs['mode'] == 'car_hov3', 'occupancy'] += 1
    PTs.loc[PTs['mode'] == 'car_hov3_emer', 'occupancy'] = 1
    PTs.loc[PTs['mode'] == 'walk', 'occupancy'] = 1
    PTs.loc[PTs['mode'] == 'bike', 'occupancy'] = 1

    # PTs['vehicleMiles'] = PTs['length'] / 1609.34
    # PTs['passengerMiles'] = (PTs['length'] * PTs['occupancy']) / 1609.34
    # PTs['totalEnergyInJoules'] = PTs['primaryFuel'] + PTs['secondaryFuel']
    transit_modes = ['bus', 'subway', 'tram', 'rail','cable_car', 'ferry']
    for tm in transit_modes:
        PTs['is'+tm] = PTs['mode'].str.contains(tm)
    for tm in transit_modes:
        PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
    PTs['is_transit'] = 0
    for tm in transit_modes:
        PTs['is_transit']+=PTs['is'+tm]
    for tm in transit_modes:
        PTs.loc[PTs['is_'+tm+'_empty'], 'mode'] += '_empty'
        PTs.drop(columns=['is'+tm])
        PTs.drop(columns=['is_'+tm+'_empty'])
        
    PTs.drop(columns=['isCAV','is_empty','is_RHempty','isRH_WC','is_car_emer'])
    
    
    
    
    PTs = addGeometryIdToDataFrame2(PTs, BGs, 'startX', 'startY', 'ZIPo')
    PTs = addGeometryIdToDataFrame2(PTs, BGs, 'endX', 'endY', 'ZIPd')
    PTs = PTs[(PTs['ZIPo'].isin(zones))|(PTs['ZIPd'].isin(zones))]
    
    print(plans_orig_to_des)

    return plans_orig_to_des, PTs

# %%
def allocate_paths(scenario):
    if scenario == 'baseline':
        plans =  pd.read_csv('gs://beam-core-outputs/sfbay-baseline-20230526/beam/year-2020-iteration-4/ITERS/it.0/0.plans.csv.gz', usecols = ['personId','planSelected','activityType', 'activityLocationX', 'activityLocationY', 'planElementIndex', 'legMode', 'legDepartureTime', 'activityEndTime', 'legTravelTime'])
        events = pd.read_csv('gs://beam-core-outputs/sfbay-baseline-20230526/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz' , usecols = ['mode','type','startX', 'startY', 'endX', 'endY','length', 'departureTime', 'arrivalTime','vehicleType', 'vehicle', 'numPassengers', 'capacity'])
        BGs = gpd.read_file('/vsicurl/https://github.com/LBNL-UCB-STI/beam-core-analysis/raw/main/Users/Zach/scenario/sfbay-blockgroups-2010/641aa0d4-ce5b-4a81-9c30-8790c4ab8cfb202047-1-wkkklf.j5ouj.shp')
        print('Completed. Selected scenario: Baseline')
    elif scenario == 'income-based':
        plans =     pd.read_csv('gs://beam-core-outputs/sfbay-cordon-MTA-20230703/beam/year-2020-iteration-4/ITERS/it.0/0.plans.csv.gz', usecols = ['personId','planSelected','activityType', 'activityLocationX', 'activityLocationY', 'planElementIndex', 'legMode', 'legDepartureTime', 'activityEndTime', 'legTravelTime'])
        events = pd.read_csv('gs://beam-core-outputs/sfbay-cordon-MTA-20230703/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz' , usecols = ['mode','type','startX', 'startY', 'endX', 'endY','length', 'departureTime', 'arrivalTime','vehicleType', 'vehicle', 'numPassengers', 'capacity'])
        BGs = gpd.read_file('/vsicurl/https://github.com/LBNL-UCB-STI/beam-core-analysis/raw/main/Users/Zach/scenario/sfbay-blockgroups-2010/641aa0d4-ce5b-4a81-9c30-8790c4ab8cfb202047-1-wkkklf.j5ouj.shp')
        print('Completed. Selected scenario: Income-based toll')
    elif scenario == 'flat':
        plans =     pd.read_csv('gs://beam-core-outputs/sfbay-cordon-MTA-flatrate-20230719/beam/year-2020-iteration-4/ITERS/it.0/0.plans.csv.gz', usecols = ['personId','planSelected','activityType', 'activityLocationX', 'activityLocationY', 'planElementIndex', 'legMode', 'legDepartureTime', 'activityEndTime', 'legTravelTime'])
        events = pd.read_csv('gs://beam-core-outputs/sfbay-cordon-MTA-flatrate-20230719/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz' , usecols = ['mode','type','startX', 'startY', 'endX', 'endY','length', 'departureTime', 'arrivalTime','vehicleType', 'vehicle', 'numPassengers', 'capacity'])
        BGs = gpd.read_file('/vsicurl/https://github.com/LBNL-UCB-STI/beam-core-analysis/raw/main/Users/Zach/scenario/sfbay-blockgroups-2010/641aa0d4-ce5b-4a81-9c30-8790c4ab8cfb202047-1-wkkklf.j5ouj.shp')
        print('Completed. Selected scenario: Flat toll')
    else:
        print('Error. Incorrect scenario')
        plans = 0
        events = 0
        BGs = 0
        
    return plans, events, BGs

# %%
##### EDIT THIS, SELECT FROM 0, 1, 2:

# RUN THIS CELL IF ONLY ONE SCENARIO
#scenarios = ['baseline', 'income-based', 'flat']

#selected_scenario = scenarios[2]

#plans_base, events_base, BGs = allocate_paths(selected_scenario)

#plans_orig_to_des, events_base_pt = process(plans_base, events_base, BGs, SF_zones)
#geo = 'SF'

# %%
# LOOP
# %timeit
scenarios = ['baseline', 'income-based', 'flat']
for i in range(0,3):
    selected_scenario = scenarios[i]
    plans_base, events_base, BGs = allocate_paths(selected_scenario)
    plans_orig_to_des, events_base_pt = process(plans_base, events_base, BGs, SF_zones)
    geo = 'SF'
    plans_orig_to_des.legMode.value_counts().sort_index().to_csv(f'trip_count_{selected_scenario}_{geo}.csv')
    events_base_pt = events_base_pt[events_base_pt['length']>0]
    events_base_pt['duration'] = events_base_pt['arrivalTime']-events_base_pt['departureTime']
    grouped = events_base_pt.groupby('mode')
    vmt_mode = grouped['length'].sum()
    vmt_mode_av = grouped['length'].mean()
    vht_mode = grouped['duration'].sum()
    vht_mode_av = grouped['duration'].mean()
    speed_mode = grouped['length'].sum()/grouped['duration'].sum()
    vmt_mode.to_csv(f'vmt_mode_{selected_scenario}_{geo}.csv')
    vmt_mode_av.to_csv(f'vmt_mode_av_{selected_scenario}_{geo}.csv')
    vht_mode.to_csv(f'vht_mode_{selected_scenario}_{geo}.csv')
    vht_mode_av.to_csv(f'vht_mode_av_{selected_scenario}_{geo}.csv')
    speed_mode.to_csv(f'speed_mode_{selected_scenario}_{geo}.csv')
# Out:
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\610976916.py:4: DtypeWarning: Columns (14,15,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   events = pd.read_csv('gs://beam-core-outputs/sfbay-baseline-20230526/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz' , usecols = ['mode','type','startX', 'startY', 'endX', 'endY','length', 'departureTime', 'arrivalTime','vehicleType', 'vehicle', 'numPassengers', 'capacity'])
# Completed. Selected scenario: Baseline
#          personId  planSelected  planElementIndex activityType  \
# 7563273         4          True                 0         Home
# 7563274         4          True                 1          NaN
# 7563275         4          True                 2     othdiscr
# 7563276         4          True                 3          NaN
# 7563277         4          True                 4       social
# ...           ...           ...               ...          ...
# 2283162   6808834          True                 2         work
# 2283163   6808834          True                 3          NaN
# 2283164   6808834          True                 4       eatout
# 2283165   6808834          True                 5          NaN
# 2283166   6808834          True                 6         Home
#
#          activityLocationX  activityLocationY  activityEndTime legMode  \
# 7563273      567919.614977       4.189908e+06          55026.0     NaN
# 7563274                NaN                NaN              NaN     car
# 7563275      566680.335629       4.183202e+06          58204.8     NaN
# 7563276                NaN                NaN              NaN     car
# 7563277      565948.027887       4.185053e+06          59457.6     NaN
# ...                    ...                ...              ...     ...
# 2283162      516981.693500       4.263965e+06          56790.0     NaN
# 2283163                NaN                NaN              NaN     car
# 2283164      526488.631550       4.256155e+06          79074.0     NaN
# 2283165                NaN                NaN              NaN     car
# 2283166      494885.497981       4.242350e+06             -inf     NaN
#
#          legDepartureTime  legTravelTime
# 7563273               NaN            NaN
# 7563274              -inf           -inf
# 7563275               NaN            NaN
# 7563276              -inf           -inf
# 7563277               NaN            NaN
# ...                   ...            ...
# 2283162               NaN            NaN
# 2283163              -inf           -inf
# 2283164               NaN            NaN
# 2283165              -inf           -inf
# 2283166               NaN            NaN
#
# [5721129 rows x 10 columns]
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['duration'] = PTs['arrivalTime'] - PTs['departureTime']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isCAV'] = PTs['vehicleType'].str.contains('L5')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isRH'] = PTs['vehicle'].str.contains('rideHail')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_pool'] = PTs['numPassengers'] >1
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isRHpool'] = PTs['vehicle'].str.contains('rideHail')*PTs['is_pool']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isBS'] = PTs['vehicle'].str.contains('bay_wheels')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isRH_WC'] = PTs['vehicleType'].str.contains('RH_Car-wheelchair')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_empty'] = PTs['numPassengers'] == 0
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_RHempty'] = PTs['isRH']*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_car_emer'] = PTs['vehicle'].str.contains('emergency')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs.loc[PTs['mode'] == 'car', 'occupancy'] = 1
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit'] = 0
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#           personId  planSelected  planElementIndex activityType  \
# 7563274          4          True                 1          NaN
# 7563276          4          True                 3          NaN
# 7563278          4          True                 5          NaN
# 7563291          8          True                 1          NaN
# 7563293          8          True                 3          NaN
# ...            ...           ...               ...          ...
# 11920788   6808782          True                 5          NaN
# 11920790   6808782          True                 7          NaN
# 2283161    6808834          True                 1          NaN
# 2283163    6808834          True                 3          NaN
# 2283165    6808834          True                 5          NaN
#
#           activityLocationX  activityLocationY  activityEndTime   legMode  \
# 7563274                 NaN                NaN              NaN       car
# 7563276                 NaN                NaN              NaN       car
# 7563278                 NaN                NaN              NaN       car
# 7563291                 NaN                NaN              NaN       car
# 7563293                 NaN                NaN              NaN  car_hov2
# ...                     ...                ...              ...       ...
# 11920788                NaN                NaN              NaN       car
# 11920790                NaN                NaN              NaN       car
# 2283161                 NaN                NaN              NaN       car
# 2283163                 NaN                NaN              NaN       car
# 2283165                 NaN                NaN              NaN       car
#
#           legDepartureTime  legTravelTime    tripOriginX   tripOriginY  \
# 7563274            55026.0           -inf  567919.614977  4.189908e+06
# 7563276            58204.8           -inf  566680.335629  4.183202e+06
# 7563278            59457.6           -inf  565948.027887  4.185053e+06
# 7563291            56210.4           -inf  567919.614977  4.189908e+06
# 7563293            73836.0           -inf  564199.236050  4.191804e+06
# ...                    ...            ...            ...           ...
# 11920788           60026.4           -inf  500118.780671  4.251865e+06
# 11920790           75333.6           -inf  521057.276130  4.255188e+06
# 2283161            26589.6           -inf  494885.497981  4.242350e+06
# 2283163            56790.0           -inf  516981.693500  4.263965e+06
# 2283165            79074.0           -inf  526488.631550  4.256155e+06
#
#               tripDestX     tripDestY          ZIPo          ZIPd
# 7563274   566680.335629  4.183202e+06  060014001001  060014054022
# 7563276   565948.027887  4.185053e+06  060014054022  060014037021
# 7563278   567919.614977  4.189908e+06  060014037021  060014001001
# 7563291   564199.236050  4.191804e+06  060014001001  060014229002
# 7563293   567919.614977  4.189908e+06  060014229002  060014001001
# ...                 ...           ...           ...           ...
# 11920788  521057.276130  4.255188e+06  060971543043  060971530063
# 11920790  500118.780671  4.251865e+06  060971530063  060971543043
# 2283161   516981.693500  4.263965e+06  060971543043  060971527021
# 2283163   526488.631550  4.256155e+06  060971527021  060971523004
# 2283165   494885.497981  4.242350e+06  060971523004  060971543043
#
# [2535152 rows x 16 columns]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\610976916.py:9: DtypeWarning: Columns (12,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   events = pd.read_csv('gs://beam-core-outputs/sfbay-cordon-MTA-20230703/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz' , usecols = ['mode','type','startX', 'startY', 'endX', 'endY','length', 'departureTime', 'arrivalTime','vehicleType', 'vehicle', 'numPassengers', 'capacity'])
# Completed. Selected scenario: Income-based toll
#          personId  planSelected  planElementIndex activityType  \
# 7545080         4          True                 0         Home
# 7545081         4          True                 1          NaN
# 7545082         4          True                 2     othdiscr
# 7545083         4          True                 3          NaN
# 7545084         4          True                 4       social
# ...           ...           ...               ...          ...
# 2272185   6808834          True                 0         Home
# 2272186   6808834          True                 1          NaN
# 2272187   6808834          True                 2         work
# 2272188   6808834          True                 3          NaN
# 2272189   6808834          True                 4         Home
#
#          activityLocationX  activityLocationY  activityEndTime legMode  \
# 7545080      567919.614977       4.189908e+06          55353.6     NaN
# 7545081                NaN                NaN              NaN     car
# 7545082      566119.984702       4.183143e+06          57988.8     NaN
# 7545083                NaN                NaN              NaN     car
# 7545084      566237.284468       4.186224e+06          58071.6     NaN
# ...                    ...                ...              ...     ...
# 2272185      494885.497981       4.242350e+06          22914.0     NaN
# 2272186                NaN                NaN              NaN     car
# 2272187      515592.958636       4.261727e+06          58554.0     NaN
# 2272188                NaN                NaN              NaN     car
# 2272189      494885.497981       4.242350e+06             -inf     NaN
#
#          legDepartureTime  legTravelTime
# 7545080               NaN            NaN
# 7545081              -inf           -inf
# 7545082               NaN            NaN
# 7545083              -inf           -inf
# 7545084               NaN            NaN
# ...                   ...            ...
# 2272185               NaN            NaN
# 2272186              -inf           -inf
# 2272187               NaN            NaN
# 2272188              -inf           -inf
# 2272189               NaN            NaN
#
# [5703382 rows x 10 columns]
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['duration'] = PTs['arrivalTime'] - PTs['departureTime']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isCAV'] = PTs['vehicleType'].str.contains('L5')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isRH'] = PTs['vehicle'].str.contains('rideHail')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_pool'] = PTs['numPassengers'] >1
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isRHpool'] = PTs['vehicle'].str.contains('rideHail')*PTs['is_pool']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isBS'] = PTs['vehicle'].str.contains('bay_wheels')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isRH_WC'] = PTs['vehicleType'].str.contains('RH_Car-wheelchair')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_empty'] = PTs['numPassengers'] == 0
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_RHempty'] = PTs['isRH']*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_car_emer'] = PTs['vehicle'].str.contains('emergency')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs.loc[PTs['mode'] == 'car', 'occupancy'] = 1
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit'] = 0
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#           personId  planSelected  planElementIndex activityType  \
# 7545081          4          True                 1          NaN
# 7545083          4          True                 3          NaN
# 7545085          4          True                 5          NaN
# 7545098          8          True                 1          NaN
# 7545100          8          True                 3          NaN
# ...            ...           ...               ...          ...
# 11891250   6808782          True                 3          NaN
# 11891252   6808782          True                 5          NaN
# 11891254   6808782          True                 7          NaN
# 2272186    6808834          True                 1          NaN
# 2272188    6808834          True                 3          NaN
#
#           activityLocationX  activityLocationY  activityEndTime legMode  \
# 7545081                 NaN                NaN              NaN     car
# 7545083                 NaN                NaN              NaN     car
# 7545085                 NaN                NaN              NaN     car
# 7545098                 NaN                NaN              NaN     car
# 7545100                 NaN                NaN              NaN     car
# ...                     ...                ...              ...     ...
# 11891250                NaN                NaN              NaN     car
# 11891252                NaN                NaN              NaN     car
# 11891254                NaN                NaN              NaN     car
# 2272186                 NaN                NaN              NaN     car
# 2272188                 NaN                NaN              NaN     car
#
#           legDepartureTime  legTravelTime    tripOriginX   tripOriginY  \
# 7545081            55353.6           -inf  567919.614977  4.189908e+06
# 7545083            57988.8           -inf  566119.984702  4.183143e+06
# 7545085            58071.6           -inf  566237.284468  4.186224e+06
# 7545098            59313.6           -inf  567919.614977  4.189908e+06
# 7545100            60192.0           -inf  564110.733907  4.192749e+06
# ...                    ...            ...            ...           ...
# 11891250           56343.6           -inf  527337.845771  4.254995e+06
# 11891252           60480.0           -inf  500118.780671  4.251865e+06
# 11891254           73897.2           -inf  527563.171492  4.257499e+06
# 2272186            22914.0           -inf  494885.497981  4.242350e+06
# 2272188            58554.0           -inf  515592.958636  4.261727e+06
#
#               tripDestX     tripDestY          ZIPo          ZIPd
# 7545081   566119.984702  4.183143e+06  060014001001  060014054021
# 7545083   566237.284468  4.186224e+06  060014054021  060014039001
# 7545085   567919.614977  4.189908e+06  060014039001  060014001001
# 7545098   564110.733907  4.192749e+06  060014001001  060014217002
# 7545100   567919.614977  4.189908e+06  060014217002  060014001001
# ...                 ...           ...           ...           ...
# 11891250  500118.780671  4.251865e+06  060971518005  060971543043
# 11891252  527563.171492  4.257499e+06  060971543043  060971524002
# 11891254  500118.780671  4.251865e+06  060971524002  060971543043
# 2272186   515592.958636  4.261727e+06  060971543043  060971527021
# 2272188   494885.497981  4.242350e+06  060971527021  060971543043
#
# [2527217 rows x 16 columns]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\610976916.py:14: DtypeWarning: Columns (22,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   events = pd.read_csv('gs://beam-core-outputs/sfbay-cordon-MTA-flatrate-20230719/beam/year-2020-iteration-4/ITERS/it.0/0.events.csv.gz' , usecols = ['mode','type','startX', 'startY', 'endX', 'endY','length', 'departureTime', 'arrivalTime','vehicleType', 'vehicle', 'numPassengers', 'capacity'])
# Completed. Selected scenario: Flat toll
#          personId  planSelected  planElementIndex activityType  \
# 7539685         4          True                 0         Home
# 7539686         4          True                 1          NaN
# 7539687         4          True                 2     othdiscr
# 7539688         4          True                 3          NaN
# 7539689         4          True                 4         Home
# ...           ...           ...               ...          ...
# 2271818   6808834          True                 2         work
# 2271819   6808834          True                 3          NaN
# 2271820   6808834          True                 4       eatout
# 2271821   6808834          True                 5          NaN
# 2271822   6808834          True                 6         Home
#
#          activityLocationX  activityLocationY  activityEndTime       legMode  \
# 7539685      567919.614977       4.189908e+06          52113.6           NaN
# 7539686                NaN                NaN              NaN  walk_transit
# 7539687      564540.848722       4.184819e+06          67312.8           NaN
# 7539688                NaN                NaN              NaN  walk_transit
# 7539689      567919.614977       4.189908e+06             -inf           NaN
# ...                    ...                ...              ...           ...
# 2271818      520949.652609       4.261449e+06          57409.2           NaN
# 2271819                NaN                NaN              NaN           car
# 2271820      525995.237790       4.257443e+06          75668.4           NaN
# 2271821                NaN                NaN              NaN           car
# 2271822      494885.497981       4.242350e+06             -inf           NaN
#
#          legDepartureTime  legTravelTime
# 7539685               NaN            NaN
# 7539686              -inf           -inf
# 7539687               NaN            NaN
# 7539688              -inf           -inf
# 7539689               NaN            NaN
# ...                   ...            ...
# 2271818               NaN            NaN
# 2271819              -inf           -inf
# 2271820               NaN            NaN
# 2271821              -inf           -inf
# 2271822               NaN            NaN
#
# [5702374 rows x 10 columns]
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:60: SettingWithCopyWarning:
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_pool'] = PTs['numPassengers'] >1
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isRHpool'] = PTs['vehicle'].str.contains('rideHail')*PTs['is_pool']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isBS'] = PTs['vehicle'].str.contains('bay_wheels')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['isRH_WC'] = PTs['vehicleType'].str.contains('RH_Car-wheelchair')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_empty'] = PTs['numPassengers'] == 0
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_RHempty'] = PTs['isRH']*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_car_emer'] = PTs['vehicle'].str.contains('emergency')
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs.loc[PTs['mode'] == 'car', 'occupancy'] = 1
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is'+tm] = PTs['mode'].str.contains(tm)
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_'+tm+'_empty'] = PTs['is'+tm]*PTs['is_empty']
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit'] = 0
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\AppData\Local\Temp\2\ipykernel_9048\4111925240.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PTs['is_transit']+=PTs['is'+tm]
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\cguirado\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#           personId  planSelected  planElementIndex activityType  \
# 7539686          4          True                 1          NaN
# 7539688          4          True                 3          NaN
# 7539701          8          True                 1          NaN
# 7539703          8          True                 3          NaN
# 13210704        18          True                 1          NaN
# ...            ...           ...               ...          ...
# 11885294   6808782          True                 5          NaN
# 11885296   6808782          True                 7          NaN
# 2271817    6808834          True                 1          NaN
# 2271819    6808834          True                 3          NaN
# 2271821    6808834          True                 5          NaN
#
#           activityLocationX  activityLocationY  activityEndTime       legMode  \
# 7539686                 NaN                NaN              NaN  walk_transit
# 7539688                 NaN                NaN              NaN  walk_transit
# 7539701                 NaN                NaN              NaN           car
# 7539703                 NaN                NaN              NaN      car_hov2
# 13210704                NaN                NaN              NaN          bike
# ...                     ...                ...              ...           ...
# 11885294                NaN                NaN              NaN           car
# 11885296                NaN                NaN              NaN           car
# 2271817                 NaN                NaN              NaN           car
# 2271819                 NaN                NaN              NaN           car
# 2271821                 NaN                NaN              NaN           car
#
#           legDepartureTime  legTravelTime    tripOriginX   tripOriginY  \
# 7539686            52113.6           -inf  567919.614977  4.189908e+06
# 7539688            67312.8           -inf  564540.848722  4.184819e+06
# 7539701            56196.0           -inf  567919.614977  4.189908e+06
# 7539703            74394.0           -inf  564139.644284  4.191035e+06
# 13210704           38473.2           -inf  567054.747829  4.190684e+06
# ...                    ...            ...            ...           ...
# 11885294           61063.2           -inf  500118.780671  4.251865e+06
# 11885296           75088.8           -inf  525146.027954  4.259837e+06
# 2271817            26254.8           -inf  494885.497981  4.242350e+06
# 2271819            57409.2           -inf  520949.652609  4.261449e+06
# 2271821            75668.4           -inf  525995.237790  4.257443e+06
#
#               tripDestX     tripDestY          ZIPo          ZIPd
# 7539686   564540.848722  4.184819e+06  060014001001  060014029001
# 7539688   567919.614977  4.189908e+06  060014029001  060014001001
# 7539701   564139.644284  4.191035e+06  060014001001  060014229002
# 7539703   567919.614977  4.189908e+06  060014229002  060014001001
# 13210704  568003.781402  4.190896e+06  060014001001  060014001001
# ...                 ...           ...           ...           ...
# 11885294  525146.027954  4.259837e+06  060971543043  060971524003
# 11885296  500118.780671  4.251865e+06  060971524003  060971543043
# 2271817   520949.652609  4.261449e+06  060971543043  060971527022
# 2271819   525995.237790  4.257443e+06  060971527022  060971523001
# 2271821   494885.497981  4.242350e+06  060971523001  060971543043
#
# [2526726 rows x 16 columns]

# %%
# RUN THIS IF ONLY ONE SCENARIO
# CHOOSE BETWEEN CORDON ZONES AND SF ZONES

#GET PLANS AND EVENTS FILTERED FOR THE CORDON ZONE
#plans_orig_to_des, events_base_pt = process(plans_base, events_base, BGs, cordon_zones)
#geo = 'cordon'

#GET PLANS AND EVENTS FILTERED FOR SF
#plans_orig_to_des, events_base_pt = process(plans_base, events_base, BGs, SF_zones)
#geo = 'SF'

#REPEAT FOR EACH SCENARIO

# %%
#plans_orig_to_des

# %%
#events_base_pt

# %%
#plans_orig_to_des.legMode.value_counts().sort_index().to_csv(f'trip_count_{selected_scenario}_{geo}.csv')

# %%
#events_base_pt = events_base_pt[events_base_pt['length']>0]
#events_base_pt['duration'] = events_base_pt['arrivalTime']-events_base_pt['departureTime']
#grouped = events_base_pt.groupby('mode')
#vmt_mode = grouped['length'].sum()
#vmt_mode_av = grouped['length'].mean()
#vht_mode = grouped['duration'].sum()
#vht_mode_av = grouped['duration'].mean()
#speed_mode = grouped['length'].sum()/grouped['duration'].sum()

# %%
# Export to CSV
#vmt_mode.to_csv(f'vmt_mode_{selected_scenario}_{geo}.csv')
#vmt_mode_av.to_csv(f'vmt_mode_av_{selected_scenario}_{geo}.csv')
#vht_mode.to_csv(f'vht_mode_{selected_scenario}_{geo}.csv')
#vht_mode_av.to_csv(f'vht_mode_av_{selected_scenario}_{geo}.csv')
#speed_mode.to_csv(f'speed_mode_{selected_scenario}_{geo}.csv')

# %%
# measure time
end = time.time()

delta_t = end - start
print("Time elapsed: ", delta_t)
# Out:
# Time elapsed:  4111.504703760147
