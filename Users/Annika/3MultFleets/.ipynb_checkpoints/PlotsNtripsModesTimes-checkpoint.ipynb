# %%
# Multiple fleets, Graphs

#### On Feb 28 2023

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# %matplotlib inline
sns.set(rc={'figure.figsize':(20,14)})
sns.set_theme(style="whitegrid")

# %%
path = 'H:/.shortcut-targets-by-id/1xuAay2JQWDmg2wb0MD2Ft4mCSjufwjq3/BEAM CORE - LBNL NREL Collaboration/Task4 Deep Dive Analyses/3. Fleet Size -- and Multiple Fleets paper/'
path_data = path + 'data/'
path_output = path + 'plots/'

# %%
df_temp = pd.read_csv(path_data + 'SummaryWait.csv')
df_temp = pd.read_csv(path_data + 'sf_2018_stacked_rh_fltsz_price_incRank_1_2_modifiedLeverNumbers.csv')

# %%
#df_temp.info()
#df_temp.describe()
#print(df_temp.columns.tolist())
#print(df_temp.columns.values)

# %%
cd0 = df_temp[['lever_n_fleets' ,'lever_position_price', 'lever_position_fltsz',
              'incRank', 'n_agents' ,'n_trips' ]]
cd0 = df_temp[['lever_n_fleets' ,'lever_position_price', 'lever_position_fltsz',
               'mode_ride_hail_pooled_sum', 'mode_ride_hail_solo_sum', 'mode_ridehail_total_sum', 'mode_walk_sum', 'mode_walk_transit_sum' ]]
cd.head(4)
# Out:
#                                                           mode_ride_hail_pooled_sum  \
# lever_n_fleets lever_position_price lever_position_fltsz
# 1              1.00                 1.0                                       14811
# 2              0.27                 1.0                                       13320
#                0.47                 1.0                                       15467
#                1.00                 1.0                                       14828
#
#                                                           mode_ride_hail_solo_sum  \
# lever_n_fleets lever_position_price lever_position_fltsz
# 1              1.00                 1.0                                     98669
# 2              0.27                 1.0                                     98752
#                0.47                 1.0                                     97005
#                1.00                 1.0                                     93675
#
#                                                           mode_ridehail_total_sum  \
# lever_n_fleets lever_position_price lever_position_fltsz
# 1              1.00                 1.0                                    113480
# 2              0.27                 1.0                                    112072
#                0.47                 1.0                                    112472
#                1.00                 1.0                                    108503
#
#                                                           mode_walk_sum  \
# lever_n_fleets lever_position_price lever_position_fltsz
# 1              1.00                 1.0                          428439
# 2              0.27                 1.0                          452216
#                0.47                 1.0                          437350
#                1.00                 1.0                          428191
#
#                                                           mode_walk_transit_sum
# lever_n_fleets lever_position_price lever_position_fltsz
# 1              1.00                 1.0                                  453763
# 2              0.27                 1.0                                  484590
#                0.47                 1.0                                  470493
#                1.00                 1.0                                  452856

# %%
cd5=cd0.loc[(cd0['lever_n_fleets']==5)]
cd2=cd0.loc[(cd0['lever_n_fleets']==2)]
cd1=cd0.loc[(cd0['lever_n_fleets']==1)]
cd5
# Out:
#      lever_n_fleets  lever_position_price  lever_position_fltsz  \
# 42                5                  1.00                   1.0
# 43                5                  1.00                   1.0
# 44                5                  1.00                   1.0
# 45                5                  1.00                   1.0
# 46                5                  1.00                   1.0
# ..              ...                   ...                   ...
# 478               5                  0.27                  10.0
# 479               5                  0.27                  10.0
# 480               5                  0.27                  10.0
# 481               5                  0.27                  10.0
# 482               5                  0.27                  10.0
#
#      mode_ride_hail_pooled_sum  mode_ride_hail_solo_sum  \
# 42                         703                     3226
# 43                         603                     3291
# 44                         579                     3288
# 45                         772                     4148
# 46                         687                     3907
# ..                         ...                      ...
# 478                       4349                    27671
# 479                       3689                    23601
# 480                       3776                    25433
# 481                       3975                    25390
# 482                       3481                    21566
#
#      mode_ridehail_total_sum  mode_walk_sum  mode_walk_transit_sum
# 42                      3929          32399                  27725
# 43                      3894          26735                  24840
# 44                      3867          26015                  26184
# 45                      4920          25483                  24880
# 46                      4594          23231                  23613
# ..                       ...            ...                    ...
# 478                    32020          17655                  21548
# 479                    27290          14357                  17979
# 480                    29209          16203                  20132
# 481                    29365          15903                  19089
# 482                    25047          15123                  16425
#
# [315 rows x 8 columns]

# %%
cd5noI = cd5.groupby(['lever_n_fleets' ,'lever_position_price', 'lever_position_fltsz']).sum().reset_index(drop=True)
cd2 = cd2.groupby(['lever_n_fleets' ,'lever_position_price', 'lever_position_fltsz']).sum()
cd1 = cd1.groupby(['lever_n_fleets' ,'lever_position_price', 'lever_position_fltsz']).sum()
cd  = cd0.groupby(['lever_n_fleets' ,'lever_position_price', 'lever_position_fltsz']).sum()
#pd.melt(cd)
#cd.describe()
cd5.head(50)
#cd = cd.where(['lever_n_fleets']==5)
#cd = cd.groupby(['lever_n_fleets' ,'lever_position_price', 'lever_position_fltsz']).sum()
# Out:
#     lever_n_fleets  lever_position_price  lever_position_fltsz  \
# 42               5                   1.0                  1.00
# 43               5                   1.0                  1.00
# 44               5                   1.0                  1.00
# 45               5                   1.0                  1.00
# 46               5                   1.0                  1.00
# 47               5                   1.0                  1.00
# 48               5                   1.0                  1.00
# 49               5                   1.0                  1.00
# 50               5                   1.0                  1.00
# 51               5                   1.0                  1.00
# 52               5                   1.0                  1.00
# 53               5                   1.0                  1.00
# 54               5                   1.0                  1.00
# 55               5                   1.0                  1.00
# 56               5                   1.0                  1.00
# 57               5                   1.0                  1.00
# 58               5                   1.0                  1.00
# 59               5                   1.0                  1.00
# 60               5                   1.0                  1.00
# 61               5                   1.0                  1.00
# 62               5                   1.0                  1.00
# 63               5                   1.0                  1.64
# 64               5                   1.0                  1.64
# 65               5                   1.0                  1.64
# 66               5                   1.0                  1.64
# 67               5                   1.0                  1.64
# 68               5                   1.0                  1.64
# 69               5                   1.0                  1.64
# 70               5                   1.0                  1.64
# 71               5                   1.0                  1.64
# 72               5                   1.0                  1.64
# 73               5                   1.0                  1.64
# 74               5                   1.0                  1.64
# 75               5                   1.0                  1.64
# 76               5                   1.0                  1.64
# 77               5                   1.0                  1.64
# 78               5                   1.0                  1.64
# 79               5                   1.0                  1.64
# 80               5                   1.0                  1.64
# 81               5                   1.0                  1.64
# 82               5                   1.0                  1.64
# 83               5                   1.0                  1.64
# 84               5                   1.0                  2.00
# 85               5                   1.0                  2.00
# 86               5                   1.0                  2.00
# 87               5                   1.0                  2.00
# 88               5                   1.0                  2.00
# 89               5                   1.0                  2.00
# 90               5                   1.0                  2.00
# 91               5                   1.0                  2.00
#
#     mode_ride_hail_pooled_sum  mode_ride_hail_solo_sum  \
# 42                        703                     3226
# 43                        603                     3291
# 44                        579                     3288
# 45                        772                     4148
# 46                        687                     3907
# 47                        594                     3983
# 48                        625                     3832
# 49                        686                     4515
# 50                        710                     4289
# 51                        719                     4591
# 52                        623                     4471
# 53                        697                     4257
# 54                        691                     4491
# 55                        640                     4314
# 56                        684                     4664
# 57                        682                     4793
# 58                        642                     4917
# 59                        645                     4184
# 60                        640                     4972
# 61                        644                     4627
# 62                        534                     4026
# 63                       1161                     4799
# 64                       1012                     4641
# 65                        972                     4809
# 66                       1253                     6098
# 67                       1150                     6227
# 68                       1098                     5882
# 69                       1034                     5833
# 70                       1229                     6674
# 71                       1072                     6386
# 72                       1160                     6340
# 73                       1126                     6320
# 74                       1182                     6418
# 75                       1161                     6688
# 76                       1041                     6390
# 77                       1220                     6830
# 78                       1191                     7457
# 79                       1229                     7068
# 80                       1011                     6397
# 81                       1140                     7012
# 82                       1008                     6913
# 83                        909                     6105
# 84                       1403                     5482
# 85                       1182                     5292
# 86                       1127                     5517
# 87                       1541                     7016
# 88                       1379                     6998
# 89                       1378                     6714
# 90                       1305                     6704
# 91                       1468                     7682
#
#     mode_ridehail_total_sum  mode_walk_sum  mode_walk_transit_sum
# 42                     3929          32399                  27725
# 43                     3894          26735                  24840
# 44                     3867          26015                  26184
# 45                     4920          25483                  24880
# 46                     4594          23231                  23613
# 47                     4577          22509                  24221
# 48                     4457          21614                  22495
# 49                     5201          19565                  22650
# 50                     4999          19884                  21863
# 51                     5310          19685                  22026
# 52                     5094          18599                  21465
# 53                     4954          17534                  19147
# 54                     5182          17218                  19830
# 55                     4954          17694                  19338
# 56                     5348          17671                  19444
# 57                     5475          18516                  20569
# 58                     5559          18024                  20428
# 59                     4829          15724                  18145
# 60                     5612          18118                  19972
# 61                     5271          17630                  19246
# 62                     4560          16963                  16100
# 63                     5960          31738                  28034
# 64                     5653          26081                  24784
# 65                     5781          25303                  26105
# 66                     7351          23961                  24842
# 67                     7377          22556                  23596
# 68                     6980          21735                  23566
# 69                     6867          20492                  22651
# 70                     7903          18858                  22569
# 71                     7458          18308                  21812
# 72                     7500          18417                  22257
# 73                     7446          18101                  21324
# 74                     7600          16637                  18843
# 75                     7849          16383                  19656
# 76                     7431          16507                  19564
# 77                     8050          16808                  18985
# 78                     8648          17458                  20648
# 79                     8297          17032                  20339
# 80                     7408          14997                  17716
# 81                     8152          16946                  19964
# 82                     7921          16575                  19005
# 83                     7014          15657                  16017
# 84                     6885          31790                  27934
# 85                     6474          26120                  24744
# 86                     6644          25714                  26012
# 87                     8557          24791                  24681
# 88                     8377          22601                  23386
# 89                     8092          21783                  23640
# 90                     8009          20617                  22369
# 91                     9150          18719                  22545

# %%
#cdPr1=cd5.loc[(cd5['lever_position_price']==1)]  #THIS DOESNT WORK IF INDEX

# %%
sns.lineplot(data=cd5,
             x='lever_position_price', size ="lever_position_fltsz", sizes=(1,20),
             y='mode_ride_hail_pooled_sum', 
               ci=None, linewidth = 6,
            palette = 'Blues'
             )
sns.lineplot(data=cd5,
             x='lever_position_price', size ="lever_position_fltsz", sizes=(1,20),
             y='mode_ride_hail_solo_sum', 
               ci=None, linewidth = 6,
            palette = 'Reds',
             #legend=off
             )
sns.lineplot(data=cd5,
             x='lever_position_price', size ="lever_position_fltsz", sizes=(1,20),
             y='mode_walk_transit_sum', 
               ci=None, linewidth = 6,
            palette = 'Reds'
             )
# There's another more complex way of doing it that Nazanin has
#SNS facet grid -- on top of each other
# Out:
# <AxesSubplot:xlabel='lever_position_price', ylabel='mode_ride_hail_pooled_sum'>

# %%
sns.lineplot(data=cd,
             x='lever_position_price', hue='lever_n_fleets',size ="lever_position_fltsz", sizes=(5,20),
             #style=""
             y='mode_ride_hail_pooled_sum', 
               ci=None, linewidth = 6,
            palette = 'Blues'
             )
sns.lineplot(data=cd,
             x='lever_position_price', hue='lever_n_fleets',size ="lever_position_fltsz", sizes=(5,20),
             
    linestyle='--',
             y='mode_ride_hail_solo_sum', 
               ci=None, linewidth = 6,
            palette = 'Reds'
             )
sns.lineplot(data=cd,
             x='lever_position_price', hue='lever_n_fleets',size ="lever_position_fltsz", sizes=(5,20),
             
    #linestyle='--',
             y='mode_walk_transit_sum', 
               ci=None, linewidth = 6,
            palette = 'Greens'
             )
# Out:
# <AxesSubplot:xlabel='lever_position_price', ylabel='mode_ride_hail_pooled_sum'>

# %%
pd.melt(cd)
# Out:
#                       variable   value
# 0    mode_ride_hail_pooled_sum   14811
# 1    mode_ride_hail_pooled_sum   13320
# 2    mode_ride_hail_pooled_sum   15467
# 3    mode_ride_hail_pooled_sum   14828
# 4    mode_ride_hail_pooled_sum   24258
# ..                         ...     ...
# 110      mode_walk_transit_sum  454181
# 111      mode_walk_transit_sum  452277
# 112      mode_walk_transit_sum  451295
# 113      mode_walk_transit_sum  444526
# 114      mode_walk_transit_sum  435735
#
# [115 rows x 2 columns]

# %%
sns.lineplot(data=pd.melt(cd),y='value',
             hue='variable',
               ci=None, linewidth = 6,
 
            palette = 'Blues')
# Out:
# <AxesSubplot:ylabel='value'>

# %%
#temp_varName='Wait time PM - Pooled RH (median)'
#temp_varName='Trip Exec Share Ride Hail Pooled'

# %%
df_tmLong = df_temp[['lever_n_fleets' ,'lever_position_price', 'lever_position_fltsz', 
                     
# 'Wait time PM - Solo RH (median)',  'Wait time PM - Pooled RH (median)', 
 #'Pooling Success Rate', 'Car_Exec_Total', 'Transit_Exec_Total',
 'Trip Exec Share Bike' ,'Trip Exec Share Walk' ,'Trip Exec Share Ride Hail',
 'Trip Exec Share Ride Hail Pooled' ]]

# %%
cd_plt = cd[(cd['income_deciles']=='1stD')|(cd['income_deciles']=='10thD')]

# %%
sns.lineplot(data=pd.melt(df_tmLong, ['lever_position_fltsz','lever_n_fleets','lever_position_price']),
             x='lever_position_fltsz', y='value', hue='variable', 
               ci=None, linewidth = 6
             )
# Out:
# <AxesSubplot:xlabel='lever_position_fltsz', ylabel='value'>

# %%
t_plot = sns.lineplot(data = df_temp.loc[ (df_temp['lever_position_price']>=-1)
                                           &(df_temp['lever_position_fltsz']>=-1)
                                           &(df_temp['lever_n_fleets']>=0)], 
           # x = 'lever_position_fltsz', 
            #y = temp_varName, 
            #y=["Wait time PM - Pooled RH (median)", "Trip Exec Share Ride Hail Pooled"],
            #hue = 'lever_n_fleets', # hue, style, size
            #style = 'lever_position_price',
            #size ="lever_position_fltsz", sizes=(5,20),
                      #size_order=["T1", "T2"],
             #palette = palette, 
            ci=None, linewidth = 6,
            palette = 'Blues'
            )
#t_plot.set_xlabel('Income Rank (Percentiles of Income)', fontsize = 40)
#t_plot.set_ylabel('Potential INEXUS relative to Baseline', fontsize = 40)
#t_plot.yaxis.set_tick_params(labelsize = 26)
#t_plot.xaxis.set_tick_params(labelsize = 26)
#t_plot.legend(fontsize='medium', fancybox=False, bbox_to_anchor=(1, 0.8), ncol=1, frameon=True, loc = 'best', prop={'size': 26})
# SAVE
#filename  = path_output + temp_varName + "__" + datetime.now().strftime('%m_%d_%Y_%H_%M_%S') + '.svg'
#print(filename)
#plt.savefig(filename, format='svg')
#plt.savefig('lorenz_viridisATB.png', dpi=1000)
