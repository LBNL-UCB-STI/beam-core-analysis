# %%
import pandas as pd
from pandas import read_csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.chdir('/Volumes/GoogleDrive/My Drive/BEAM-CORE/BEAM Validation')

plt.style.use('ggplot')

# %%
# load data for validation
modeled_vmt = read_csv('sample output/AUS2018/0.linkstats.csv.gz', low_memory=False)
observed_vmt = read_csv('data for validation/Austin/VMT/austin_roadway_inventory.csv', low_memory=False)
model_network = read_csv('sample output/AUS2018/beam_network_by_county.csv', low_memory=False)
modeled_vmt.head(5)
# Out:
#      link    from      to  hour  length  freespeed  capacity stat  volume  \
# 0  285550  102109  120927   0.0  13.623   14.75232    2100.0  AVG     0.0
# 1  285550  102109  120927   1.0  13.623   14.75232    2100.0  AVG     0.0
# 2  285550  102109  120927   2.0  13.623   14.75232    2100.0  AVG     0.0
# 3  285550  102109  120927   3.0  13.623   14.75232    2100.0  AVG     0.0
# 4  285550  102109  120927   4.0  13.623   14.75232    2100.0  AVG     0.0
#
#    traveltime
# 0    0.923448
# 1    0.923448
# 2    0.923448
# 3    0.923448
# 4    0.923448

# %%
observed_vmt.head(5)
total_lane_mile_observed = observed_vmt['LN_MILES'].sum()
print(total_lane_mile_observed)
# Out:
# 31169.408

# %%
meter_to_mile = 0.000621371
model_network = model_network.drop_duplicates(subset=['linkId'])
model_network.head(5)
model_network.loc[:, 'lane_mile'] = meter_to_mile * model_network.loc[:, 'linkLength'] * model_network.loc[:, 'numberOfLanes']
total_lane_mile_modeled = model_network['lane_mile'].sum()
print(total_lane_mile_modeled)
# Out:
# 46312.51890791604

# %%
# filter modeled network
# model_vmt_24_hour = modeled_vmt.loc[modeled_vmt['hour'] <= 23]
model_network['fromNodeId'] = model_network['fromNodeId'].astype(int)
model_network['toNodeId'] = model_network['toNodeId'].astype(int)
model_vmt_24_hour = pd.merge(modeled_vmt, model_network, 
                                 left_on = ['link', 'from', 'to'],
                                 right_on = ['linkId', 'fromNodeId', 'toNodeId'], how = 'left')
model_vmt_24_hour.head(5)
# Out:
#      link    from      to  hour  length_x  freespeed  capacity stat  volume  \
# 0  285550  102109  120927   0.0    13.623   14.75232    2100.0  AVG     0.0
# 1  285550  102109  120927   1.0    13.623   14.75232    2100.0  AVG     0.0
# 2  285550  102109  120927   2.0    13.623   14.75232    2100.0  AVG     0.0
# 3  285550  102109  120927   3.0    13.623   14.75232    2100.0  AVG     0.0
# 4  285550  102109  120927   4.0    13.623   14.75232    2100.0  AVG     0.0
#
#    traveltime  ...  linkCapacity  numberOfLanes      linkModes  \
# 0    0.923448  ...        2100.0            1.0  car;walk;bike
# 1    0.923448  ...        2100.0            1.0  car;walk;bike
# 2    0.923448  ...        2100.0            1.0  car;walk;bike
# 3    0.923448  ...        2100.0            1.0  car;walk;bike
# 4    0.923448  ...        2100.0            1.0  car;walk;bike
#
#    attributeOrigId  attributeOrigType  fromNodeId  toNodeId        name  \
# 0      544896591.0           tertiary    102109.0  120927.0  Williamson
# 1      544896591.0           tertiary    102109.0  120927.0  Williamson
# 2      544896591.0           tertiary    102109.0  120927.0  Williamson
# 3      544896591.0           tertiary    102109.0  120927.0  Williamson
# 4      544896591.0           tertiary    102109.0  120927.0  Williamson
#
#    txdot_abbr fips_code
# 0        14.0     491.0
# 1        14.0     491.0
# 2        14.0     491.0
# 3        14.0     491.0
# 4        14.0     491.0
#
# [5 rows x 25 columns]

# %%
model_vmt_24_hour = model_vmt_24_hour.rename(columns = {'length_x': 'length_raw', 
                                                        'length_y': 'length_adj'})
print(model_vmt_24_hour.columns)
# Out:
# Index(['link', 'from', 'to', 'hour', 'length_raw', 'freespeed', 'capacity',
#        'stat', 'volume', 'traveltime', 'Unnamed: 0', 'linkId', 'linkLength',
#        'length_adj', 'linkFreeSpeed', 'linkCapacity', 'numberOfLanes',
#        'linkModes', 'attributeOrigId', 'attributeOrigType', 'fromNodeId',
#        'toNodeId', 'name', 'txdot_abbr', 'fips_code'],
#       dtype='object')

# %%
model_vmt_24_hour.loc[:, 'VMT'] = meter_to_mile * model_vmt_24_hour.loc[:, 'linkLength'] * model_vmt_24_hour.loc[:, 'volume']
model_vmt_by_county = model_vmt_24_hour.groupby(['name'])[['VMT']].sum()
model_vmt_by_county = model_vmt_by_county.reset_index()
model_vmt_by_county
# Out:
#          name           VMT
# 0     Bastrop  3.890692e+05
# 1      Burnet  4.469847e+05
# 2    Caldwell  1.931504e+05
# 3        Hays  6.799823e+05
# 4      Travis  5.052181e+06
# 5  Williamson  1.746340e+06

# %%
model_vmt_by_hour = model_vmt_24_hour.groupby(['hour'])[['VMT']].sum()
model_vmt_by_hour
# Out:
#                 VMT
# hour
# 0.0        0.000000
# 1.0        0.000000
# 2.0        0.000000
# 3.0        0.000000
# 4.0      466.887605
# 5.0   118430.036150
# 6.0   330490.902060
# 7.0   539830.433841
# 8.0   631785.407431
# 9.0   508510.983954
# 10.0  410887.574057
# 11.0  414875.246271
# 12.0  420658.666614
# 13.0  432485.765482
# 14.0  414612.593236
# 15.0  430411.142301
# 16.0  493723.729827
# 17.0  608721.734007
# 18.0  672935.309805
# 19.0  571698.858699
# 20.0  412237.704568
# 21.0  368586.116695
# 22.0  279790.335056
# 23.0  201139.671076
# 24.0  122277.679997
# 25.0   41369.924703
# 26.0   22788.199072
# 27.0   15383.486676
# 28.0   10859.554343
# 29.0    7446.510487
# 30.0    6040.721002
# 31.0    4872.187296
# 32.0    3357.456435
# 33.0    2948.027851
# 34.0    2162.404403
# 35.0    1650.737182
# 36.0    1264.269398
# 37.0     710.936669
# 38.0     835.008724
# 39.0     404.497949
# 40.0     238.028104
# 41.0     152.543685
# 42.0     119.060165
# 43.0     105.805627
# 44.0     104.482086
# 45.0      38.468463
# 46.0      67.148581
# 47.0      35.929057
# 48.0      27.222881
# 49.0      80.796090
# 50.0      53.852487
# 51.0      30.860358
# 52.0       2.393233
# 53.0       0.000000
# 54.0       0.000000
# 55.0       0.000000
# 56.0       0.068429
# 57.0       0.000000
# 58.0       0.000000
# 59.0       0.000000

# %%
print(model_vmt_24_hour.linkModes.unique())
# Out:
# ['car;walk;bike' 'walk;bike' 'car;bike' 'bike' nan]

# %%
observed_vmt_by_county = observed_vmt.groupby('County.Name')[['DVMT']].sum()
observed_vmt_by_county = observed_vmt_by_county.reset_index()
observed_vmt_by_county
# Out:
#   County.Name          DVMT
# 0     Bastrop  5.293038e+06
# 1      Burnet  1.941568e+06
# 2    Caldwell  2.284149e+06
# 3        Hays  1.219118e+07
# 4      Travis  6.188790e+07
# 5  Williamson  2.425238e+07

# %%
VMT_comparison = pd.merge(model_vmt_by_county, observed_vmt_by_county, 
                          left_on = 'name', right_on = 'County.Name', how = 'left')
VMT_comparison = VMT_comparison.loc[:, ['name', 'VMT', 'DVMT']]
VMT_comparison.columns = ['county', 'modeled_VMT', 'observed_VMT']
VMT_comparison
# Out:
#        county   modeled_VMT  observed_VMT
# 0     Bastrop  3.890692e+05  5.293038e+06
# 1      Burnet  4.469847e+05  1.941568e+06
# 2    Caldwell  1.931504e+05  2.284149e+06
# 3        Hays  6.799823e+05  1.219118e+07
# 4      Travis  5.052181e+06  6.188790e+07
# 5  Williamson  1.746340e+06  2.425238e+07

# %%
VMT_comparison.plot.bar(x = 'county')
plt.xlabel('')
plt.ylabel('daily VMT')
plt.title('VMT comparison')
# Out:
# Text(0.5, 1.0, 'VMT comparison')
