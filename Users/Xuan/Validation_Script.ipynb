# %%
import pandas as pd

# %%
data = pd.read_csv('data/2017-2018 Austin Household Travel Survey Public Use data.xlsx - Rec_1.csv')

# %%
data
# Out:
#       1. Record Type  2. Sample Number  3. Phone  4. Month  5. Day  6. Year  \
# 0                  1                27       NaN         2       7     2018
# 1                  1                47       NaN         8       1     2017
# 2                  1               128       NaN         8       3     2017
# 3                  1               150       NaN         8      21     2018
# 4                  1               151       NaN         8       4     2017
# ...              ...               ...       ...       ...     ...      ...
# 2878               1        3100200702       NaN         5      23     2018
# 2879               1        3100200703       NaN         5      23     2018
# 2880               1        3100200716       NaN         9      19     2018
# 2881               1        3100200719       NaN         9      18     2018
# 2882               1        3100200720       NaN         9      19     2018
#
# ...
