# %%
import pandas as pd

# %%
skimsTransitCrowding = pd.read_csv('1.String _ skimsTransitCrowding.csv.gz')

# %%
overloadedMode = skimsTransitCrowding[skimsTransitCrowding['capacity'] <= skimsTransitCrowding['numberOfPassengers']]

# %%
overloadedMode['firstTwo'] = overloadedMode['vehicleId'].str[:2]
# Out:
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_3401/4091636193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overloadedMode['firstTwo'] = overloadedMode['vehicleId'].str[:2]

# %%
overloadedMode[overloadedMode['firstTwo'] == 'SF']
## The 77 here is actually TRAM-DEFAULT
# Out:
#          vehicleId  fromStopIdx  numberOfPassengers  capacity  observations  \
# 3746    SF:7631636            0                  22        22             1
# 6241    SF:7628514            0                  22        22             1
# 7401    SF:7631639            1                  22        22             1
# 11906   SF:7631638            2                  22        22             1
# 12297   SF:7631633            0                  22        22             1
# 13535   SF:7631635            0                  22        22             1
# 14220   SF:7628518            0                  22        22             1
# 18326   SF:7631707            3                  22        22             1
# 18720   SF:7631636            3                  22        22             1
# 20773   SF:7628517            1                  22        22             1
# 21712   SF:7631706            1                  22        22             1
# 25530   SF:7628517            0                  22        22             1
# 26299   SF:7628565            0                  22        22             1
# 31089   SF:7631716            0                  22        22             1
# 34582   SF:7628639            0                  22        22             1
# 39396   SF:7628646            0                  22        22             1
# 40311   SF:7628514            3                  22        22             1
# 40422   SF:7628638            0                  22        22             1
# 42014   SF:7631706            0                  22        22             1
# 43228   SF:7628516            1                  22        22             1
# 43460   SF:7628508            0                  22        22             1
# 44534   SF:7631636            1                  22        22             1
# 44569   SF:7628649            0                  22        22             1
# 46482   SF:7628517            3                  22        22             1
# 47416   SF:7628523            1                  22        22             1
# 48580   SF:7628514            2                  22        22             1
# 49389   SF:7631638            1                  22        22             1
# 49829   SF:7631633            1                  22        22             1
# 51248   SF:7679460           28                  79        79             1
# 53245   SF:7628519            0                  22        22             1
# 53804   SF:7631716            1                  22        22             1
# 54050   SF:7631707            0                  22        22             1
# 56435   SF:7679456           29                  79        79             1
# 57184   SF:7628647            0                  22        22             1
# 62947   SF:7628515            0                  22        22             1
# 66080   SF:7631663            0                  22        22             1
# 67470   SF:7631666            0                  22        22             1
# 71264   SF:7631666            1                  22        22             1
# 71597   SF:7628648            1                  22        22             1
# 79632   SF:7679460           29                  79        79             1
# 81408   SF:7628520            0                  22        22             1
# 84096   SF:7628510            0                  22        22             1
# 84306   SF:7631707            1                  22        22             1
# 85108   SF:7631636            2                  22        22             1
# 86392   SF:7628648            0                  22        22             1
# 90087   SF:7628514            4                  22        22             1
# 102155  SF:7631638            0                  22        22             1
#
#         iterations firstTwo
# 3746             1       SF
# 6241             1       SF
# 7401             1       SF
# 11906            1       SF
# 12297            1       SF
# 13535            1       SF
# 14220            1       SF
# 18326            1       SF
# 18720            1       SF
# 20773            1       SF
# 21712            1       SF
# 25530            1       SF
# 26299            1       SF
# 31089            1       SF
# 34582            1       SF
# 39396            1       SF
# 40311            1       SF
# 40422            1       SF
# 42014            1       SF
# 43228            1       SF
# 43460            1       SF
# 44534            1       SF
# 44569            1       SF
# 46482            1       SF
# 47416            1       SF
# 48580            1       SF
# 49389            1       SF
# 49829            1       SF
# 51248            1       SF
# 53245            1       SF
# 53804            1       SF
# 54050            1       SF
# 56435            1       SF
# 57184            1       SF
# 62947            1       SF
# 66080            1       SF
# 67470            1       SF
# 71264            1       SF
# 71597            1       SF
# 79632            1       SF
# 81408            1       SF
# 84096            1       SF
# 84306            1       SF
# 85108            1       SF
# 86392            1       SF
# 90087            1       SF
# 102155           1       SF

# %%
overloadedMode.groupby('firstTwo').count()

# it's causing more denied trips -- 37% vs 24% before, VTA caused the denied trips for both BA and Tram, how many 
# boardings we should have VTA?
# TRAM-DEFAULT is for VTA light rail??
# Out:
#           vehicleId  fromStopIdx  numberOfPassengers  capacity  observations  \
# firstTwo
# BA               70           70                  70        70            70
# SF               47           47                  47        47            47
# VT              224          224                 224       224           224
#
#           iterations
# firstTwo
# BA                70
# SF                47
# VT               224

# %%
events = pd.read_csv('1.events.csv.gz')
# Out:
# /usr/local/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (0,1,5,6,20,22,23,24,28,29,31,33,35,36,37,38,48,49,50,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
events['type'].unique()
# Out:
# array(['departure', 'PersonEntersVehicle', 'PathTraversal', 'ModeChoice',
#        'actend', 'LeavingParkingEvent', 'PersonLeavesVehicle', 'arrival',
#        'actstart', 'ReserveRideHail', 'ParkingEvent', 'PersonCost',
#        'Replanning', 'ChargingPlugInEvent', 'RefuelSessionEvent',
#        'ChargingPlugOutEvent'], dtype=object)

# %%
pathTraversal = events[events['type'] == 'PathTraversal'].dropna(how='all', axis=1)

# %%
pathTraversal
# Out:
#                                   vehicleType  \
# 85480                                  BUS-MA
# 85481                                  BUS-MA
# 149932                                 BUS-MA
# 149933                                 BUS-MA
# 149934                                 BUS-MA
# ...                                       ...
# 85450236                          BUS-DEFAULT
# 85450238              sharedVehicle-sharedCar
# 85450242              sharedVehicle-sharedCar
# 85450243              sharedVehicle-sharedCar
# 85450255  conv-L1-10000-to-25000-LowTech-2019
#
#                                                       links  numPassengers  \
# 85480     20393,134727,134715,17955,17951,132987,17949,7...            0.0
# 85481     20393,134727,134715,17955,17951,132987,17949,7...            0.0
# 149932           20389,16787,15697,15698,35152,35151,133091            0.0
# 149933           20389,16787,15697,15698,35152,35151,133091            0.0
# 149934               133091,133087,21883,21448,133066,21450            0.0
# ...                                                     ...            ...
# 85450236                                      140262,140178            0.0
# 85450238                                        47168,47196            0.0
# 85450242  62754,62753,41994,81666,20621,46298,36909,3033...            0.0
# 85450243  29136,29137,46176,46179,29261,76242,76241,4458...            0.0
# 85450255                                        76122,76121            0.0
#
#              length   primaryFuel mode riders  toStopIndex  fromStopIndex  \
# 85480       653.352  8.088759e+06  bus    NaN          NaN            NaN
# 85481       653.352  8.088759e+06  bus    NaN          NaN            NaN
# 149932     1912.970  2.368333e+07  bus    NaN          NaN            NaN
# 149933     1912.970  2.368333e+07  bus    NaN          NaN            NaN
# 149934      390.593  4.835698e+06  bus    NaN          NaN            NaN
# ...             ...           ...  ...    ...          ...            ...
# 85450236     19.199  3.849016e+05  bus    NaN          NaN            NaN
# 85450238   4470.070  6.140057e+06  car    NaN          NaN            NaN
# 85450242  12061.922  1.763686e+07  car    NaN          NaN            NaN
# 85450243  18407.699  2.675651e+07  car    NaN          NaN            NaN
# 85450255   4906.137  7.081355e+06  car    NaN          NaN            NaN
#
#           seatingCapacity  ...  arrivalTime  departureTime  \
# 85480                12.0  ...         42.0            0.0
# 85481                12.0  ...         42.0            0.0
# 149932               12.0  ...        300.0           42.0
# 149933               12.0  ...        300.0           42.0
# 149934               12.0  ...        660.0          300.0
# ...                   ...  ...          ...            ...
# 85450236             13.0  ...     108012.0       107990.0
# 85450238              3.0  ...     108013.0       107656.0
# 85450242              3.0  ...     108013.0       107547.0
# 85450243              3.0  ...     108013.0       107220.0
# 85450255              3.0  ...     108018.0       107835.0
#
#                                              linkTravelTime  secondaryFuel  \
# 85480     10.1,10.1,10.1,10.1,10.1,10.1,10.1,10.1,10.1,1...            0.0
# 85481     10.1,10.1,10.1,10.1,10.1,10.1,10.1,10.1,10.1,1...            0.0
# 149932                                  29,29,29,29,29,29,0            0.0
# 149933                                  29,29,29,29,29,29,0            0.0
# 149934                          16.2,16.2,16.2,16.2,16.2,-0            0.0
# ...                                                     ...            ...
# 85450236                                              119,0            0.0
# 85450238                                    254.319,357.117            0.0
# 85450242  273.029,111.43,65.918,65.114,40.091,0.653,10.5...            0.0
# 85450243  5.675,4.938,2.024,117.735,3.456,23.062,11.87,5...            0.0
# 85450255                                      2.818,182.912            0.0
#
#           secondaryFuelType  primaryFuelType                         driver  \
# 85480                  None         Gasoline  TransitDriverAgent-MA:5323312
# 85481                  None         Gasoline  TransitDriverAgent-MA:5348932
# 149932                 None         Gasoline  TransitDriverAgent-MA:5348932
# 149933                 None         Gasoline  TransitDriverAgent-MA:5323312
# 149934                 None         Gasoline  TransitDriverAgent-MA:5323312
# ...                     ...              ...                            ...
# 85450236               None           Diesel  TransitDriverAgent-SF:7600910
# 85450238               None         Gasoline                        6698197
# 85450242               None         Gasoline                        6280982
# 85450243               None         Gasoline                        4759034
# 85450255               None         Gasoline                        2512774
#
#              vehicle      time           type
# 85480     MA:5323312      42.0  PathTraversal
# 85481     MA:5348932      42.0  PathTraversal
# 149932    MA:5348932     300.0  PathTraversal
# 149933    MA:5323312     300.0  PathTraversal
# 149934    MA:5323312     660.0  PathTraversal
# ...              ...       ...            ...
# 85450236  SF:7600910  108012.0  PathTraversal
# 85450238     3412339  108013.0  PathTraversal
# 85450242     1010738  108013.0  PathTraversal
# 85450243     2891389  108013.0  PathTraversal
# 85450255      430751  108018.0  PathTraversal
#
# [20306865 rows x 28 columns]

# %%
pathTraversalInOverloaded = pathTraversal[pathTraversal['vehicle'].isin(overloadedMode['vehicleId'])]

# %%
events['type'].unique()
# Out:
# array(['departure', 'PersonEntersVehicle', 'PathTraversal', 'ModeChoice',
#        'actend', 'LeavingParkingEvent', 'PersonLeavesVehicle', 'arrival',
#        'actstart', 'ReserveRideHail', 'ParkingEvent', 'PersonCost',
#        'Replanning', 'ChargingPlugInEvent', 'RefuelSessionEvent',
#        'ChargingPlugOutEvent'], dtype=object)

# %%
PersonEntersVehicle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_3401/3660722208.py in <module>
# ----> 1 PersonEntersVehicle
#
# NameError: name 'PersonEntersVehicle' is not defined

# %%
pathTraversalInOverloaded['firstTwoOfVehicle'] = pathTraversalInOverloaded['vehicle'].str[:2]

# %%
pathTraversalInOverloadedSF = pathTraversalInOverloaded[pathTraversalInOverloaded['firstTwoOfVehicle'] == 'SF']

# %%
pathTraversalInOverloadedSF['mode'].unique()

# %%
transitPathTraversal = pathTraversal[(pathTraversal['mode'] == 'cable_car') 
             | (pathTraversal['mode'] == 'rail')
             | (pathTraversal['mode'] == 'tram')
             | (pathTraversal['mode'] == 'subway')
             | (pathTraversal['mode'] == 'bus')]

# %%
transitPathTraversal.dropna(how='all', axis=1)

# %%
transitPathTraversal = transitPathTraversal[transitPathTraversal['time'] <= 86400]

# %%
transitPathTraversal['hour'] = transitPathTraversal['time'] / 3600

# %%
transitPathTraversal['hour'] = transitPathTraversal['hour'].astype(int)

# %%
hourlytransitPathTraversal = transitPathTraversal.groupby(['hour', 'mode']).sum()

# %%
hourlytransitPathTraversal.reset_index(inplace=True)

# %%
bus = hourlytransitPathTraversal[hourlytransitPathTraversal['mode'] == 'bus']
bus.reset_index(inplace=True)
bus['rate'] = bus['numPassengers']/ bus['numPassengers'].sum()
bus['rate'].plot(title='bus')

# %%
cable_car = hourlytransitPathTraversal[hourlytransitPathTraversal['mode'] == 'cable_car']
cable_car.reset_index(inplace=True)
cable_car['rate'] = cable_car['numPassengers']/ cable_car['numPassengers'].sum()
cable_car['rate'].plot(title='cable_car')

# %%
rail = hourlytransitPathTraversal[hourlytransitPathTraversal['mode'] == 'rail']
rail.reset_index(inplace=True)
rail['rate'] = rail['numPassengers']/ rail['numPassengers'].sum()
rail['rate'].plot(title='rail')

# %%
subway = hourlytransitPathTraversal[hourlytransitPathTraversal['mode'] == 'subway']
subway.reset_index(inplace=True)
subway['rate'] = subway['numPassengers']/ subway['numPassengers'].sum()
subway['rate'].plot(title='subway')

# %%
tram = hourlytransitPathTraversal[hourlytransitPathTraversal['mode'] == 'tram']
tram.reset_index(inplace=True)
tram['rate'] = tram['numPassengers']/ tram['numPassengers'].sum()
tram['rate'].plot(title='tram')

# %%
transitPathTraversal.groupby('mode').sum().to_csv('out/transitModesShare.csv')

# %%
df = transitPathTraversal.groupby('mode').sum()[['numPassengers']]

# %%
plot = df.plot.pie(y='numPassengers', figsize=(15, 25), autopct='%1.1f%%')
