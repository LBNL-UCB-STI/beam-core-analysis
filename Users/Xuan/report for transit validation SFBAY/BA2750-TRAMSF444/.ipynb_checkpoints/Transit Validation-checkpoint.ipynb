# %%
import pandas as pd

# %%
skimsTransitCrowding = pd.read_csv('1.String _ skimsTransitCrowding.csv.gz')

# %%
overloadedMode = skimsTransitCrowding[skimsTransitCrowding['capacity'] <= skimsTransitCrowding['numberOfPassengers']]

# %%
overloadedMode['firstTwo'] = overloadedMode['vehicleId'].str[:2]
# Out:
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_3479/4091636193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overloadedMode['firstTwo'] = overloadedMode['vehicleId'].str[:2]

# %%
overloadedMode.groupby('firstTwo').count()
# Out:
#           vehicleId  fromStopIdx  numberOfPassengers  capacity  observations  \
# firstTwo
# SF                9            9                   9         9             9
# VT              750          750                 750       750           750
#
#           iterations
# firstTwo
# SF                 9
# VT               750

# %%
events = pd.read_csv('1.events.csv.gz')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3172: DtypeWarning: Columns (0,1,2,4,6,11,12,13,14,19,23,24,27,30,32,44,46,47,48,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pathTraversal = events[events['type'] == 'PathTraversal'].dropna(how='all', axis=1)

# %%
pathTraversal
# Out:
#          mode     length      time           type     vehicle  \
# 85480     bus    653.352      42.0  PathTraversal  MA:5323312
# 85481     bus    653.352      42.0  PathTraversal  MA:5348932
# 149932    bus   1912.970     300.0  PathTraversal  MA:5348932
# 149933    bus   1912.970     300.0  PathTraversal  MA:5323312
# 149934    bus    390.593     660.0  PathTraversal  MA:5348932
# ...       ...        ...       ...            ...         ...
# 86584839  car   6370.557  107997.0  PathTraversal       31214
# 86584840  car   6444.915  107995.0  PathTraversal     2659160
# 86584850  car  11579.427  108000.0  PathTraversal     2791801
# 86584924  car    416.375  108002.0  PathTraversal     1221357
# 86584928  car  15328.045  108002.0  PathTraversal     3976658
#
#                                  driver  secondaryFuelLevel  primaryFuelLevel  \
# 85480     TransitDriverAgent-MA:5323312                 0.0      2.999191e+10
# 85481     TransitDriverAgent-MA:5348932                 0.0      2.999191e+10
# 149932    TransitDriverAgent-MA:5348932                 0.0      2.996823e+10
# 149933    TransitDriverAgent-MA:5323312                 0.0      2.996823e+10
# 149934    TransitDriverAgent-MA:5348932                 0.0      2.996339e+10
# ...                                 ...                 ...               ...
# 86584839                        5932550                 0.0      3.116328e+09
# 86584840                        6536629                 0.0      3.369273e+09
# 86584850                        6028123                 0.0      3.131095e+09
# 86584924                         267611                 0.0      3.403945e+09
# 86584928                         684892                 0.0     -3.256808e+07
#
#                                                 vehicleType riders  ...  \
# 85480                                                BUS-MA    NaN  ...
# 85481                                                BUS-MA    NaN  ...
# 149932                                               BUS-MA    NaN  ...
# 149933                                               BUS-MA    NaN  ...
# 149934                                               BUS-MA    NaN  ...
# ...                                                     ...    ...  ...
# 86584839                conv-L1-10000-to-25000-LowTech-2019    NaN  ...
# 86584840  conv-L1-0-to-50000-LowTech-2035-Car-ICEV_Gasoline    NaN  ...
# 86584850                            sharedVehicle-sharedCar    NaN  ...
# 86584924                            sharedVehicle-sharedCar    NaN  ...
# 86584928                  ev-L1-10000-to-25000-LowTech-2019    NaN  ...
#
#           capacity  arrivalTime  departureTime  \
# 85480         48.0         42.0            0.0
# 85481         48.0         42.0            0.0
# 149932        48.0        300.0           42.0
# 149933        48.0        300.0           42.0
# 149934        48.0        660.0          300.0
# ...            ...          ...            ...
# 86584839       3.0     107997.0       107759.0
# 86584840       3.0     107995.0       107754.0
# 86584850       3.0     108000.0       107529.0
# 86584924       3.0     108002.0       107681.0
# 86584928       3.0     108002.0       107269.0
#
#                                              linkTravelTime  secondaryFuel  \
# 85480     10.1,10.1,10.1,10.1,10.1,10.1,10.1,10.1,10.1,1...            0.0
# 85481     10.1,10.1,10.1,10.1,10.1,10.1,10.1,10.1,10.1,1...            0.0
# 149932                    29.0,29.0,29.0,29.0,29.0,29.0,0.0            0.0
# 149933                    29.0,29.0,29.0,29.0,29.0,29.0,0.0            0.0
# 149934      16.2,16.2,16.2,16.2,16.2,-3.552713678800501E-15            0.0
# ...                                                     ...            ...
# 86584839                                          3.0,238.0            0.0
# 86584840                                    364.0,238.0,3.0            0.0
# 86584850                                        184.0,471.0            0.0
# 86584924                                         19.0,321.0            0.0
# 86584928  4.0,22.0,22.0,5.0,2.0,4.0,20.0,3.0,11.0,7.0,19...            0.0
#
#           secondaryFuelType  primaryFuelType  \
# 85480                  None         Gasoline
# 85481                  None         Gasoline
# 149932                 None         Gasoline
# 149933                 None         Gasoline
# 149934                 None         Gasoline
# ...                     ...              ...
# 86584839               None         Gasoline
# 86584840               None         Gasoline
# 86584850               None         Gasoline
# 86584924               None         Gasoline
# 86584928               None      Electricity
#
#                                                       links  numPassengers  \
# 85480     20393,134727,134715,17955,17951,132987,17949,7...            0.0
# 85481     20393,134727,134715,17955,17951,132987,17949,7...            0.0
# 149932           20389,16787,15697,15698,35152,35151,133091            0.0
# 149933           20389,16787,15697,15698,35152,35151,133091            0.0
# 149934               133091,133087,21883,21448,133066,21450            0.0
# ...                                                     ...            ...
# 86584839                                        51246,51251            0.0
# 86584840                                  46134,51250,51247            0.0
# 86584850                                        41211,23654            0.0
# 86584924                                        15024,15025            0.0
# 86584928  179459,178893,178889,28125,2813,2814,178772,17...            0.0
#
#            primaryFuel
# 85480     8.088759e+06
# 85481     8.088759e+06
# 149932    2.368333e+07
# 149933    2.368333e+07
# 149934    4.835698e+06
# ...                ...
# 86584839  9.195050e+06
# 86584840  9.302376e+06
# 86584850  1.609358e+07
# 86584924  1.522259e+06
# 86584928  6.079417e+06
#
# [20501038 rows x 28 columns]

# %%
pathTraversalInOverloaded = pathTraversal[pathTraversal['vehicle'].isin(overloadedMode['vehicleId'])]

# %%
pathTraversalInOverloaded['firstTwoOfVehicle'] = pathTraversalInOverloaded['vehicle'].str[:2]
# Out:
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_1092/523607190.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pathTraversalInOverloaded['firstTwoOfVehicle'] = pathTraversalInOverloaded['vehicle'].str[:2]

# %%
pathTraversalInOverloadedSF = pathTraversalInOverloaded[pathTraversalInOverloaded['firstTwoOfVehicle'] == 'SF']

# %%
pathTraversalInOverloadedSF['mode'].unique()
# Out:
# array(['tram'], dtype=object)
