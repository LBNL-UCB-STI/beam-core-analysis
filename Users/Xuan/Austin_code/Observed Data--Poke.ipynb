# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_columns", None)

# %%
observed = pd.read_csv('data/Observed-data/bcycleaus4.csv')

# %%
observed['dist'].median()
# Out:
# 0.595068216753823

# %%
type(observed.dist.to_numpy())
# Out:
# numpy.ndarray

# %%
observed.dist.to_numpy()
# Out:
# 0.297860900807576

# %%
import numpy as np
   
# 1D array
arr = [20, 2, 7, 1, 34]
print("arr : ", arr)
print("50th percentile of arr : ",
       np.percentile(arr, 50))
print("25th percentile of arr : ",
       np.percentile(arr, 25))
print("75th percentile of arr : ",
       np.percentile(arr, 75))
# Out:
# arr :  [20, 2, 7, 1, 34]
# 50th percentile of arr :  7.0
# 25th percentile of arr :  2.0
# 75th percentile of arr :  20.0

# %%
my_list1 = observed.dist.to_numpy().tolist()

# %%
def checkNan(number):
    if (number != float('NaN')):
        return True
    return False

# %%
my_list1[8]
# Out:
# nan

# %%
my_list = list(filter(checkNan, my_list))

# %%
cleanedList = [x for x in my_list if (x == x)]

# %%
cleanedList
# Out:
# [0.0,
#  0.297860900807576,
#  0.0,
#  1.00897607139871,
#  0.0,
#  0.916090947729074,
#  0.513728218189537,
#  0.513728218189537,
#  0.740936869623931,
#  0.46440589112846,
#  0.589044929138274,
#  0.322337759850668,
#  0.684141802453947,
#  0.383549695071926,
#  0.303796188336031,
#  0.303796188336031,
#  0.322337759850668,
#  0.720458785419555,
#  0.32316816051838,
#  0.475947427507263,
#  0.553799484113659,
#  0.0,
#  0.740936869623931,
#  0.857391318600161,
#  0.265157439880233,
#  1.01367836076724,
#  1.01367836076724,
#  0.920186515219562,
#  0.890423665734975,
#  0.466155890646527,
#  0.8234434792304,
#  1.28710198895651,
#  1.28710198895651,
#  0.175262764502724,
#  0.190019950746713,
#  1.35677391435735,
#  1.11474876496429,
#  0.0,
#  0.0,
#  0.0,
#  0.779102533139531,
#  0.303796188336031,
#  0.276487694595365,
#  0.779102533139531,
#  1.22172596455627,
#  0.782371405586897,
#  1.60226843713035,
#  0.890138810096423,
#  0.636313508816496,
#  0.830119769583415,
# ...

# %%
np.percentile(cleanedList, 25)
# Out:
# 0.322068544015927

# %%
observed
# Out:
#                         membership_type  bike_type    st_date   st_time  \
# 0        24-Hour Kiosk (Austin B-cycle)        NaN  1/08/2014  23:12:00
# 1        24-Hour Kiosk (Austin B-cycle)        NaN  3/06/2014  11:12:00
# 2        24-Hour Kiosk (Austin B-cycle)        NaN  3/07/2014  11:12:00
# 3        24-Hour Kiosk (Austin B-cycle)        NaN  3/07/2014  13:12:00
# 4        24-Hour Kiosk (Austin B-cycle)        NaN  3/07/2014  16:12:00
# ...                                 ...        ...        ...       ...
# 1629188                         Local31        NaN  7/23/2021  13:07:22
# 1629189              Student Membership        NaN  7/23/2021  17:10:55
# 1629190         U.T. Student Membership        NaN  7/23/2021  17:58:15
# 1629191              Student Membership        NaN  7/24/2021  19:38:58
# 1629192                        Explorer        NaN  7/24/2021  22:12:42
#
#          end_time   end_date               st_dt              end_dt  st_stn  \
# ...

# %%
halfSample = observed[observed['dist'] >= 0.595068216753823]

# %%
halfSample
# Out:
#           index                     membership_type  bike_type    st_date  \
# 0             3      24-Hour Kiosk (Austin B-cycle)        NaN  3/07/2014
# 1             5  Annual Membership (Austin B-cycle)        NaN  3/07/2014
# 2             9      24-Hour Kiosk (Austin B-cycle)        NaN  3/09/2014
# 3            13      24-Hour Kiosk (Austin B-cycle)        NaN  3/10/2014
# 4            18      24-Hour Kiosk (Austin B-cycle)        NaN  3/11/2014
# ...         ...                                 ...        ...        ...
# 808167  1629181                             Local31        NaN  7/20/2021
# 808168  1629184                  Student Membership        NaN  7/21/2021
# 808169  1629185                  Student Membership        NaN  7/21/2021
# 808170  1629186                            Local365        NaN  7/22/2021
# 808171  1629192                            Explorer        NaN  7/24/2021
#
#          st_time  end_time   end_date               st_dt              end_dt  \
# ...

# %%
halfSample['st_time'][3][0:2]
# Out:
# '13'

# %%
halfSample.reset_index(inplace=True)

# %%
halfSample
# Out:
#           index                     membership_type  bike_type    st_date  \
# 0             3      24-Hour Kiosk (Austin B-cycle)        NaN  3/07/2014
# 1             5  Annual Membership (Austin B-cycle)        NaN  3/07/2014
# 2             9      24-Hour Kiosk (Austin B-cycle)        NaN  3/09/2014
# 3            13      24-Hour Kiosk (Austin B-cycle)        NaN  3/10/2014
# 4            18      24-Hour Kiosk (Austin B-cycle)        NaN  3/11/2014
# ...         ...                                 ...        ...        ...
# 808167  1629181                             Local31        NaN  7/20/2021
# 808168  1629184                  Student Membership        NaN  7/21/2021
# 808169  1629185                  Student Membership        NaN  7/21/2021
# 808170  1629186                            Local365        NaN  7/22/2021
# 808171  1629192                            Explorer        NaN  7/24/2021
#
#          st_time  end_time   end_date               st_dt              end_dt  \
# ...

# %%
halfSample['hour'] = halfSample['st_time'].apply(lambda x : x[0:2])
# Out:
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_11536/2101143295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   halfSample['hour'] = halfSample['st_time'].apply(lambda x : x[0:2])

# %%
halfSample
# Out:
#           index                     membership_type  bike_type    st_date  \
# 0             3      24-Hour Kiosk (Austin B-cycle)        NaN  3/07/2014
# 1             5  Annual Membership (Austin B-cycle)        NaN  3/07/2014
# 2             9      24-Hour Kiosk (Austin B-cycle)        NaN  3/09/2014
# 3            13      24-Hour Kiosk (Austin B-cycle)        NaN  3/10/2014
# 4            18      24-Hour Kiosk (Austin B-cycle)        NaN  3/11/2014
# ...         ...                                 ...        ...        ...
# 808167  1629181                             Local31        NaN  7/20/2021
# 808168  1629184                  Student Membership        NaN  7/21/2021
# 808169  1629185                  Student Membership        NaN  7/21/2021
# 808170  1629186                            Local365        NaN  7/22/2021
# 808171  1629192                            Explorer        NaN  7/24/2021
#
#          st_time  end_time   end_date               st_dt              end_dt  \
# ...

# %%
(halfSample.groupby('hour')['st_time'].count()/len(halfSample)).plot()
# Out:
# <AxesSubplot:xlabel='hour'>

# %%
halfSample

# %%
halfSample.groupby('hour').sum()

# %%
sample75 = observed[observed['dist'] >= 0.322068544015927]

# %%
sample75
# Out:
#                             membership_type  bike_type    st_date   st_time  \
# 3            24-Hour Kiosk (Austin B-cycle)        NaN  3/07/2014  13:12:00
# 5        Annual Membership (Austin B-cycle)        NaN  3/07/2014  16:12:00
# 6        Annual Membership (Austin B-cycle)        NaN  3/07/2014  16:12:00
# 7            24-Hour Kiosk (Austin B-cycle)        NaN  3/07/2014  17:12:00
# 9            24-Hour Kiosk (Austin B-cycle)        NaN  3/09/2014  09:12:00
# ...                                     ...        ...        ...       ...
# 1629186                            Local365        NaN  7/22/2021  18:37:10
# 1629187                  Student Membership        NaN  7/22/2021  19:50:07
# 1629190             U.T. Student Membership        NaN  7/23/2021  17:58:15
# 1629191                  Student Membership        NaN  7/24/2021  19:38:58
# 1629192                            Explorer        NaN  7/24/2021  22:12:42
#
# ...

# %%
sample75['hour'] = sample75['st_time'].apply(lambda x : x[0:2])
# Out:
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_11536/2993471360.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample75['hour'] = sample75['st_time'].apply(lambda x : x[0:2])

# %%
(sample75.groupby('hour')['st_time'].count()/len(sample75)).plot()
# Out:
# <AxesSubplot:xlabel='hour'>
