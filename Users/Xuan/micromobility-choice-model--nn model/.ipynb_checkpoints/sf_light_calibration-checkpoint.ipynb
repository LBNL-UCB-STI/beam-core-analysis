# %% [markdown]
# # Calibration on SF-light scenario
# ----------------------------------

# %%
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-paper')
import numpy as np
import pandas as pd

import os
root_dir = "/Users/jiangxuan/Desktop/link_final/beam/test/input/sfbay"
os.chdir(root_dir)
os.getcwd()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/geopandas/_compat.py:110: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string
# '/Users/jiangxuan/Desktop/link_final/beam/test/input/sfbay'

# %% [markdown]
# ## Trim ActivitySim data

# %%
# read ActivitySim Data
dat_dir = os.path.join(root_dir, "sfbay/gemini/activitysim-plans-base-2010")
plns = pd.read_csv(os.path.join(dat_dir, "plans.csv.gz")).sort_values(by='person_id')
plns.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-75e012643695> in <module>
#       1 # read ActivitySim Data
#       2 dat_dir = os.path.join(root_dir, "sfbay/gemini/activitysim-plans-base-2010")
# ----> 3 plns = pd.read_csv(os.path.join(dat_dir, "plans.csv.gz")).sort_values(by='person_id')
#       4 plns.head(5)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1366             compression=kwds.get("compression", None),
#    1367             memory_map=kwds.get("memory_map", False),
# -> 1368             storage_options=kwds.get("storage_options", None),
#    1369         )
#    1370
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     587                     filename=handle,
#     588                     mode=ioargs.mode,
# --> 589                     **compression_args,
#     590                 )
#     591             else:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     166             mode += 'b'
#     167         if fileobj is None:
# --> 168             fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     169         if filename is None:
#     170             filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/jiangxuan/Desktop/link_final/beam/test/input/sfbay/sfbay/gemini/activitysim-plans-base-2010/plans.csv.gz'

# %%
taz = gpd.read_file(os.path.join(root_dir, 'sf-light/shape/sf-light-tazs.shp'))
# extract pid whose O & D are all in the region
acts = plns.loc[plns.ActivityElement=='activity', ['person_id', 'x', 'y']]
acts['O_coords'] = gpd.points_from_xy(acts.x, acts.y, crs='epsg:26910')
acts.head(5)

# %%
plns[plns.person_id == 1.0]
# Out:
#     Unnamed: 0  trip_id  person_id  number_of_participants       trip_mode  \
# 19          10      NaN        1.0                     NaN             NaN
# 18          10    535.0        1.0                     1.0  DRIVEALONEFREE
# 17           9      NaN        1.0                     NaN             NaN
# 16           9    534.0        1.0                     1.0  DRIVEALONEFREE
# 15           8      NaN        1.0                     NaN             NaN
# 14           8    533.0        1.0                     1.0      TNC_SINGLE
# 13           7      NaN        1.0                     NaN             NaN
# 10           6    529.0        1.0                     1.0            TAXI
# 11           6      NaN        1.0                     NaN             NaN
# 9            5      NaN        1.0                     NaN             NaN
# 8            5    597.0        1.0                     1.0   DRIVEALONEPAY
# 7            4      NaN        1.0                     NaN             NaN
# 6            4    593.0        1.0                     1.0  DRIVEALONEFREE
# 5            3      NaN        1.0                     NaN             NaN
# 12           7    530.0        1.0                     1.0  DRIVEALONEFREE
#
#     PlanElementIndex ActivityElement ActivityType           x          y  \
# 19                15        activity         Home -122.226436  37.855050
# 18                14             leg          NaN         NaN        NaN
# 17                13        activity       eatout -122.255917  37.802758
# 16                12             leg          NaN         NaN        NaN
# 15                11        activity     shopping -122.059891  37.391916
# 14                10             leg          NaN         NaN        NaN
# 13                 9        activity     othdiscr -122.034969  37.380056
# 10                 6             leg          NaN         NaN        NaN
# 11                 7        activity       eatout -122.223518  37.862738
# 9                  5        activity         Home -122.226436  37.855050
# 8                  4             leg          NaN         NaN        NaN
# 7                  3        activity     shopping -122.168858  37.684617
# 6                  2             leg          NaN         NaN        NaN
# 5                  1        activity         Home -122.226436  37.855050
# 12                 8             leg          NaN         NaN        NaN
#
#     departure_time
# 19             NaN
# 18             NaN
# 17          21.646
# 16             NaN
# 15          21.471
# 14             NaN
# 13          21.229
# 10             NaN
# 11          19.223
# 9           18.140
# 8              NaN
# 7           17.113
# 6              NaN
# 5           12.546
# 12             NaN
