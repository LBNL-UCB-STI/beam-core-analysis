# %%
import pandas as pd

# %%
pd.read_csv('plans.csv.gz')
# Out:
#           Unnamed: 0  Unnamed: 0.1       trip_id  person_id  \
# 0                  0             0           NaN        0.0
# 1                  1             1  7.300000e+01        0.0
# 2                  2             1           NaN        0.0
# 3                  3             2  7.700000e+01        0.0
# 4                  4             2           NaN        0.0
# ...              ...           ...           ...        ...
# 41952749    53229564      29622296           NaN  6741460.0
# 41952750    53229565      29622297  2.211199e+09  6741460.0
# 41952751    53229566      29622297           NaN  6741460.0
# 41952752    53229567      29622298  2.211199e+09  6741460.0
# 41952753    53229568      29622298           NaN  6741460.0
#
#           number_of_participants    trip_mode  PlanElementIndex  \
# 0                            NaN          NaN                 1
# 1                            1.0  SHARED2FREE                 2
# ...
