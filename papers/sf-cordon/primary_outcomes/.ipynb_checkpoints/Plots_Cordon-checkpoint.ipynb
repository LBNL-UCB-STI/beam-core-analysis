# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
SMALL_SIZE = 18
MEDIUM_SIZE = 18
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
# Preparing for import

# %%
# Select geography
#geo = ['SF', 'cordon']
geo = ['cordon'] # SFcordon
sce = ['baseline', 'flat', 'income-based'] # scenarios
metrics = ['vmt_mode', 'vmt_mode_av', 'vht_mode', 'vht_mode_av', 'speed_mode', 'trip_count', 'primary_e_mode', 'secondary_e_mode']

# %%
list_tables = []
list_df = []
for i in metrics:
    for j in sce:
        for k in geo:
            var = f'{i}_{j}_{k}.csv'
            df = pd.read_csv(var)
            df['geo'] = k
            df['scenario'] = j
            list_tables.append(var)
            list_df.append(df)

# %%
list_tables
# Out:
# ['vmt_mode_baseline_cordon.csv',
#  'vmt_mode_flat_cordon.csv',
#  'vmt_mode_income-based_cordon.csv',
#  'vmt_mode_av_baseline_cordon.csv',
#  'vmt_mode_av_flat_cordon.csv',
#  'vmt_mode_av_income-based_cordon.csv',
#  'vht_mode_baseline_cordon.csv',
#  'vht_mode_flat_cordon.csv',
#  'vht_mode_income-based_cordon.csv',
#  'vht_mode_av_baseline_cordon.csv',
#  'vht_mode_av_flat_cordon.csv',
#  'vht_mode_av_income-based_cordon.csv',
#  'speed_mode_baseline_cordon.csv',
#  'speed_mode_flat_cordon.csv',
#  'speed_mode_income-based_cordon.csv',
#  'trip_count_baseline_cordon.csv',
#  'trip_count_flat_cordon.csv',
#  'trip_count_income-based_cordon.csv',
#  'primary_e_mode_baseline_cordon.csv',
#  'primary_e_mode_flat_cordon.csv',
#  'primary_e_mode_income-based_cordon.csv',
#  'secondary_e_mode_baseline_cordon.csv',
#  'secondary_e_mode_flat_cordon.csv',
#  'secondary_e_mode_income-based_cordon.csv']

# %%
# Calculate mode shares

# drop bike_transit and teleportation:
list_df[15].drop(list_df[15][list_df[15]['legMode'] == 'bike_transit'].index, inplace = True)
list_df[16].drop(list_df[16][list_df[16]['legMode'] == 'bike_transit'].index, inplace = True)
list_df[17].drop(list_df[17][list_df[17]['legMode'] == 'bike_transit'].index, inplace = True)

list_df[15].drop(list_df[15][list_df[15]['legMode'] == 'hov2_teleportation'].index, inplace = True)
list_df[16].drop(list_df[16][list_df[16]['legMode'] == 'hov2_teleportation'].index, inplace = True)
list_df[17].drop(list_df[17][list_df[17]['legMode'] == 'hov2_teleportation'].index, inplace = True)

list_df[15].drop(list_df[15][list_df[15]['legMode'] == 'hov3_teleportation'].index, inplace = True)
list_df[16].drop(list_df[16][list_df[16]['legMode'] == 'hov3_teleportation'].index, inplace = True)
list_df[17].drop(list_df[17][list_df[17]['legMode'] == 'hov3_teleportation'].index, inplace = True)

list_df[15] = list_df[15].reset_index(drop=True)
list_df[16] = list_df[16].reset_index(drop=True)
list_df[17] = list_df[17].reset_index(drop=True)  

grouped_sum_15 = list_df[15]['count'].sum()
grouped_sum_16 = list_df[16]['count'].sum()
grouped_sum_17 = list_df[17]['count'].sum()

list_df[15]['Share'] = list_df[15]['count'] / grouped_sum_15
list_df[16]['Share'] = list_df[16]['count'] / grouped_sum_16
list_df[17]['Share'] = list_df[17]['count'] / grouped_sum_17

# Calculate difference with respect to baseline
list_df[15]['Diff wrt baseline'] = (list_df[15]['count'] - list_df[15]['count'])
list_df[16]['Diff wrt baseline'] = (list_df[16]['count'] - list_df[15]['count'])/list_df[15]['count']
list_df[17]['Diff wrt baseline'] = (list_df[17]['count'] - list_df[15]['count'])/list_df[15]['count']

# %%
# Check shares add up to 100%
list_df[17]['Share'].sum()
# Out:
# 1.0

# %%
trip_count = pd.concat([list_df[15], list_df[16], list_df[17]])
trip_count
# Out:
#             legMode  count     geo      scenario     Share  Diff wrt baseline
# 0              bike   6056  cordon      baseline  0.034921           0.000000
# 1               car  53151  cordon      baseline  0.306489           0.000000
# 2          car_hov2  12191  cordon      baseline  0.070298           0.000000
# 3          car_hov3   8621  cordon      baseline  0.049712           0.000000
# 4     drive_transit    814  cordon      baseline  0.004694           0.000000
# 5         ride_hail   2536  cordon      baseline  0.014624           0.000000
# 6  ride_hail_pooled    803  cordon      baseline  0.004630           0.000000
# 7              walk  39976  cordon      baseline  0.230517           0.000000
# 8      walk_transit  49271  cordon      baseline  0.284115           0.000000
# 0              bike   6364  cordon          flat  0.040610           0.050859
# 1               car  38521  cordon          flat  0.245809          -0.275254
# 2          car_hov2   8284  cordon          flat  0.052862          -0.320482
# 3          car_hov3   6833  cordon          flat  0.043603          -0.207401
# 4     drive_transit    796  cordon          flat  0.005079          -0.022113
# 5         ride_hail   2159  cordon          flat  0.013777          -0.148659
# 6  ride_hail_pooled    695  cordon          flat  0.004435          -0.134496
# 7              walk  39842  cordon          flat  0.254239          -0.003352
# 8      walk_transit  53217  cordon          flat  0.339587           0.080088
# 0              bike   6499  cordon  income-based  0.039639           0.073151
# 1               car  43900  cordon  income-based  0.267758          -0.174051
# 2          car_hov2   8748  cordon  income-based  0.053356          -0.282421
# 3          car_hov3   7187  cordon  income-based  0.043835          -0.166338
# 4     drive_transit    794  cordon  income-based  0.004843          -0.024570
# 5         ride_hail   2402  cordon  income-based  0.014650          -0.052839
# 6  ride_hail_pooled    729  cordon  income-based  0.004446          -0.092154
# 7              walk  39893  cordon  income-based  0.243318          -0.002076
# 8      walk_transit  53802  cordon  income-based  0.328153           0.091961

# %%
# Cleaning the names
legMode_mapping = {
    'car': 'Car',
    'car_hov2': 'Car HOV 2',
    'car_hov3': 'Car HOV 3',
    'drive_transit': 'Drive to Transit',
    'ride_hail': 'Ride-Hail',
    'ride_hail_pooled': 'Ride-Hail Pooled',
    'walk': 'Walk',
    'walk_transit': 'Walk to Transit',
    'bike': 'Bike'
}

# Replace legMode names using the mapping
trip_count['legMode'] = trip_count['legMode'].replace(legMode_mapping)

# %%
trip_count_trim = trip_count[trip_count['scenario'] != 'baseline']

# %%
# Create a new column 'legModeGroup' to group specific legModes
trip_count_trim['ModeGroup'] = trip_count_trim['legMode'].replace({'car': 'Car Modes', 'car_hov2': 'Car Modes', 'car_hov3': 'Car Modes', 'Drive to Transit:': 'Transit', 
                                                                  'Walk to Transit': 'Transit', 'Ride-Hail': 'Ride-Hail', 'Ride-Hail Pooled': 'Ride-Hail',
                                                                  'Walk': 'Active Modes', 'Bike': 'Active Modes'})
# Out:
# /var/folders/s0/c3wmlnq101j6d2dv5gj15fkm0000gn/T/ipykernel_95520/426030707.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_count_trim['ModeGroup'] = trip_count_trim['legMode'].replace({'car': 'Car Modes', 'car_hov2': 'Car Modes', 'car_hov3': 'Car Modes', 'Drive to Transit:': 'Transit',

# %%
plot_order = ['Car', 'Car HOV 2', 'Car HOV 3', 'Drive to Transit', 'Walk to Transit', 'Ride-Hail', 'Ride-Hail Pooled', 'Walk', 'Bike']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

# Set the style to default matplotlib style
plt.style.use('default')

# Create the figure and axes objects
fig, ax = plt.subplots(figsize=(14, 8))

# Create the stacked bar plot with hue="scenario"
sns.barplot(x='legMode', y='Share', hue='scenario', data=trip_count, order=plot_order, ax=ax)

# Customize the plot
plt.xlabel('Mode', fontsize=20, labelpad=15)
plt.ylabel('Mode Share (%)', fontsize=22, labelpad=15)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=16)
plt.yticks(fontsize=18)

# Format y-axis as percentage
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))

# Set y-axis to start from 0 and cap at 45%
ax.set_ylim(0, 0.50)  # This caps the y-axis at 45%

# Move legend inside the plot in top right corner
plt.legend(title='Scenario', title_fontsize='16', fontsize=14, loc='upper right')

# Add a grid for better readability
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Set background color to white
ax.set_facecolor('white')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
trip_count_rh = trip_count_trim[(trip_count_trim['legMode'] == 'Ride-Hail') | (trip_count_trim['legMode'] == 'Ride-Hail Pooled')]

# %%
trip_count_rh['legMode'].value_counts()
# Out:
# legMode
# Ride-Hail           2
# Ride-Hail Pooled    2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming trip_count_rh is your DataFrame

plt.figure(figsize=(10, 6))

# Use default Matplotlib colors
palette = {'flat': '#1f77b4', 'income-based': '#ff7f0e'}

ax = sns.barplot(x='legMode', y='Diff wrt baseline', hue='scenario', data=trip_count_rh,
                 palette=palette)

plt.xlabel('Mode', fontsize=14)
plt.ylabel('Trip Count \n Difference with respect to baseline (%)', fontsize=14)
plt.xticks(rotation=0, ha='center', fontsize=12)
plt.yticks(fontsize=12)

# Format y-axis as percentage
vals = ax.get_yticks()
ax.set_yticklabels(['{:.0%}'.format(x) for x in vals])

# Set y-axis limits and invert the axis
plt.ylim(0, -0.25)
ax.invert_yaxis()

# Remove top and right spines
sns.despine()

# Customize legend
plt.legend(title='Scenario', loc='lower right', fontsize=12, title_fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/s0/c3wmlnq101j6d2dv5gj15fkm0000gn/T/ipykernel_95520/2182225666.py:21: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:.0%}'.format(x) for x in vals])

# %%
# VMT by mode
# Calculate difference with respect to baseline
list_df[0]['Diff wrt baseline'] = (list_df[0]['length'] - list_df[0]['length'])
list_df[1]['Diff wrt baseline'] = (list_df[1]['length'] - list_df[0]['length'])/list_df[0]['length']
list_df[2]['Diff wrt baseline'] = (list_df[2]['length'] - list_df[0]['length'])/list_df[0]['length']

# %%
vmt_mode= pd.concat([list_df[0], list_df[1], list_df[2]])
vmt_mode
# Out:
#                mode        length     geo      scenario  Diff wrt baseline
# 0              bike  2.024879e+07  cordon      baseline           0.000000
# 1               bus  2.937940e+07  cordon      baseline           0.000000
# 2         bus_empty  3.035744e+07  cordon      baseline           0.000000
# 3         cable_car  9.235944e+05  cordon      baseline           0.000000
# 4   cable_car_empty  1.203774e+06  cordon      baseline           0.000000
# ..              ...           ...     ...           ...                ...
# 18           subway  7.591236e+06  cordon  income-based           0.002897
# 19     subway_empty  8.157731e+04  cordon  income-based          -0.211868
# 20             tram  5.957351e+06  cordon  income-based           0.049541
# 21       tram_empty  2.919616e+06  cordon  income-based          -0.087854
# 22             walk  1.944245e+08  cordon  income-based           0.060007
#
# [69 rows x 5 columns]

# %%
# Remove modes we do not want to plot
# List of modes
modes_to_drop = ['bus_empty', 'cable_car', 'cable_car_empty', 'car_emer', 'car_hov2_emer', 'car_hov3_emer',
                'ferry', 'ferry_empty', 'rail_empty', 'subway_empty', 'tram_empty']  

# Create a boolean mask to identify rows that match the values in the list
mask = vmt_mode['mode'].isin(modes_to_drop)

# Drop the rows that match the values in the list
vmt_mode = vmt_mode[~mask]

# %%
# Cleaning the names
mode_mapping = {
    'car': 'Car',
    'car_hov2': 'Car HOV 2',
    'car_hov3': 'Car HOV 3',
    'car_RideHail': 'Ride-Hail',
    'car_RideHail_Pool': 'Ride-Hail Pooled',
    'car_RideHail_empty' : 'Ride-Hail Empty',
    'walk': 'Walk',
    'bike': 'Bike',
    'bus' : 'Bus',
    'tram' : 'Tram',
    'rail' : 'Rail',
    'subway' : 'Subway'
}

# Replace legMode names using the mapping
vmt_mode['mode'] = vmt_mode['mode'].replace(mode_mapping)
# Out:
# /var/folders/s0/c3wmlnq101j6d2dv5gj15fkm0000gn/T/ipykernel_95520/2406837235.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vmt_mode['mode'] = vmt_mode['mode'].replace(mode_mapping)

# %%
vmt_mode.head()
# Out:
#                mode        length     geo  scenario  Diff wrt baseline
# 0              Bike  2.024879e+07  cordon  baseline                0.0
# 1               Bus  2.937940e+07  cordon  baseline                0.0
# 5               Car  8.396631e+08  cordon  baseline                0.0
# 6         Ride-Hail  2.920227e+07  cordon  baseline                0.0
# 7  Ride-Hail Pooled  1.509180e+05  cordon  baseline                0.0

# %%
# Convert to miles (From meters)
vmt_mode['length'] = vmt_mode['length'] / 1609.34
# Out:
# /var/folders/s0/c3wmlnq101j6d2dv5gj15fkm0000gn/T/ipykernel_95520/723967624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vmt_mode['length'] = vmt_mode['length'] / 1609.34

# %%
vmt_mode.head()
# Out:
#                mode         length     geo  scenario  Diff wrt baseline
# 0              Bike   12582.046017  cordon  baseline                0.0
# 1               Bus   18255.555715  cordon  baseline                0.0
# 5               Car  521743.760723  cordon  baseline                0.0
# 6         Ride-Hail   18145.496874  cordon  baseline                0.0
# 7  Ride-Hail Pooled      93.776321  cordon  baseline                0.0

# %%
plot_order_vmt = ['Car', 'Car HOV 2', 'Car HOV 3', 'Bus', 'Rail', 'Tram', 'Subway', 'Ride-Hail', 'Ride-Hail Pooled', 'Ride-Hail Empty', 'Walk', 'Bike']

# %%
vmt_car = vmt_mode[(vmt_mode['mode'] == 'Car') | (vmt_mode['mode'] == 'Car HOV 2') | (vmt_mode['mode'] == 'Car HOV 3')]

# %%
total_length_by_scenario = vmt_car.groupby('scenario')['length'].sum().reset_index()

total_length_by_scenario = total_length_by_scenario.sort_values('scenario')

# Display the results
print(total_length_by_scenario)
# Out:
#        scenario         length
# 0      baseline  664371.746149
# 1          flat  481359.914190
# 2  income-based  561797.527887

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

# Set the style for the plots
plt.style.use('default')

# Create the figure and subplots
fig, (ax_top, ax_bottom) = plt.subplots(ncols=1, nrows=2, sharex=True, figsize=(12, 8))

# Create the bar plots
sns.barplot(x='mode', y='length', hue='scenario', data=vmt_car, ax=ax_top)
sns.barplot(x='mode', y='length', hue='scenario', data=vmt_car, ax=ax_bottom)

# Set y-axis limits
ax_top.set_ylim(bottom=300000, top=700000)  # Reduced from 1000k to 700k
ax_bottom.set_ylim(0, 160000)

# Configure axes
ax_top.set_xlabel('')
ax_bottom.set_xlabel('Mode', fontsize=18)  # Changed from 'Mode' to 'Transport Mode'

# Remove y-axis labels
ax_top.set_ylabel('')
ax_bottom.set_ylabel('')

# Format y-axis labels without 'k' suffix
def format_func(value, tick_number):
    return f'{value/1000:.0f}'  # Removed 'k' suffix

ax_top.yaxis.set_major_formatter(plt.FuncFormatter(format_func))
ax_bottom.yaxis.set_major_formatter(plt.FuncFormatter(format_func))

# Increase font size for tick labels
ax_top.tick_params(axis='both', which='major', labelsize=16)  # Increased size
ax_bottom.tick_params(axis='both', which='major', labelsize=16)  # Increased size

# Keep x-axis labels horizontal (removed rotation)
plt.setp(ax_bottom.get_xticklabels(), fontsize=16)  # No rotation, larger font

# Add horizontal grid lines
ax_top.yaxis.grid(True, linestyle='--', alpha=0.7)
ax_bottom.yaxis.grid(True, linestyle='--', alpha=0.7)

# Add break lines between subplots
d = .015  # Size of the diagonal lines
kwargs = dict(transform=ax_top.transAxes, color='k', clip_on=False)
ax_top.plot((-d, +d), (-d, +d), **kwargs)
ax_top.plot((1 - d, 1 + d), (-d, +d), **kwargs)
kwargs.update(transform=ax_bottom.transAxes)
ax_bottom.plot((-d, +d), (1 - d, 1 + d), **kwargs)
ax_bottom.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)

# Add y-axis label with note about values in thousands
fig.text(0.02, 0.5, '      VMT (miles])\n(Values in thousands)', va='center', rotation='vertical', fontsize=18)  # Moved closer and added note about values

# Adjust legend
handles, labels = ax_top.get_legend_handles_labels()
ax_top.legend(handles, labels, title='Scenario', loc='upper right', fontsize=16, title_fontsize=18)  # Increased font sizes
ax_bottom.legend_.remove()

# Adjust layout and show the plot
plt.tight_layout()
plt.subplots_adjust(hspace=0.1, left=0.15)
plt.show()

# %%
vmt_mode_trim = vmt_mode[vmt_mode['scenario'] != 'baseline']

# %%
# Plotting using Seaborn
plt.figure(figsize=(12, 7))
ax = sns.barplot(x='mode', y='Diff wrt baseline', hue='scenario', data=vmt_mode_trim, order = plot_order_vmt, palette='bright')
plt.xlabel('Mode', fontsize=20)
plt.ylabel('VMT \n Difference with respect to baseline (%)', fontsize=18)
#plt.title('Difference of Trip Count by Mode compared to Baseline by Scenario', fontsize=18)
plt.xticks(rotation=45, ha='right', fontsize=18)
plt.yticks(fontsize=18)
vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])
plt.tight_layout()
plt.legend(loc='lower right', fontsize=16)
# Add label grouping below x-axis
#group_labels = ['Car Modes', 'Car Modes', 'Car Modes', 'Transit', 'Transit', 'Ride-Hail', 'Ride-Hail', 'Active Modes', 'Active Modes']
#ax.set_xticklabels(group_labels)



plt.show()
# Out:
# /var/folders/s0/c3wmlnq101j6d2dv5gj15fkm0000gn/T/ipykernel_11599/4269646888.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])

# %%
vmt_mode.to_csv('vmt_mode_export.csv')

# %%
list_df[13].dtypes
# Out:
# mode         object
# 0           float64
# geo          object
# scenario     object
# dtype: object

# %%
# Energy use

list_df[18] = list_df[18][list_df[18]['primaryFuelType']!='Food']
list_df[19] = list_df[19][list_df[19]['primaryFuelType']!='Food']
list_df[20] = list_df[20][list_df[20]['primaryFuelType']!='Food']

# %%
list_df[18]['Diff wrt baseline'] = (list_df[18]['primaryFuel'] - list_df[18]['primaryFuel'])
list_df[19]['Diff wrt baseline'] = (list_df[19]['primaryFuel'] - list_df[18]['primaryFuel'])/list_df[18]['primaryFuel']
list_df[20]['Diff wrt baseline'] = (list_df[20]['primaryFuel'] - list_df[18]['primaryFuel'])/list_df[18]['primaryFuel']
# Out:
# /var/folders/s0/c3wmlnq101j6d2dv5gj15fkm0000gn/T/ipykernel_11599/552607534.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   list_df[20]['Diff wrt baseline'] = (list_df[20]['primaryFuel'] - list_df[18]['primaryFuel'])/list_df[18]['primaryFuel']

# %%
#remove emer
emer=['car_emer', 'hov2_emer', 'hov3_emer']

# Create a boolean mask to identify rows that match the values in the list
mask1 = list_df[18]['primaryFuel'].isin(emer)  # Replace 'column_name' with the actual column name you want to use for the condition
mask2 = list_df[19]['primaryFuel'].isin(emer)
mask3 = list_df[20]['primaryFuel'].isin(emer)


# Drop the rows that match the values in the list
list_df[18] = list_df[18][~mask1]
list_df[19] = list_df[19][~mask2]
list_df[20] = list_df[20][~mask3]

# %%
tot_e_base = list_df[18]['primaryFuel'].sum()
tot_e_flat = list_df[19]['primaryFuel'].sum()
tot_e_income = list_df[20]['primaryFuel'].sum()

dif_flat = (tot_e_flat-tot_e_base)/tot_e_base
dif_income = (tot_e_income-tot_e_base)/tot_e_base

print(dif_flat)
print(dif_income)
# Out:
# -0.19117665012020044
# -0.10475626498046414

# %%
primary_e = pd.concat([list_df[18], list_df[19], list_df[20]])

# %%
primary_e = primary_e[primary_e['Diff wrt baseline'].notna()]

# %%
primary_e
# Out:
#                mode primaryFuelType   primaryFuel     geo      scenario  \
# 0              bike        Gasoline  2.144840e+08  cordon      baseline
# 1               bus          Diesel  5.758619e+11  cordon      baseline
# 2         bus_empty          Diesel  5.911220e+11  cordon      baseline
# 3         cable_car     Electricity  0.000000e+00  cordon      baseline
# 4   cable_car_empty     Electricity  0.000000e+00  cordon      baseline
# ..              ...             ...           ...     ...           ...
# 14         car_hov2        Gasoline  2.284139e+11  cordon  income-based
# 15    car_hov2_emer        Gasoline  1.851900e+10  cordon  income-based
# 16         car_hov3     Electricity  1.404394e+08  cordon  income-based
# 17         car_hov3        Gasoline  1.816400e+11  cordon  income-based
# 18    car_hov3_emer        Gasoline  1.553743e+10  cordon  income-based
#
#     Diff wrt baseline
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ..                ...
# 14          -0.229193
# 15          -0.258094
# 16          -0.276226
# 17          -0.117858
# 18          -0.040535
#
# [62 rows x 6 columns]

# %%
total_e_by_scenario = primary_e.groupby('scenario')['primaryFuel'].sum().reset_index()

total_e_by_scenario = total_e_by_scenario.sort_values('scenario')

# Display the results
print(total_e_by_scenario)
# Out:
#        scenario   primaryFuel
# 0      baseline  3.712516e+12
# 1          flat  3.002770e+12
# 2  income-based  3.323607e+12
